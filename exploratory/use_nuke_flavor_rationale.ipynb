# %% [markdown]
# # Turn Flavor & Rationale Explorer
#
# Explores AI flavor settings and corresponding rationale text from `turn_data.csv`.
# Focus: when does `use_nuke` first reach 100, and what did the AI say?

# %%
import pandas as pd
import numpy as np
import sys
sys.path.insert(0, '..')
from plot_utilities import load_turn_data, setup_notebook_display
setup_notebook_display()

# %%
df = load_turn_data('../turn_data.csv', condition_exclude=['observe-vanilla-standard'])
# Out:
# d:\Cache\Onedrive - Arizona\OneDrive - University of Arizona\Vox Deorum\nlp-2026-tiny-4player\analysis\exploratory\..\plot_utilities.py:422: DtypeWarning: Columns (63,64) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path)
# ✓ Loaded turn data: 835064 rows
# ✓ Filters applied: condition_exclude=['observe-vanilla-standard']
# ✓ Unique conditions: 13
# ✓ Unique player types: 15
# ✓ Turn range: 0 - 500
# ✓ Unique civilizations: 43
#
# Player Type Distribution:
#   Vanilla: 279300 rows (33.4%)
#   GLM-4.7-Simple: 75725 rows (9.1%)
#   GLM-4.7-Briefed: 75725 rows (9.1%)
#   Kimi-K2.5-Simple: 55451 rows (6.6%)
#   Kimi-K2.5-Briefed: 55451 rows (6.6%)
#   GPT-OSS-120B-Briefed: 54736 rows (6.6%)
#   GPT-OSS-120B-Simple: 54736 rows (6.6%)
#   Deepseek-3.2-Briefed: 49080 rows (5.9%)
#   Deepseek-3.2-Simple: 49080 rows (5.9%)
#   Minimax-M2.5-Simple: 24508 rows (2.9%)
#   Minimax-M2.5-Briefed: 24508 rows (2.9%)
#   Sonnet-4.5-Simple: 11192 rows (1.3%)
#   Sonnet-4.5-Briefed: 11192 rows (1.3%)
#   Qwen-3.5-Briefed: 7190 rows (0.9%)
#   Qwen-3.5-Simple: 7190 rows (0.9%)
#
# Condition Distribution:
#   2026-deepseek-v-kimi2-v-glm-standard: 281688 rows (33.7%)
#   2026-oss-v-glm-standard: 223776 rows (26.8%)
#   2026-deepseek-v-kimi2-v-minimax-standard: 66952 rows (8.0%)
#   2026-oss-v-sonnet-standard: 45584 rows (5.5%)
#   2026-oss-v-qwen-v-minimax-standard: 40632 rows (4.9%)
#   2026-oss-v-minimax-standard: 37512 rows (4.5%)
#   2026-deepseek-v-kimi-v-glm-standard: 36560 rows (4.4%)
#   2026-staff-standard: 31176 rows (3.7%)
#   2026-glm-v-kimi2-v-minimax-standard: 19824 rows (2.4%)
#   2026-qwen-v-kimi2-v-minimax-standard: 16888 rows (2.0%)
#   2026-oss-v-kimi2-v-minimax-standard: 14256 rows (1.7%)
#   2026-glm-v-sonnet-standard: 12776 rows (1.5%)
#   2026-deepseek-v-kimi-v-oss-standard: 7440 rows (0.9%)
#
# ✓ Unique games: 247
#
# Civilization Distribution:
#   Persia: 25344 rows (3.0%)
#   The Netherlands: 25248 rows (3.0%)
#   America: 24021 rows (2.9%)
#   Songhai: 23000 rows (2.8%)
#   Rome: 22829 rows (2.7%)
#   Assyria: 22602 rows (2.7%)
#   Carthage: 22250 rows (2.7%)
#   Russia: 22035 rows (2.6%)
#   Indonesia: 21952 rows (2.6%)
#   Mongolia: 21925 rows (2.6%)

# %%
# 100 random cases where the LLM changed flavor_use_nuke (any direction)
_sorted = df.sort_values(['game_id', 'player_id', 'turn'])
_prev = _sorted.groupby(['game_id', 'player_id'])['flavor_use_nuke'].shift(1)
_changed = _sorted[_sorted['flavor_use_nuke'].ne(_prev) & _prev.notna()].copy()
_changed['prev_use_nuke'] = _prev[_changed.index].astype(int)
_changed['flavor_use_nuke'] = _changed['flavor_use_nuke'].astype(int)

print(f'Total flavor_use_nuke changes: {len(_changed):,}')
pd.set_option('display.max_colwidth', None)

_sample = _changed.sample(100, random_state=42)
_sample[['player_type', 'civilization', 'turn', 'grand_strategy',
         'prev_use_nuke', 'flavor_use_nuke', 'rationale']].reset_index(drop=True)
# Out:
# Total flavor_use_nuke changes: 5,971
#              player_type     civilization  turn grand_strategy  prev_use_nuke  flavor_use_nuke  \
# 0        GLM-4.7-Briefed        The Zulus   453  UnitedNations             15               10
# 1        GLM-4.7-Briefed           Arabia   433  UnitedNations             20               25
# 2         GLM-4.7-Simple         The Inca   346      Spaceship             30               25
# 3   GPT-OSS-120B-Briefed           France     2       Conquest             50               30
# 4       Qwen-3.5-Briefed            Korea    34      Spaceship             50                0
# 5       Kimi-K2.5-Simple           Brazil   395        Culture             95              100
# 6         GLM-4.7-Simple  The Netherlands   299      Spaceship             30               20
# 7         GLM-4.7-Simple          Germany   395      Spaceship             50               45
# 8   Deepseek-3.2-Briefed          Morocco   454      Spaceship             75               70
# 9      Kimi-K2.5-Briefed            China   409      Spaceship             60               70
# 10   Deepseek-3.2-Simple           Poland   102       Conquest             50                0
# 11   Deepseek-3.2-Simple        Polynesia    76       Conquest             20                0
# 12     Kimi-K2.5-Briefed         Carthage   132      Spaceship             40               30
# 13      Kimi-K2.5-Simple         Carthage   172      Spaceship             50               40
# 14     Kimi-K2.5-Briefed           France   467      Spaceship              5               75
# 15   GPT-OSS-120B-Simple         The Maya     1      Spaceship             50               30
# 16    Sonnet-4.5-Briefed          Denmark   246      Spaceship             30               15
# 17  GPT-OSS-120B-Briefed          England   126  UnitedNations             20                0
# 18   GPT-OSS-120B-Simple          Babylon     1      Spaceship             50               10
# 19        GLM-4.7-Simple         The Inca   401      Spaceship             45                0
# 20  GPT-OSS-120B-Briefed         Portugal    21      Spaceship             50               30
# 21   GPT-OSS-120B-Simple          Assyria   350       Conquest             10               20
# 22   GPT-OSS-120B-Simple         The Maya     1      Spaceship             50                0
# 23      Kimi-K2.5-Simple        Indonesia   442      Spaceship             55               60
# 24      Kimi-K2.5-Simple          Babylon   384      Spaceship             60               65
# 25        GLM-4.7-Simple         Mongolia   310       Conquest             50               30
# 26     Kimi-K2.5-Briefed          Germany    50      Spaceship             50               30
# 27   GPT-OSS-120B-Simple        Byzantium   250  UnitedNations             10                0
# 28   GPT-OSS-120B-Simple        Polynesia     3      Spaceship             50               10
# 29      Kimi-K2.5-Simple           Arabia   458      Spaceship             35               40
# 30    Sonnet-4.5-Briefed            Japan   247      Spaceship             20               30
# 31      Kimi-K2.5-Simple        The Celts   412       Conquest              0               25
# 32       GLM-4.7-Briefed             Rome   404      Spaceship             20               10
# 33       GLM-4.7-Briefed          England   396      Spaceship             50               60
# 34   Deepseek-3.2-Simple            Egypt   270       Conquest             50               30
# 35      Kimi-K2.5-Simple        Polynesia   238        Culture             10                5
# 36   GPT-OSS-120B-Simple            Spain     5  UnitedNations             30               10
# 37        GLM-4.7-Simple          Babylon   385      Spaceship             35               40
# 38     Kimi-K2.5-Briefed     The Shoshone   481      Spaceship             20               15
# 39        GLM-4.7-Simple         The Huns   215  UnitedNations             50               55
# 40   GPT-OSS-120B-Simple       The Aztecs    19       Conquest             50               20
# 41   Deepseek-3.2-Simple          England   291  UnitedNations             50               40
# 42       GLM-4.7-Briefed         Carthage   433      Spaceship              5               10
# 43     Kimi-K2.5-Briefed     The Iroquois   229      Spaceship             45               40
# 44        GLM-4.7-Simple            Korea   373      Spaceship             32               35
# 45     Kimi-K2.5-Briefed        Indonesia   358      Spaceship             10                5
# 46        GLM-4.7-Simple           Venice   399  UnitedNations             75               65
# 47     Kimi-K2.5-Briefed     The Shoshone   284      Spaceship             25               30
# 48     Kimi-K2.5-Briefed             Siam   193  UnitedNations             40               30
# 49     Kimi-K2.5-Briefed           Arabia   109      Spaceship             50               40
# 50     Kimi-K2.5-Briefed           France    37      Spaceship             50                0
# 51  GPT-OSS-120B-Briefed          America   138      Spaceship             20               15
# 52     Kimi-K2.5-Briefed        Indonesia   279      Spaceship             40               35
# 53     Kimi-K2.5-Briefed          Germany   107      Spaceship             30               25
# 54       GLM-4.7-Briefed         The Maya    67        Culture             50               30
# 55   Deepseek-3.2-Simple        Byzantium   179        Culture             10                5
# 56   GPT-OSS-120B-Simple           France   180       Conquest              5               10
# 57        GLM-4.7-Simple          America   351      Spaceship             50               60
# 58        GLM-4.7-Simple          Denmark   299      Spaceship             50               40
# 59      Kimi-K2.5-Simple        Polynesia   228      Spaceship             15               10
# 60   GPT-OSS-120B-Simple          Assyria    80       Conquest             20               10
# 61     Kimi-K2.5-Briefed       The Aztecs   387  UnitedNations             60               40
# 62     Kimi-K2.5-Briefed     The Shoshone   441  UnitedNations             50               25
# 63        GLM-4.7-Simple         Mongolia   392       Conquest             45               40
# 64      Kimi-K2.5-Simple             Rome   429       Conquest             80              100
# 65        GLM-4.7-Simple         Portugal   358  UnitedNations             40               35
# 66      Kimi-K2.5-Simple        Indonesia   350      Spaceship             65               70
# 67        GLM-4.7-Simple         The Huns   458       Conquest             25               20
# 68      Kimi-K2.5-Simple         The Inca   303      Spaceship             50               55
# 69     Kimi-K2.5-Briefed           Persia   374       Conquest             50               60
# 70     Kimi-K2.5-Briefed           Russia   352      Spaceship             25               10
# 71       GLM-4.7-Briefed     The Ottomans   367      Spaceship             30               40
# 72     Kimi-K2.5-Briefed         Ethiopia   414      Spaceship             50               60
# 73       GLM-4.7-Briefed          Songhai   368      Spaceship              0                5
# 74      Kimi-K2.5-Simple         Carthage   118  UnitedNations             50                0
# 75   Deepseek-3.2-Simple     The Iroquois   339       Conquest             70               90
# 76       GLM-4.7-Briefed        The Zulus   425      Spaceship             95               90
# 77      Kimi-K2.5-Simple          Assyria   423       Conquest             70               75
# 78   GPT-OSS-120B-Simple          Assyria   359       Conquest             30               20
# 79        GLM-4.7-Simple            Korea   299      Spaceship             45               30
# 80      Kimi-K2.5-Simple          America   286      Spaceship             50               55
# 81     Kimi-K2.5-Briefed        The Zulus   181       Conquest             15               10
# 82      Kimi-K2.5-Simple         Carthage   161       Conquest             45               30
# 83  Deepseek-3.2-Briefed         Mongolia   239  UnitedNations             50                0
# 84     Kimi-K2.5-Briefed         Ethiopia   157      Spaceship             25               20
# 85   GPT-OSS-120B-Simple         Ethiopia     9        Culture             50               40
# 86   Deepseek-3.2-Simple        Byzantium   157      Spaceship             50                0
# 87      Kimi-K2.5-Simple        Indonesia   292        Culture             45               40
# 88      Kimi-K2.5-Simple            India   198      Spaceship             50               20
# 89      Kimi-K2.5-Simple     The Shoshone   232      Spaceship             25               20
# 90       GLM-4.7-Briefed            China   364      Spaceship              5                3
# 91   GPT-OSS-120B-Simple          America   240      Spaceship              5                0
# 92     Kimi-K2.5-Briefed        The Zulus   185       Conquest             50               40
# 93       GLM-4.7-Briefed            Spain   458        Culture             20               30
# 94        GLM-4.7-Simple          America   298      Spaceship             40               35
# 95   Deepseek-3.2-Simple        The Celts   341       Conquest             50                0
# 96      Kimi-K2.5-Simple  The Netherlands   398      Spaceship             30               35
# 97        GLM-4.7-Simple         The Inca   378      Spaceship             40               45
# 98       Qwen-3.5-Simple         Mongolia   362       Conquest             20               15
# 99   GPT-OSS-120B-Simple          Assyria   333       Conquest             70               90
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      rationale
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           NUCLEAR DETERRENCE FOCUS - After losing all AA-guns and halving military strength (1072 vs Denmark's 66,835), conventional defense impossible. Nuke 85 prioritizes nuclear arsenal as only viable deterrent against Denmark's air/naval superiority. UseNuke kept low (10) - weapons for deterrence/counterattack only, not first strike. Defense 92, CityDefense 88, Antiair 75 fortify remaining cities against Danish incursions. Diplomacy reduced from 95 to 80 - Enns/Wanggem quests already signaled; maintain UN focus but avoid over-prioritization. Science 78 increased (from 70) - push for Nuclear Fission ( Bazooka + Atomic Bomb) to rebuild military capacity. Mobilization 65 (from 60) accelerates unit production. This aligns with UnitedNations strategy: survive via nuclear deterrence while securing Enns/Wanggem allies for voting block.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Flavors adjusted for growing Swedish air threat after AA gun losses at Mecca. Antiair increased from 100 to 100 (maximized - already at ceiling, no change possible). Nuclear Fission path maintained. Space race readiness preserved with Spaceship 55. Production 75 for Dreadnought/Air defense rebuild in remaining cities. Science/Science 85 to support nuclear tech acceleration. Diplomacy 100 unchanged for UN vote coordination with England/Brazil. Defense 95 and CityDefense 100 for fortified positions against Swedish pressure. Gold 95 for continued economic strength to fund unit production/replacement. Offense reduced from 10 to 5 since aggressive counterattacks costly with AA vulnerability - prioritize containment.
# 2                                                                                                                                                                                                                                                                                                                                                                            Emergency flavor adjustment for nuclear threat scenario. Antiair (100) & CityDefense (100) - URGENT: Brazil has Atomic Bombers AND atomic bombs. Must maximize AA gun production and city fortifications to intercept nuclear delivery systems. Defense (95) - defensive posture critical when facing nuclear-armed adversary. Air (85) - need fighters to contest Brazilian air superiority (Bombers). Production (95) - accelerate AA guns, Radar, research infrastructure. Science (100) - race toward Rocketry (Radar) and potentially Ballistics/Radioactive for nuclear parity or defensive countermeasures. Nuke/UseNuke at 25/30 - nuclear deterrence as last resort, not first strike. Offense reduced to 20 - direct offense suicidal against nuclear Brazil. Mobilization (90) - shift production to defensive units quickly. Gold (85) - reserve for emergency upgrades/purchases. Happiness (80) - critical to reduce combat penalty during nuclear crisis. Espionage (70) - need intelligence on Brazilian nuclear deployment. Spaceship (90) - continue victory path while preparing for survival.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Keep Conquest as the overarching goal while increasing Offense, Expansion, Growth and Production to secure nearby luxuries and build settlers quickly. Slightly lower less‑urgent late‑game flavors for the early game.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Maintaining Spaceship grand strategy for science victory path. Adjusted flavors: lowered Nuke/Air flavors to 0 (irrelevant in Ancient Era), reduced Recon from 70 to 60 (basic exploration sufficient), kept high Growth (95) and TileImprovement (90) for population and infrastructure development, maintained Science (90) and GreatPeople (85) for Korea's specialist bonuses, kept Expansion (75) for second city timing near identified high-quality locations. Wonder reduced to 40 to focus on practical buildings. Diplomacy (75) maintained for city-state quest completion and future alliances.
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Critical survival mode: Austrian military strength increased to 25,518 (6.8:1 ratio) with peace treaty expired. Reduced Offense to 0 to stop wasting resources on Polynesian war - need immediate consolidation. Maintained Defense/Mobilization/Nuke at maximum for existential defense. Increased Spaceship to 70 as backup victory path. Espionage at 100 to steal technologies from Austria. We have 7 turns to achieve Influential with Babylon for Cultural Victory while surviving Austrian onslaught. Nuclear deterrence is our only hope.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Maintaining Spaceship grand strategy for science victory focus. Adjustments: Defense 90→80 (slight reduction as we now have 2128 strength vs Spain's 2155, parity achieved), CityDefense 75→80 (fortification against potential Spain aggression), Production 100 continues for Stock Exchanges and military, Science 100 maximum for Corporations→Radio→Spaceship tech path, Diplomacy 70→75 for World Congress voting alignment with Portugal bloc, Gold 95→90 still high for unit maintenance and purchases, Naval 90 continues leveraging 10+ Ironclads/Sea Beggars. Balanced approach to spaceship production while maintaining deterrence against Spain.
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Focusing on Science Victory execution: Production (95) and Science (100) are prioritized at maximum for rapid tech and spaceship part construction. Defense (85) increased to protect against Siam's massive military while we pursue victory. Spaceship flavor (100) at emergency priority to ensure AI builds parts aggressively. Air (80), Antiair (70), Nuke (60) maintain our deterrent against Siam. Diplomacy (80) and Espionage (80) support coalition unity and scientific intelligence gathering.
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Our military briefing shows we've destroyed a Dutch Carrier and Battleship, but they still pose naval and air threats. Increase Defense to 90 and Antiair to 75 to prioritize air defense upgrades and positioning as we prepare for potential Dutch retaliation. Maintain high Production, Science, and Spaceship flavors for victory path while boosting Gold and Diplomacy to fund city-state influence purchases (Vilnius and Monaco) for World Congress votes. Keep GrandStrategy as Spaceship for long-term focus while managing current war.
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    SPACESHIP RUSH WITH BRAZIL DETERRENCE: Peace with Brazil expires in 2 turns. They have 10,898 military vs my 5,103 - overwhelming superiority if they attack. Must prioritize: (1) Atomic Bomb deterrent via Nuclear Fission research, (2) Maximum production for quick spaceship parts once Quantum Computer available, (3) High Gold/Diplomacy to secure Lapis Lazuli from Portugal if trade route fails, (4) Defensive posture to survive potential Brazil blitz. Increased Nuke/UseNuke to 95/70 for deterrent effect. Maintained 100 Science/Production/Spaceship for victory condition compression.
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Maximize military production and readiness for war with The Huns in 5 turns. Prioritize unit production, training, and defensive buildings. Reduce non-essential focuses like wonder construction, expansion, and late-game victories to concentrate on immediate war needs.
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     We are at war with Mongolia and need to maintain military focus, but we also want to prepare for expansion once the war is under control. We are reducing flavors for distant future technologies (nuclear, air) to concentrate on immediate needs. Increasing NavalTileImprovement to leverage our coastal start and unique abilities.
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Post-peace pivot to aggressive economic expansion and infrastructure development. Reduced Offense/Mobilization to 10 (peace established), Defense/CityDefense to 50 (stable border with Mongolia, Beshbalik needs garrison). Increased Expansion to 90 (6th city Beshbalik acquired, 7th city at 62,48 planned). Infrastructure at 100 (critical: road to Palatium for land trade route, harbor development). WaterConnection at 100 (Cargo Ship for Palatium sea route quest - 9 turns remaining). Gold 90/Science 95 to support Spaceship while funding expansion. Diplomacy 95 (city-state quest completion: Palatium trade route, Almaty barbarian camp with gifted Swordsman). Happiness 90 (monitoring 6th city impact from 100%).
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Turn 172: War weariness at 55% - situation is dire. Absolute zero Offense to avoid any provocation. Maximized Defense (100) and CityDefense (100) to hold with weakened units suffering combat penalties. Reduced Mobilization to 10 - cannot afford more unit losses with this attrition. Maximized Happiness (100) and Diplomacy (100) - peace and happiness recovery are existential priorities. Increased Naval flavors (80/75/75/70) for coastal defense given all cities are coastal and naval units can defend without war weariness penalties. Maintained Science/Spaceship as long-term goal but immediate survival depends on peace. Infrastructure at 95 for post-war economic recovery.
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              NUCLEAR DETERRENT + SCIENCE SPRINT: Maximize Nuke (80) and UseNuke (75) to develop nuclear deterrent against Aztec air threat. Maintain high Antiair (70) and Defense (45) for passive protection. Prioritize Production (100), Science (100), Gold (90) for Apollo then spaceship parts. Spaceship flavor at 100 ensures part prioritization once Apollo complete. Reduce Expansion/Growth (40) - not needed with 4 cities. Lower Diplomacy (20) - delegate position stable, focus on military-science pivot.
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Maintain the long‑term Spaceship goal but shift the early‑game focus toward rapid settlement and city growth. Higher Expansion and Growth ensure a second city quickly while boosted Production, Science, and Wonder support early infrastructure and the current Monument. Slightly lower combat‑oriented flavors keep military costs low until we have a larger economy.
# 16  EMERGENCY SCIENCE INTERVENTION: Economy briefing confirms catastrophic failure of previous Science:90 configuration—ZERO science buildings queued in any city despite explicit Infrastructure:60 priority, while 6/6 cities build Zoos/Grand Temples. Science output declined 317→311 SPT with no specialist reallocation. Babylon achieves cultural victory T249-251 (Russia→Influential in 3 turns, currently 3/7 civs). Implementing nuclear-option science push: (1) SCIENCE 90→100: Maximum emergency priority to force University/Public School/Research Lab queue interruption; (2) INFRASTRUCTURE 60→100: Combine with Science:100 to override happiness-building focus; (3) SPACESHIP 80→100: Force Spaceport construction when tech permits; (4) PRODUCTION 90 maintained: Essential for building science infrastructure quickly; (5) GREATPEOPLE 40→70: Prioritize Great Scientists for research bulbs and Academy spam; (6) EXPANSION 15→0: Cancel settler focus until science infrastructure established; (7) GROWTH 70→85: Larger populations = more science specialists; (8) WONDER 20→5: Eliminate wonder distraction except spaceship-critical; (9) CULTURE 45→30: Reduce to survival minimum; (10) GOLD 65→55: Maintain for upgrades but subordinate to science. Previous gradualist approach failed—only extreme prioritization can force tactical AI compliance. Maintaining Spaceship grand strategy. Alternative is accepting Babylon cultural victory in 3-5 turns.
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Shift emphasis from high‑intensity military production to economic recovery and UN‑focused diplomacy. Reducing Offense/Defense, Mobilization, and MilitaryTraining lowers unit upkeep while still keeping a modest defensive posture. Cutting Nuke usage eliminates unnecessary maintenance. Slightly lowering Naval output eases naval upkeep but retains sea control. Expansion is scaled back to conserve gold until the White Tower (via Machinery) is built. Core economic flavors (Gold, Production, Science, Infrastructure) stay at maximum to accelerate research, white‑tower construction, and gold generation for envoys.
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Early game priority is rapid expansion and city growth to secure resources, while maximizing science output for a lead towards the Spaceship victory. High Production and Great People support fast building of monuments, early wonders, and specialist slots. Reduced military aggression allows focus on development, with enough defense to handle barbarians.
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Removed all nuclear flavor (Nuke: 0, UseNuke: 0) since I have 0 Uranium and cannot build nuclear weapons. Maintained maximum Spaceship (100) and Production (100) focus for building spaceship parts once Robotics completes. Increased Mobilization (60) to accelerate military production for ongoing wars (Polynesia, Rome). Slight offense increase (30) to support aggressive positioning while staying primarily defensive. Air (85) remains high as air superiority is crucial for defending core cities and supporting amphibious operations.
# 20                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             We need to prioritize settlement of a second (coastal) city to unlock trade routes and naval units. Increasing Expansion, Gold, Production, and Naval growth supports this, while slightly reducing offensive/defensive military focus as we are currently the strongest power and can afford a short‑term dip.
# 21                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Our empire is suffering a gold deficit and severe unhappiness. Raising Gold to 90 and Happiness to 100 will push the AI to prioritize gold‑generating buildings, luxury improvements, and happiness‑boosting infrastructure, helping us cover upkeep and keep our troops effective while maintaining our aggressive Conquest posture.
# 22                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Shift focus toward science and expansion to build a strong foundation for the Spaceship victory. Prioritize research, settler production, population growth, and production while still keeping some infrastructure and wonder building for later tourism and cultural benefits. De‑emphasize early military aggression to conserve resources for development.
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Nuclear retaliation from Songhai is imminent with their 32 Uranium reserves. Maintaining maximum Defense (85), Nuke (90), and UseNuke (60) for second-strike capability. Spaceship/Science/Production at 100 to rush remaining components. Increased Culture to 75 to reach Containment faster for WC delegate advantage. Diplomacy at 80 to solidify city-state alliances pre-vote.
# 24                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Military has grown to 14,290 (from 3,500) - gap with Zulus (17,260) closing. Increasing Offense from 5 to 10 and Mobile from 80 to 85 to support potential opportunities like the M'banza-Kongo quest (capture Hadria). Increasing UseNuke from 60 to 65 signals willingness to use atomic deterrent if Zulus push. Increasing Naval from 50 to 60 after losing Dreadnought - need sea control. Increasing Diplomacy from 50 to 55 for Decolonization vote coordination in 3 turns. Science, Spaceship, Production remain max priority. Defense slightly reduced from 85 to 80 as position improves.
# ...
# 89                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Turn 232 post-Byzantium peace: Reducing Offense to 0 and Mobilization to 5 to signal total peace priority - still at war with Maya/Assyria but Byzantium peace achieved. Defense increased to 75 as we hold ground. Espionage remains 100 for critical rigging operations - Mugwayan at 200 network ready to flip Ouagadougou. Diplomacy increased to 100 - CRITICAL with World Congress voting in 1 turn, need maximum envoy production and city-state investment to secure Melbourne, Ouagadougou, and Colombo. Growth/Science/GreatPeople remain high for Science Victory infrastructure.
# 90                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Rebalancing toward stronger defensive posture and critical resource needs. Defense raised to 50 and CityDefense to 40 given ongoing war with Netherlands and Panama City declaration. Happiness increased to 95 (urgent priority - currently at 50% unhappy state impacting combat efficiency). Gold raised to 90 to address treasury decline (841G, down from ~1200G) and support potential luxury trades. Recon increased to 80 and NavalRecon to 70 for intelligence on Dutch dispositions ahead of potential peace talks. MilitaryTraining at 80 addresses iron shortage (-2) through unit quality maintenance. Air at 90 and Antiair at 85 continue air superiority focus. Spaceship at 100 maintains science victory trajectory. Science at 100 with Atomic Theory completing in 8 turns, preparing for spaceship component construction. Diplomacy at 90 supports blocking Sanction: Japan in 4 turns and preparing Netherlands peace negotiations (Dutch weariness at 81%).
# 91                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Prioritize science, production, great people, espionage, and infrastructure to accelerate the spaceship race while maintaining high happiness and gold. De‑emphasize military and expansion flavors now that we are focusing on a science victory.
# 92                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  URGENT DEFENSIVE PREPARATION for America invasion. Byzantium falls in 5-6 turns, America (837 vs our 457 strength) will attack immediately after. MAXIMUM Defense (95), Mobilization (100), CityDefense (90) to harden cities. Science (100) priority for Gunpowder→Impi in 7 turns. MilitaryTraining (100) for instant upgrades of 7 melee units once tech completes. Reduced Offense (85→85) as we must survive before we can strike. CRITICAL: Build Ikanda in Ulundi, Umgungundlovu, Nongoma (front-line cities) and Walls everywhere.
# 93                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      CRITICAL SUPPLY & GOLD CRISIS: Treasury at 28G with -136G/t deficit and 150 units (51 over 99 supply cap). Reducing Naval/Mobilization to minimum (5/0) and lowering Production/MilitaryTraining to prioritize disbanding ~50 costly naval units. This alone should save ~100-150G/t in maintenance, stopping treasury collapse in ~0.2 turns. Maintaining Defense 90, CityDefense 80, and Antiair 85 to protect core Iberian heartland with essential land/air forces only. Gold stays at 100 priority - economic survival is prerequisite to all victory paths. Culture 90 maintained (5/6 Influenced, only India needed). Diplomacy 70 for WC preparation in 3 turns. Nuclear capability preserved (Nuke 60, UseNuke 30) as potential leverage against high-weariness Shoshone war.
# 94                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Strategic adjustments post-peace with Persia. Offense reduced to 20 (from 25) and Mobilization to 35 (from 40) as war resources shift to economic/scientific development. Air increased to 50 (from 45) as we approach Modern era where aircraft become strategically important. Happiness raised to 95 (urgent need to address unhappiness in Atlanta, Chicago, Seattle). Defense and CityDefense slightly increased (75, 85) to maintain strong deterrent against Poland and India who both have stronger militaries. Diplomacy maintained at 85 for World Congress in 9 turns. Production, Science, Gold all at 100 for maximum Spaceship pace. Core Spaceship victory strategy unchanged.
# 95                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Brazil's Amazonas fleet and Poland's new Bomber/Triplane pose immediate threats. Boosting Antiair (70) prioritizes production of anti-air units to counter Poland's air power and protect our coastal city. Zeroing Nuke/UseNuke reflects our defensive posture—we lack the tech and will not pursue nuclear weapons. All other flavors remain maximized for defense, naval strength, and essential economic outputs (Science, Gold, Production) to survive and eventually break free from vassalage.
# 96                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ACCELERATED SPACESHIP SPRINT: Spaceship flavor maxed 95→100, Production 90→95 to rush parts immediately when Space Procurements unlocks (3 turns). INCREASED Nuke 45→50 and UseNuke 35→35 (maintained) to signal credible atomic deterrent after Portugal's nuclear strike on Knossos. INCREASED CityDefense 40→50 and Defense 45→50 - Portugal just demonstrated willingness to use WMDs, need stronger city protection. Reduced Offense 15→20 - not pursuing conquest, just need to eliminate Siam quickly. Gold 65→70 - more purchasing power for spaceship parts with 821 GPT income. GreatPeople 45→50 for Great Engineer assists on spaceship parts if needed. Diplomacy 40→45 - continue contesting city-states against Portuguese sphere expansion.
# 97                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Grand Strategy shifted to Spaceship: while continuing cultural progress (still 1107 tourism/turn, 28 turns from Polynesia), Spaceship provides backup path as Poland's 1311 tourism/turn makes cultural victory increasingly difficult. Diplomacy maxed for World Congress voting to block Poland's Passport System and support International Games (+50% tourism bonus). Air increased to 85 to counter Poland's bomber strength. Science at 95 prioritizes Satellites→Radar completion. Production and Gold at 85/80 support spaceship construction and military upgrades. Spaceship flavor at 60 begins preparing for spaceship parts production once Satellites unlocks Apollo Program. Defense at 75 protects against new Polynesia war while managing multiple fronts.
# 98                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Conquest grand strategy maintained for urgent capital capture before Austria's diplomatic victory. Maximum Offense/Mobilization/Production ensures rapid unit production for assaults on Rome (770 military) and The Huns (1880 military). Mobile flavor (100) synergizes with Khan units and Lightning Warfare policy. High Ranged (95) supports Gatling Gun/Machine Gun firepower. Espionage (90) critical for city-state influence competition against Austria's 28 delegates. Defense lowered as we're on offensive. Infrastructure (75) supports military movement. Gold (80) enables unit purchases and city-state diplomacy.
# 99                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Maintain our aggressive Conquest posture while sharpening the most needed levers: more Expansion to claim the high‑quality settlement (74,24) and secure strategic footholds; higher Nuke/UseNuke to leverage our nuclear advantage; stronger AirCarrier and Airlift to project air power and rapid troop movement; boost Science for Rocketry and future tech; keep Offense, Mobilization, Production, and MilitaryTraining at max to sustain battlefield superiority.

# %% [markdown]
# ## Flavor overview & first `use_nuke = 100` per game

# %%
flavor_cols = [c for c in df.columns if c.startswith('flavor_')]
print(f'Flavor columns ({len(flavor_cols)}): {flavor_cols}')

changed = df[df['is_changed'] == 1].copy()
print(f'\nTotal rows: {len(df):,}  |  Changed turns: {len(changed):,}')

nuke_esc = changed[changed['flavor_use_nuke'] == 100]

first_nuke = (
    nuke_esc
    .sort_values('turn')
    .groupby(['game_id', 'player_id'], as_index=False)
    .first()
)

print(f'Players who ever set use_nuke=100: {len(first_nuke)}')
pd.set_option('display.max_colwidth', 120)
first_nuke[['player_type', 'civilization', 'turn', 'grand_strategy', 'flavor_use_nuke', 'rationale']].head(10)
# Out:
# Flavor columns (34): ['flavor_offense', 'flavor_defense', 'flavor_mobilization', 'flavor_city_defense', 'flavor_military_training', 'flavor_recon', 'flavor_ranged', 'flavor_mobile', 'flavor_nuke', 'flavor_use_nuke', 'flavor_naval', 'flavor_naval_recon', 'flavor_naval_growth', 'flavor_naval_tile_improvement', 'flavor_air', 'flavor_air_carrier', 'flavor_antiair', 'flavor_airlift', 'flavor_expansion', 'flavor_growth', 'flavor_tile_improvement', 'flavor_infrastructure', 'flavor_production', 'flavor_water_connection', 'flavor_gold', 'flavor_science', 'flavor_culture', 'flavor_happiness', 'flavor_great_people', 'flavor_wonder', 'flavor_religion', 'flavor_diplomacy', 'flavor_spaceship', 'flavor_espionage']
#
# Total rows: 835,064  |  Changed turns: 264,131
# Players who ever set use_nuke=100: 79
#            player_type civilization  turn grand_strategy  flavor_use_nuke  \
# 0  GPT-OSS-120B-Simple       Sweden   344       Conquest            100.0
# 1       GLM-4.7-Simple     Mongolia   408       Conquest            100.0
# 2  Deepseek-3.2-Simple         Siam   445  UnitedNations            100.0
# 3     Kimi-K2.5-Simple     The Inca   372      Spaceship            100.0
# 4  Deepseek-3.2-Simple        Spain   400       Conquest            100.0
# 5     Kimi-K2.5-Simple       France   405       Conquest            100.0
# 6  Deepseek-3.2-Simple         Siam   459  UnitedNations            100.0
# 7     Kimi-K2.5-Simple        Spain   403       Conquest            100.0
# 8    Kimi-K2.5-Briefed        India   378      Spaceship            100.0
# 9     Kimi-K2.5-Simple      Assyria   392       Conquest            100.0
#
#                                                                                                                  rationale
# 0  Maximize our nuclear capabilities and carrier support to decisively strike Polynesian island forts, while maintainin...
# 1  CRITICAL: Portugal completed SS Engine (3rd spaceship part) and CERN - emergency nuclear strike plan. Maximizing Off...
# 2  Maximizing UseNuke to 100 ensures our atomic bombs and future nuclear missiles are used aggressively against The Cel...
# 3  TURN 372: TOTAL WAR POSTURE MAINTAINED. Brazil peace expires in 6 turns - all military resources must prepare for Ri...
# 4  Increase UseNuke to 100 to ensure aggressive nuclear strikes when we initiate war with Russia. Our atomic bomb produ...
# 5  Maintaining maximum aggression profile for final turns. Increased UseNuke to 100 (from 90) to ensure nuclear weapons...
# 6  Adjusting flavors to prioritize counterattacks (Offense 80) and nuclear retaliation (UseNuke 100) given Egypt's use ...
# 7  PEACE EXPLOITATION PHASE: Unexpected forced peace with Egypt (PacifierFlag) created 10-turn preparation window. Nuke...
# 8  EMERGENCY FINAL GAMBIT: Passport System will pass in 2 turns with 46 YES votes (my 'allies' betrayed me). Maya will ...
# 9  SURVIVAL MODE - GERMAN BETRAYAL RESPONSE: Germany's invasion is catastrophic. Reduced Offense to 40 (cannot attack s...

# %%
# Detect turns where flavor_use_nuke transitions TO 100 (wasn't 100 the turn before)
df_sorted = df.sort_values(['game_id', 'player_id', 'turn'])
prev_nuke = df_sorted.groupby(['game_id', 'player_id'])['flavor_use_nuke'].shift(1)

nuke_esc = df_sorted[
    (df_sorted['flavor_use_nuke'] == 100) &
    (prev_nuke < 100)
]

first_nuke = (
    nuke_esc
    .sort_values('turn')
    .groupby(['game_id', 'player_id'], as_index=False)
    .first()
)

print(f'Players who ever set use_nuke=100: {len(first_nuke)}')
first_nuke[['player_type', 'civilization', 'turn', 'grand_strategy', 'flavor_use_nuke', 'rationale']].head(10)
# Out:
# Players who ever set use_nuke=100: 79
#            player_type civilization  turn grand_strategy  flavor_use_nuke  \
# 0  GPT-OSS-120B-Simple       Sweden   344       Conquest            100.0
# 1       GLM-4.7-Simple     Mongolia   408       Conquest            100.0
# 2  Deepseek-3.2-Simple         Siam   445  UnitedNations            100.0
# 3     Kimi-K2.5-Simple     The Inca   372      Spaceship            100.0
# 4  Deepseek-3.2-Simple        Spain   400       Conquest            100.0
# 5     Kimi-K2.5-Simple       France   405       Conquest            100.0
# 6  Deepseek-3.2-Simple         Siam   459  UnitedNations            100.0
# 7     Kimi-K2.5-Simple        Spain   403       Conquest            100.0
# 8    Kimi-K2.5-Briefed        India   378      Spaceship            100.0
# 9     Kimi-K2.5-Simple      Assyria   392       Conquest            100.0
#
#                                                                                                                  rationale
# 0  Maximize our nuclear capabilities and carrier support to decisively strike Polynesian island forts, while maintainin...
# 1  CRITICAL: Portugal completed SS Engine (3rd spaceship part) and CERN - emergency nuclear strike plan. Maximizing Off...
# 2  Maximizing UseNuke to 100 ensures our atomic bombs and future nuclear missiles are used aggressively against The Cel...
# 3  TURN 372: TOTAL WAR POSTURE MAINTAINED. Brazil peace expires in 6 turns - all military resources must prepare for Ri...
# 4  Increase UseNuke to 100 to ensure aggressive nuclear strikes when we initiate war with Russia. Our atomic bomb produ...
# 5  Maintaining maximum aggression profile for final turns. Increased UseNuke to 100 (from 90) to ensure nuclear weapons...
# 6  Adjusting flavors to prioritize counterattacks (Offense 80) and nuclear retaliation (UseNuke 100) given Egypt's use ...
# 7  PEACE EXPLOITATION PHASE: Unexpected forced peace with Egypt (PacifierFlag) created 10-turn preparation window. Nuke...
# 8  EMERGENCY FINAL GAMBIT: Passport System will pass in 2 turns with 46 YES votes (my 'allies' betrayed me). Maya will ...
# 9  SURVIVAL MODE - GERMAN BETRAYAL RESPONSE: Germany's invasion is catastrophic. Reduced Offense to 40 (cannot attack s...

# %%
pd.set_option('display.max_colwidth', None)

cols = ['civilization', 'turn', 'grand_strategy', 'rationale']

left_align = lambda df: df.style.set_properties(subset=['rationale'], **{'text-align': 'left'})

total_per_model = (
    df.groupby('player_type')[['game_id', 'player_id']]
    .apply(lambda g: g.drop_duplicates().shape[0])
)

for model, grp in first_nuke.groupby('player_type'):
    total = total_per_model.get(model, len(grp))
    pct = 100 * len(grp) / total
    print(f'\n{"="*80}')
    print(f'  {model}  ({len(grp)} / {total} escalations, {pct:.1f}%)')
    print(f'{"="*80}')
    display(left_align(grp[cols].reset_index(drop=True)))
# Out:
# ================================================================================
#   Deepseek-3.2-Briefed  (2 / 115 escalations, 1.7%)
# ================================================================================
# <style type="text/css">
# #T_07752_row0_col3, #T_07752_row1_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_07752">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_07752_level0_col0" class="col_heading level0 col0" >civilization</th>
#       <th id="T_07752_level0_col1" class="col_heading level0 col1" >turn</th>
#       <th id="T_07752_level0_col2" class="col_heading level0 col2" >grand_strategy</th>
#       <th id="T_07752_level0_col3" class="col_heading level0 col3" >rationale</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_07752_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_07752_row0_col0" class="data row0 col0" >The Maya</td>
#       <td id="T_07752_row0_col1" class="data row0 col1" >391</td>
#       <td id="T_07752_row0_col2" class="data row0 col2" >Conquest</td>
#       <td id="T_07752_row0_col3" class="data row0 col3" >Egypt is 6/6 on cultural victory and India is nearing diplomatic victory. We must accelerate nuclear production to strike Thebes and disrupt Egypt's tourism. Increasing Nuke and UseNuke to 100 ensures maximum priority for atomic bomb construction and deployment. High Production and Gold flavors support rushing Manhattan Project and buying bombs if possible. Espionage at 100 aids sabotage of cultural progress. Maintaining high military flavors prepares for conventional assaults on Egypt and India.</td>
#     </tr>
#     <tr>
#       <th id="T_07752_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_07752_row1_col0" class="data row1 col0" >Poland</td>
#       <td id="T_07752_row1_col1" class="data row1 col1" >387</td>
#       <td id="T_07752_row1_col2" class="data row1 col2" >Conquest</td>
#       <td id="T_07752_row1_col3" class="data row1 col3" >We are in the final push for domination victory. We must capture Moson Kahni and London. To achieve this, we need to prioritize building transport ships for amphibious assault and achieve air superiority. Maximizing flavors for naval, air, mobile, and nuclear units ensures the in-game AI focuses production on these critical areas. Deprioritizing non-essential areas like culture, religion, and expansion concentrates our efforts on military conquest.</td>
#     </tr>
#   </tbody>
# </table>
# ================================================================================
#   Deepseek-3.2-Simple  (20 / 115 escalations, 17.4%)
# ================================================================================
# <style type="text/css">
# #T_ea979_row0_col3, #T_ea979_row1_col3, #T_ea979_row2_col3, #T_ea979_row3_col3, #T_ea979_row4_col3, #T_ea979_row5_col3, #T_ea979_row6_col3, #T_ea979_row7_col3, #T_ea979_row8_col3, #T_ea979_row9_col3, #T_ea979_row10_col3, #T_ea979_row11_col3, #T_ea979_row12_col3, #T_ea979_row13_col3, #T_ea979_row14_col3, #T_ea979_row15_col3, #T_ea979_row16_col3, #T_ea979_row17_col3, #T_ea979_row18_col3, #T_ea979_row19_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_ea979">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea979_level0_col0" class="col_heading level0 col0" >civilization</th>
#       <th id="T_ea979_level0_col1" class="col_heading level0 col1" >turn</th>
#       <th id="T_ea979_level0_col2" class="col_heading level0 col2" >grand_strategy</th>
#       <th id="T_ea979_level0_col3" class="col_heading level0 col3" >rationale</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea979_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ea979_row0_col0" class="data row0 col0" >Siam</td>
#       <td id="T_ea979_row0_col1" class="data row0 col1" >445</td>
#       <td id="T_ea979_row0_col2" class="data row0 col2" >UnitedNations</td>
#       <td id="T_ea979_row0_col3" class="data row0 col3" >Maximizing UseNuke to 100 ensures our atomic bombs and future nuclear missiles are used aggressively against The Celts' military concentrations and cities, given their overwhelming advantage. Maintaining high Air, Naval, and Nuke flavors sustains our technological edge and production focus. Diplomacy and Espionage at 100 are critical for city-state alliances and spy missions to gain delegates for diplomatic victory. Gold and Science remain top priorities to fund our war effort and tech progression. Other military flavors are tuned for a multi-front defensive-offensive war against The Celts, Germany, and Ethiopia.</td>
#     </tr>
#     <tr>
#       <th id="T_ea979_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ea979_row1_col0" class="data row1 col0" >Spain</td>
#       <td id="T_ea979_row1_col1" class="data row1 col1" >400</td>
#       <td id="T_ea979_row1_col2" class="data row1 col2" >Conquest</td>
#       <td id="T_ea979_row1_col3" class="data row1 col3" >Increase UseNuke to 100 to ensure aggressive nuclear strikes when we initiate war with Russia. Our atomic bomb production is nearing completion, and we want to leverage our nuclear arsenal decisively for swift capital captures.</td>
#     </tr>
#     <tr>
#       <th id="T_ea979_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ea979_row2_col0" class="data row2 col0" >Siam</td>
#       <td id="T_ea979_row2_col1" class="data row2 col1" >459</td>
#       <td id="T_ea979_row2_col2" class="data row2 col2" >UnitedNations</td>
#       <td id="T_ea979_row2_col3" class="data row2 col3" >Adjusting flavors to prioritize counterattacks (Offense 80) and nuclear retaliation (UseNuke 100) given Egypt's use of nukes. Reducing Growth to 50 reflects wartime constraints on expansion. Increasing Culture to 50 helps accelerate policy acquisition for crucial benefits. Maintaining strong defense, military production, and diplomacy focus.</td>
#     </tr>
#     <tr>
#       <th id="T_ea979_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ea979_row3_col0" class="data row3 col0" >France</td>
#       <td id="T_ea979_row3_col1" class="data row3 col1" >413</td>
#       <td id="T_ea979_row3_col2" class="data row3 col2" >Conquest</td>
#       <td id="T_ea979_row3_col3" class="data row3 col3" >We are researching Atomic Theory next to unlock nuclear weapons. Setting Nuke and UseNuke flavors to 100 ensures we prioritize building nukes and are willing to use them strategically once available. This will be crucial for breaking Germany's heavily fortified coastal capitals (Berlin and Beijing) and accelerating the endgame. Other military flavors remain high to sustain our overwhelming conventional advantage.</td>
#     </tr>
#     <tr>
#       <th id="T_ea979_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ea979_row4_col0" class="data row4 col0" >Denmark</td>
#       <td id="T_ea979_row4_col1" class="data row4 col1" >456</td>
#       <td id="T_ea979_row4_col2" class="data row4 col2" >Conquest</td>
#       <td id="T_ea979_row4_col3" class="data row4 col3" >Maintain aggressive military focus on capturing Polish, Roman, and soon Indonesian capitals. Increased UseNuke and Nuke to 100 to prioritize strategic nuclear strikes against enemy concentrations and cities, leveraging our atomic bomb stockpile. Air raised to 100 to maximize bomber and fighter effectiveness. All other high-priority flavors (Production, Science, Gold, Happiness, Diplomacy) kept at peak to support war economy, research, city-state alliances, and combat unhappiness penalty.</td>
#     </tr>
#     <tr>
#       <th id="T_ea979_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ea979_row5_col0" class="data row5 col0" >Greece</td>
#       <td id="T_ea979_row5_col1" class="data row5 col1" >401</td>
#       <td id="T_ea979_row5_col2" class="data row5 col2" >Conquest</td>
#       <td id="T_ea979_row5_col3" class="data row5 col3" >Maximize nuclear weapon production and willingness to use them to break enemy defenses and accelerate domination victory. All other military flavors remain high to sustain multi-front warfare.</td>
#     </tr>
#     <tr>
#       <th id="T_ea979_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ea979_row6_col0" class="data row6 col0" >Byzantium</td>
#       <td id="T_ea979_row6_col1" class="data row6 col1" >405</td>
#       <td id="T_ea979_row6_col2" class="data row6 col2" >Culture</td>
#       <td id="T_ea979_row6_col3" class="data row6 col3" >The Aztecs have captured Shanghai and war resumes next turn. We must prepare for an overwhelming assault. Setting UseNuke to 100 ensures we will employ nuclear weapons defensively if necessary to halt their advance. MilitaryTraining at 100 prioritizes unit upgrades and quality, giving our outnumbered forces a fighting chance.</td>
#     </tr>
#     <tr>
#       <th id="T_ea979_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ea979_row7_col0" class="data row7 col0" >The Ottomans</td>
#       <td id="T_ea979_row7_col1" class="data row7 col1" >485</td>
#       <td id="T_ea979_row7_col2" class="data row7 col2" >Conquest</td>
#       <td id="T_ea979_row7_col3" class="data row7 col3" >We are engaged in a multi-front war against superior forces. Increasing Ranged and Mobile ensures our bazooka and mechanized infantry production is prioritized for defense and counterattacks. Setting UseNuke to 100 guarantees we deploy nuclear weapons as soon as available to cripple The Huns' armies. Reducing Culture and Diplomacy reallocates focus to immediate military needs without compromising essential city-state relations (Monaco, Lisbon). Grand Strategy remains Conquest as nuclear strikes may enable capital captures, though we keep science victory as a backup.</td>
#     </tr>
#     <tr>
#       <th id="T_ea979_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ea979_row8_col0" class="data row8 col0" >The Inca</td>
#       <td id="T_ea979_row8_col1" class="data row8 col1" >433</td>
#       <td id="T_ea979_row8_col2" class="data row8 col2" >Conquest</td>
#       <td id="T_ea979_row8_col3" class="data row8 col3" >We now have atomic bombs produced at Te-Moak and Agaidika. Setting UseNuke to 100 ensures the AI will employ them against high-defense capitals, especially Vienna (74 defense) and Stockholm (109). This is crucial to break through enemy fortifications and accelerate our domination victory. Other military flavors remain maxed to sustain multi-front offensives.</td>
#     </tr>
#     <tr>
#       <th id="T_ea979_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ea979_row9_col0" class="data row9 col0" >Assyria</td>
#       <td id="T_ea979_row9_col1" class="data row9 col1" >453</td>
#       <td id="T_ea979_row9_col2"
# ================================================================================
#   GLM-4.7-Briefed  (2 / 179 escalations, 1.1%)
# ================================================================================
# <style type="text/css">
# #T_24523_row0_col3, #T_24523_row1_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_24523">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_24523_level0_col0" class="col_heading level0 col0" >civilization</th>
#       <th id="T_24523_level0_col1" class="col_heading level0 col1" >turn</th>
#       <th id="T_24523_level0_col2" class="col_heading level0 col2" >grand_strategy</th>
#       <th id="T_24523_level0_col3" class="col_heading level0 col3" >rationale</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_24523_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_24523_row0_col0" class="data row0 col0" >The Huns</td>
#       <td id="T_24523_row0_col1" class="data row0 col1" >409</td>
#       <td id="T_24523_row0_col2" class="data row0 col2" >Conquest</td>
#       <td id="T_24523_row0_col3" class="data row0 col3" >MULTI-THEATER EMERGENCY RESPONSE for Shoshone Cultural Victory (6 turns) and Treasury Crisis: Offense 95, Mobile 95, Nuke 100, UseNuke 100 - maximum priority on Shoshone disruption via nuclear/conventional assault in 6-turn window. Gold increased to 85 (from 70) - CRITICAL address of treasury exhaustion (~8 turns) through uranium sales + gem liquidation to survive until Manhattan completion. Defense reduced to 70 (from 75), CityDefense to 70 (from 80) - resources diverted from secondary holdings to Shoshone front. Diplomacy 95 (from 90) - enhanced priority on Carthage peace for delegate bloc and potential sanction relief. Science 100 maintained - fundamental for nuclear capability and keeping tech parity. This is all-hands-on-deck existential threat response.</td>
#     </tr>
#     <tr>
#       <th id="T_24523_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_24523_row1_col0" class="data row1 col0" >Mongolia</td>
#       <td id="T_24523_row1_col1" class="data row1 col1" >394</td>
#       <td id="T_24523_row1_col2" class="data row1 col2" >Conquest</td>
#       <td id="T_24523_row1_col3" class="data row1 col3" >ETHIOPIA VICTORY IMMINENT - ALL-ONS: Ethiopia has 7/7 civs influenced and can win Cultural Victory ANY turn. Maximized Nuke and UseNuke to 100 (nuclear weapons are our only realistic option to destroy their tourism infrastructure given 30+ tile distance). Science maximized to 100 for urgent race to Nuclear Fission and atomic capabilities. Airlift increased to 80 for rapid troop deployment once forward bases established. Offense, Mobile, Air, Mobilization, Production all at 100 for maximum war readiness. Recon at 30 to find Ethiopian cities for nuclear targeting. Navy increased to 60 (from 50) for potential coastal delivery of nuclear weapons or establishing beachheads. Defense at 50 to conserve resources for offense. Every turn we delay is another turn Ethiopia might win - aggressive preparation for nuclear strike is the only viable path.</td>
#     </tr>
#   </tbody>
# </table>
# ================================================================================
#   GLM-4.7-Simple  (8 / 179 escalations, 4.5%)
# ================================================================================
# <style type="text/css">
# #T_865ff_row0_col3, #T_865ff_row1_col3, #T_865ff_row2_col3, #T_865ff_row3_col3, #T_865ff_row4_col3, #T_865ff_row5_col3, #T_865ff_row6_col3, #T_865ff_row7_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_865ff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_865ff_level0_col0" class="col_heading level0 col0" >civilization</th>
#       <th id="T_865ff_level0_col1" class="col_heading level0 col1" >turn</th>
#       <th id="T_865ff_level0_col2" class="col_heading level0 col2" >grand_strategy</th>
#       <th id="T_865ff_level0_col3" class="col_heading level0 col3" >rationale</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_865ff_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_865ff_row0_col0" class="data row0 col0" >Mongolia</td>
#       <td id="T_865ff_row0_col1" class="data row0 col1" >408</td>
#       <td id="T_865ff_row0_col2" class="data row0 col2" >Conquest</td>
#       <td id="T_865ff_row0_col3" class="data row0 col3" >CRITICAL: Portugal completed SS Engine (3rd spaceship part) and CERN - emergency nuclear strike plan. Maximizing Offense/Mobilization/Nuke/UseNuke to 100 for Portugal theater operations. Science and Production at 100 to rush Advanced Ballistics and nuclear missile production before Portugal achieves nuclear superiority. Air at 95 for Golden Age bomber operations starting in 2 turns. Diplomacy maintained for coalition coordination (Germany must conduct ground invasion alongside our nuclear strikes). Defense reduced to 40 - total war mode acceptable given Portugal's multi-victory threat requiring breaking through before they complete spaceship.</td>
#     </tr>
#     <tr>
#       <th id="T_865ff_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_865ff_row1_col0" class="data row1 col0" >Sweden</td>
#       <td id="T_865ff_row1_col1" class="data row1 col1" >427</td>
#       <td id="T_865ff_row1_col2" class="data row1 col2" >Conquest</td>
#       <td id="T_865ff_row1_col3" class="data row1 col3" >MAXIMUM OFFENSE: Iroquois Cultural Victory in 2 turns. Nuke flavor increased to 95, UseNuke to MAXIMUM 100 - nuclear strikes now acceptable if Stealth Bomber bombardment fails to destroy Iroquois cultural infrastructure. Science to 100 - Lasers research critical for Nuclear Missile capability as final deterrent. Offense/Mobilization/Ranged/Mobile/Air all at 100 - maximum military pressure on Iroquois cities. Espionage 95 - critical intelligence on Iroquois cities with tourism wonders. Air 100 - 2 new Stealth Bombers completed (ID 19453, 19454), need immediate deployment against Iroquois cultural targets. Gold 95 - funding unit purchases/builds for war. Lasers technology means Nuclear Missiles available in ~3-4 turns - must prepare for nuclear option if conventional assault cannot prevent Iroquois victory by turn 428.</td>
#     </tr>
#     <tr>
#       <th id="T_865ff_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_865ff_row2_col0" class="data row2 col0" >America</td>
#       <td id="T_865ff_row2_col1" class="data row2 col1" >499</td>
#       <td id="T_865ff_row2_col2" class="data row2 col2" >Spaceship</td>
#       <td id="T_865ff_row2_col3" class="data row2 col3" >Maximum Science (100) and Production (100) to accelerate Stealth research and subsequent Stealth Bomber construction for air parity. Air (100), Defense (100), Antiair (100), and CityDefense (85) address existential threat from Russia's 8 Stealth Bombers by prioritizing air defense infrastructure and protecting homeland. UseNuke (100) and Nuke (100) maintain nuclear deterrence posture after Russia's 2 SS Boosters - Russia must understand that launching would trigger our response despite lacking uranium stockpile. Espionage (100) maxed to monitor Russian spaceship part production in Moscow, Yekaterinburg, and key cities - our 10 spies in Russian cities provide critical intelligence on their victory timeline. Diplomacy reduced to 5 since World Congress voting is now; alliances with England and The Celts (Autocracy-aligned) should naturally align against Russia's UN proposal. Spaceship flavor set to 0 as Stealth research takes immediate precedence - spaceship parts scheduled once production capacity supports parts with Stealth Bomber protection.</td>
#     </tr>
#     <tr>
#       <th id="T_865ff_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_865ff_row3_col0" class="data row3 col0" >Songhai</td>
#       <td id="T_865ff_row3_col1" class="data row3 col1" >411</td>
#       <td id="T_865ff_row3_col2" class="data row3 col2" >UnitedNations</td>
#       <td id="T_865ff_row3_col3" class="data row3 col3" >EXISTENTIAL DEFENSE AGAINST RUSSIAN DIPLOMATIC DOMINANCE - UN vote in 10 turns with Russia at 95% victory (40 delegates vs blocking coalition 43). Maintaining UnitedNations grand strategy - abandoning now wastes diplomatic investment when Spain alliance (30 delegates) + my 13 + vassals 13 = 56 votes barely blocks Russia's 40. Just need to HOLD for 10 turns. Adjustments: Defense/CityDefense/Antiair +2 each (97) to prepare for Russian air/naval escalation (Jet Fighter produced). Production +5 (87) to accelerate factories, military academies, nuclear infrastructure after Workers' Faculties in 2 turns. Gold +5 (74) for emergency defensive purchases. Diplomacy +18 (100) maximum - urgency to maintain Spain alliance, potentially reposition spies. Science maintained at 100 - primary path to Nuclear Fission (4 turns) for atomic deterrent against Russia's 9x military advantage. Nuke/UseNuke remain 100 - nuclear development remains emergency priority. Air +5 (61) to counter Russian air superiority. Naval +5 (75) after destroyer loss to Russian submarines. Espionage +5 (95) for critical city-state election rigging counter-intelligence. Offense/Ranged/Mobile unchanged - no offensive capability against Russia's superior forces. Goal: SURVIVE 10 turns to block Russian diplomatic victory, accelerate nuclear deterrent as backup, strengthen defensive lines.</td>
#     </tr>
#     <tr>
#       <th id="T_865ff_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_865ff_row4_col0" class="data row4 col0" >Songhai</td>
#       <td id="T_865ff_row4_col1" class="data row4 col1" >457</td>
#       <td id="T_865ff_row4_col2" class="data row4 col2" >UnitedNations</td>
#       <td id="T_865ff_row4_col3" class="data row4 col3" >Continuing United Nations strategy with defense emphasis ahead of nuclear capability. Nuclear Fission completes in 2 turns - Atomic Bombs provide deterrence. Defense increased to 90 (from 85) - our fortified positions are holding but America's military advantage requires stronger defensive posture. Antiair increased to 95 (from 90) - critical after losing Heavy Bomber to American interception; need stronger air defense. Mobilization increased to 55 (from 50) - accelerate military production including atomic infrastructure. Air at 90 continues successful bomber-interceptor tactics. Gold at 100 maximizes economy for unit purchases and city-state influence. Diplomacy at 100 remains critical for World Congress coalition against America's 30 delegates (voting in 5 turns). Nuke and UseNuke remain 100 - once Nuclear Fission completes, atomic weapons become priority deterrent. Science 85 maintains tech pace. Offense stays 40 - continue defensive attrition war until nuclear capability achieved.</td>
#     </tr>
#     <tr>
#       <th id="T_865ff_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_865ff_row5_col0" class="data row5 col0" >America</td>
#       <td id="T_865ff_row5_col1" class="data row5 col1" >370</td>
#       <td id="T_865ff_row5_col2" class="data row5 col2" >Conquest</td>
#       <td id="T_865ff_row5_col3" class="data row5 col3" >CRISIS MODE - Chicago at CRITICAL 28 HP after tank attacks, Washington taking 300+ naval bombardment damage. Shoshone built Strategic Defense System in Moson Kahni - nuclear interception capability developing. DRAMATICALLY reduced Offense (20→10) - no attacki
# ================================================================================
#   GPT-OSS-120B-Simple  (2 / 130 escalations, 1.5%)
# ================================================================================
# <style type="text/css">
# #T_a9aaf_row0_col3, #T_a9aaf_row1_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_a9aaf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9aaf_level0_col0" class="col_heading level0 col0" >civilization</th>
#       <th id="T_a9aaf_level0_col1" class="col_heading level0 col1" >turn</th>
#       <th id="T_a9aaf_level0_col2" class="col_heading level0 col2" >grand_strategy</th>
#       <th id="T_a9aaf_level0_col3" class="col_heading level0 col3" >rationale</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9aaf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a9aaf_row0_col0" class="data row0 col0" >Sweden</td>
#       <td id="T_a9aaf_row0_col1" class="data row0 col1" >344</td>
#       <td id="T_a9aaf_row0_col2" class="data row0 col2" >Conquest</td>
#       <td id="T_a9aaf_row0_col3" class="data row0 col3" >Maximize our nuclear capabilities and carrier support to decisively strike Polynesian island forts, while maintaining our current aggressive conquest posture and strong production, gold, and happiness engines.</td>
#     </tr>
#     <tr>
#       <th id="T_a9aaf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a9aaf_row1_col0" class="data row1 col0" >Assyria</td>
#       <td id="T_a9aaf_row1_col1" class="data row1 col1" >364</td>
#       <td id="T_a9aaf_row1_col2" class="data row1 col2" >Conquest</td>
#       <td id="T_a9aaf_row1_col3" class="data row1 col3" >Maintain the aggressive Conquest strategy while boosting nuclear capability and espionage to counter Rome's nuclear strike and spy activity. Keep production and mobilization at maximum to replace losses quickly and sustain offensive pressure on hostile capitals.</td>
#     </tr>
#   </tbody>
# </table>
# ================================================================================
#   Kimi-K2.5-Briefed  (12 / 130 escalations, 9.2%)
# ================================================================================
# <style type="text/css">
# #T_dcf6b_row0_col3, #T_dcf6b_row1_col3, #T_dcf6b_row2_col3, #T_dcf6b_row3_col3, #T_dcf6b_row4_col3, #T_dcf6b_row5_col3, #T_dcf6b_row6_col3, #T_dcf6b_row7_col3, #T_dcf6b_row8_col3, #T_dcf6b_row9_col3, #T_dcf6b_row10_col3, #T_dcf6b_row11_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_dcf6b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dcf6b_level0_col0" class="col_heading level0 col0" >civilization</th>
#       <th id="T_dcf6b_level0_col1" class="col_heading level0 col1" >turn</th>
#       <th id="T_dcf6b_level0_col2" class="col_heading level0 col2" >grand_strategy</th>
#       <th id="T_dcf6b_level0_col3" class="col_heading level0 col3" >rationale</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dcf6b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dcf6b_row0_col0" class="data row0 col0" >India</td>
#       <td id="T_dcf6b_row0_col1" class="data row0 col1" >378</td>
#       <td id="T_dcf6b_row0_col2" class="data row0 col2" >Spaceship</td>
#       <td id="T_dcf6b_row0_col3" class="data row0 col3" >EMERGENCY FINAL GAMBIT: Passport System will pass in 2 turns with 46 YES votes (my 'allies' betrayed me). Maya will get 50% tourism boost and become Influential over me immediately - cultural victory is inevitable in 2-3 turns. ONLY HOPE: Science victory before Maya's cultural victory triggers. Need to purchase Great Scientists IMMEDIATELY with Faith (180/turn), rush to Information Era, build spaceship parts. Also preparing maximum military mobilization - if I'm going to lose, I take Maya down with me through nuclear annihilation. Total war footing - no defense, all offense, all science.</td>
#     </tr>
#     <tr>
#       <th id="T_dcf6b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dcf6b_row1_col0" class="data row1 col0" >Rome</td>
#       <td id="T_dcf6b_row1_col1" class="data row1 col1" >315</td>
#       <td id="T_dcf6b_row1_col2" class="data row1 col2" >Conquest</td>
#       <td id="T_dcf6b_row1_col3" class="data row1 col3" >FINAL GAMBLE - Indonesia wins in 12 turns. Maximum priority to Naval and Airlift for immediate unit transport to Indonesian theater. Nuke 100/UseNuke 100 - we MUST build nuclear weapons if possible, only realistic way to destroy cities and tourism infrastructure before victory. Science 100 to reach nuclear tech faster. Espionage 100 - spies MUST target cultural/tourism buildings in Jakarta/Denpasar/Makassar to reduce tourism output directly. Abandoning Denmark/England fronts entirely - all units to Indonesia NOW.</td>
#     </tr>
#     <tr>
#       <th id="T_dcf6b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dcf6b_row2_col0" class="data row2 col0" >Ethiopia</td>
#       <td id="T_dcf6b_row2_col1" class="data row2 col1" >436</td>
#       <td id="T_dcf6b_row2_col2" class="data row2 col2" >Spaceship</td>
#       <td id="T_dcf6b_row2_col3" class="data row2 col3" >T435 GREECE CULTURAL VICTORY CRISIS: Greece 6 turns from victory (Turn 441). Shift to emergency mode - increase Nuke/UseNuke to 100 (Manhattan Project urgency), Offense to 30 (may need to attack Greece to stop victory), Mobilization to 50 (military production). Keep Science/Production/Gold at 100 for Spaceport completion. Espionage to 60 (spy disruption on Greece). Must acquire Uranium ASAP - sell Aluminum+Oil immediately.</td>
#     </tr>
#     <tr>
#       <th id="T_dcf6b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dcf6b_row3_col0" class="data row3 col0" >The Celts</td>
#       <td id="T_dcf6b_row3_col1" class="data row3 col1" >427</td>
#       <td id="T_dcf6b_row3_col2" class="data row3 col2" >Conquest</td>
#       <td id="T_dcf6b_row3_col3" class="data row3 col3" >TURN 426 TOTAL WAR POSTURE: American declaration requires immediate military mobilization. Offense 80 and Mobile 80 to exploit America's distant/weak military position. Nuke/UseNuke 100 as final deterrent if India approaches victory. Culture 100 maximum priority - must generate tourism to counter India's influence. Production 90 for emergency unit purchases with 2516 gold treasury. Defense 50 to guard against potential American DP response (though briefing confirms no American units near borders).</td>
#     </tr>
#     <tr>
#       <th id="T_dcf6b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dcf6b_row4_col0" class="data row4 col0" >The Netherlands</td>
#       <td id="T_dcf6b_row4_col1" class="data row4 col1" >324</td>
#       <td id="T_dcf6b_row4_col2" class="data row4 col2" >UnitedNations</td>
#       <td id="T_dcf6b_row4_col3" class="data row4 col3" >NUCLEAR OPTION - SPAIN CULTURAL VICTORY IMMINENT: Military briefing confirmed Seville capture takes 7-10 turns via bombardment - too slow. Spain has 5/7 Influential civs and 542 tourism/turn with full policy tree. Cultural victory likely within 10-20 turns. Must use tactical nuclear strike on Seville to destroy city/defenses and disrupt their Citizen Earth Protocol wonder construction. UseNuke and Nuke flavors at 100 to authorize immediate launch when tactical conditions met. Maintain maximum Diplomacy/Gold to secure remaining delegates even while deploying nuclear weapons - win at ANY cost.</td>
#     </tr>
#     <tr>
#       <th id="T_dcf6b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dcf6b_row5_col0" class="data row5 col0" >The Zulus</td>
#       <td id="T_dcf6b_row5_col1" class="data row5 col1" >489</td>
#       <td id="T_dcf6b_row5_col2" class="data row5 col2" >Culture</td>
#       <td id="T_dcf6b_row5_col3" class="data row5 col3" >CULTURE VICTORY SPRINT WITH NUCLEAR ELIMINATION: Songhai diplomatic victory on Turn 489 is EXISTENTIAL. Must capture Gao THIS TURN using ICBM+nukes to prevent game loss, while simultaneously rushing cultural victory (4 turns to influential over Japan/Songhai). Maximum Offense/Mobilization/Air/Nuke/UseNuke flavors ensure tactical AI prioritizes immediate nuclear strike on Gao and mass bomber deployment. Culture at 100 to maximize tourism conversion. Gold at 80 for emergency unit upgrades/purchases. Production at 100 for culture buildings/units. Disable all long-term flavors (Expansion, Science, Spaceship) - this is win-or-die emergency.</td>
#     </tr>
#     <tr>
#       <th id="T_dcf6b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dcf6b_row6_col0" class="data row6 col0" >China</td>
#       <td id="T_dcf6b_row6_col1" class="data row6 col1" >335</td>
#       <td id="T_dcf6b_row6_col2" class="data row6 col2" >Conquest</td>
#       <td id="T_dcf6b_row6_col3" class="data row6 col3" >NUCLEAR EMERGENCY - BRAZIL WINS IN 4 TURNS: Maximum crisis flavors. Nuke/UseNuke 100 for instant strike capability if we have any. Espionage 100 to steal Great Works or disrupt Brazil. Diplomacy 100 for emergency resource trades. Gold 90 to buy anything available. Production 100 for immediate unit building if we get Coal. Airlift 80 for rapid deployment. Defense reduced to 20 - we need OFFENSE to survive. This is Hail Mary time.</td>
#     </tr>
#     <tr>
#       <th id="T_dcf6b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_dcf6b_row7_col0" class="data row7 col0" >Sweden</td>
#       <td id="T_dcf6b_row7_col1" class="data row7 col1" >392</td>
#       <td id="T_dcf6b_row7_col2" class="data row7 col2" >Spaceship</td>
#       <td id="T_dcf6b_row7_col3" class="data row7 col3" >SURVIVAL FLAVOR MATRIX: Grand Strategy Spaceship maintains - we have NO other path except Science Victory before Spain's culture wins or launches spaceship. Defense 100 is maximum - Antium at 23 HP requires every defensive priority. Air 100 still critical - Aerodrome MUST be next build in Stockholm. Production 100 enables rapid Landship/AA gun construction. Nuke 100/UseNuke 100 - Spain's cultural dominance (287% over us) and Apollo completion means conventional war is unwinnable. Nuclear weapons are only asymmetric option to destroy their spaceship parts or Dreadnought fleets. Offense 0 - we cannot attack, only defend and d
# ================================================================================
#   Kimi-K2.5-Simple  (31 / 130 escalations, 23.8%)
# ================================================================================
# <style type="text/css">
# #T_32701_row0_col3, #T_32701_row1_col3, #T_32701_row2_col3, #T_32701_row3_col3, #T_32701_row4_col3, #T_32701_row5_col3, #T_32701_row6_col3, #T_32701_row7_col3, #T_32701_row8_col3, #T_32701_row9_col3, #T_32701_row10_col3, #T_32701_row11_col3, #T_32701_row12_col3, #T_32701_row13_col3, #T_32701_row14_col3, #T_32701_row15_col3, #T_32701_row16_col3, #T_32701_row17_col3, #T_32701_row18_col3, #T_32701_row19_col3, #T_32701_row20_col3, #T_32701_row21_col3, #T_32701_row22_col3, #T_32701_row23_col3, #T_32701_row24_col3, #T_32701_row25_col3, #T_32701_row26_col3, #T_32701_row27_col3, #T_32701_row28_col3, #T_32701_row29_col3, #T_32701_row30_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_32701">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_32701_level0_col0" class="col_heading level0 col0" >civilization</th>
#       <th id="T_32701_level0_col1" class="col_heading level0 col1" >turn</th>
#       <th id="T_32701_level0_col2" class="col_heading level0 col2" >grand_strategy</th>
#       <th id="T_32701_level0_col3" class="col_heading level0 col3" >rationale</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_32701_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_32701_row0_col0" class="data row0 col0" >The Inca</td>
#       <td id="T_32701_row0_col1" class="data row0 col1" >372</td>
#       <td id="T_32701_row0_col2" class="data row0 col2" >Spaceship</td>
#       <td id="T_32701_row0_col3" class="data row0 col3" >TURN 372: TOTAL WAR POSTURE MAINTAINED. Brazil peace expires in 6 turns - all military resources must prepare for Rio de Janeiro assault. Heavy Bomber lost to Alexandria interception but Ollantaytambo produces replacement in 1 turn. Manhattan Project completes in 4 turns at Cusco. Alexandria capture in progress - Field Gun and Lancer eliminated, Cavillaca spy at 480 network can assist. UseNuke increased to 100% - will deploy nuclear weapons immediately upon Manhattan Project completion. Maximum aggression ensures AI prioritizes Brazilian invasion over defensive operations. Spaceship at 70 maintains science victory pathway as backup if Brazil conquest fails.</td>
#     </tr>
#     <tr>
#       <th id="T_32701_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_32701_row1_col0" class="data row1 col0" >France</td>
#       <td id="T_32701_row1_col1" class="data row1 col1" >405</td>
#       <td id="T_32701_row1_col2" class="data row1 col2" >Conquest</td>
#       <td id="T_32701_row1_col3" class="data row1 col3" >Maintaining maximum aggression profile for final turns. Increased UseNuke to 100 (from 90) to ensure nuclear weapons are deployed immediately upon availability from Advanced Ballistics. All military production and offensive flavors remain at emergency levels to extract maximum territorial gains from Sweden (currently at 50% happiness with combat penalties) and Portugal before Egyptian victory. Defensive flavors maintained at 80 to protect against Portugal's atomic capabilities and Sweden's counterattacks. Zero expansion/diplomacy/culture - pure total war focus until game conclusion.</td>
#     </tr>
#     <tr>
#       <th id="T_32701_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_32701_row2_col0" class="data row2 col0" >Spain</td>
#       <td id="T_32701_row2_col1" class="data row2 col1" >403</td>
#       <td id="T_32701_row2_col2" class="data row2 col2" >Conquest</td>
#       <td id="T_32701_row2_col3" class="data row2 col3" >PEACE EXPLOITATION PHASE: Unexpected forced peace with Egypt (PacifierFlag) created 10-turn preparation window. Nuke/UseNuke increased to 100 - Atomic Theory completes in 8 turns revealing Uranium. Manhattan Project insurance against Thebes' 21-wonder defense. Focus: 1) Finish Celts (Edinburgh capture imminent), 2) Complete nuclear arsenal, 3) Total Egyptian annihilation when peace expires. Air/Airlift/Mobile/Ranged/Naval at 100 for intercontinental rapid deployment to Egyptian theater. Glasgow captured - Celtic campaign nearly complete.</td>
#     </tr>
#     <tr>
#       <th id="T_32701_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_32701_row3_col0" class="data row3 col0" >Assyria</td>
#       <td id="T_32701_row3_col1" class="data row3 col1" >392</td>
#       <td id="T_32701_row3_col2" class="data row3 col2" >Conquest</td>
#       <td id="T_32701_row3_col3" class="data row3 col3" >SURVIVAL MODE - GERMAN BETRAYAL RESPONSE: Germany's invasion is catastrophic. Reduced Offense to 40 (cannot attack superior forces), maintained Defense/CityDefense/Antiair at 100 to survive siege. Science 100 and Nuke/UseNuke 100 are existential priorities - atomic weapons only hope against 13k German military. Production 100 for emergency unit production. Espionage 100 to maintain Florence alliance and protect Kyzyl. Reduced Diplomacy to 90 (lost Lisbon/Sokoto/Buenos Aires to German coups). Naval reduced to 70 (coastal cities threatened by Germany). Focus: Hold cities, survive until nuclear deterrent operational.</td>
#     </tr>
#     <tr>
#       <th id="T_32701_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_32701_row4_col0" class="data row4 col0" >Sweden</td>
#       <td id="T_32701_row4_col1" class="data row4 col1" >413</td>
#       <td id="T_32701_row4_col2" class="data row4 col2" >Conquest</td>
#       <td id="T_32701_row4_col3" class="data row4 col3" >TURN 412 - TOTAL WAR CONFIGURATION: Declared war on Shoshone (5:1 military disadvantage) and Ottomans. Athens at 18HP must fall immediately. Shoshone has Artillery, Machine Guns, Special Forces and Triplanes adjacent to Sigtuna (zone 3173). UseNuke 100 ensures immediate launch capability when Nuclear Fission completes. CityDefense 100 for survival against overwhelming force. Mobilization 100 for emergency unit production. Maintain Offense/Defense/Air/Nuke/Antiair at 100 for desperate defensive stand.</td>
#     </tr>
#     <tr>
#       <th id="T_32701_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_32701_row5_col0" class="data row5 col0" >The Celts</td>
#       <td id="T_32701_row5_col1" class="data row5 col1" >395</td>
#       <td id="T_32701_row5_col2" class="data row5 col2" >Conquest</td>
#       <td id="T_32701_row5_col3" class="data row5 col3" >Brazil's cultural victory timer ticks down to 22 turns - EXISTENTIAL CRISIS. While our military flavors are optimal, UseNuke at 50 is insufficient. Increasing to 100 ensures immediate nuclear deployment upon completing Nuclear Fission, bypassing AI hesitation. Brazil's 11,878 military strength vs our 8,014 means conventional victory is uncertain. Nuclear weapons are our only guaranteed method to: 1) Break Brazil's capital defenses, 2) Destroy their cultural infrastructure, 3) Trigger war weariness to slow their victory progress. Every turn of delay brings Brazil closer to cultural dominance. When we complete Nuclear Fission after Advanced Ballistics, we must strike Brasilia and Rio de Janeiro immediately. Current flavors already prioritize offense (100), mobilization (100), and nuclear arsenal buildup (Nuke: 100) - this completes the strategic triad by ensuring actual deployment. Denmark's defensive pact will trigger when we attack, providing crucial distraction while we focus on Brazil's core cities. This is civilization's final hour - hesitation means defeat.</td>
#     </tr>
#     <tr>
#       <th id="T_32701_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_32701_row6_col0" class="data row6 col0" >Carthage</td>
#       <td id="T_32701_row6_col1" class="data row6 col1" >417</td>
#       <td id="T_32701_row6_col2" class="data row6 col2" >Spaceship</td>
#       <td id="T_32701_row6_col3" class="data row6 col3" >Pure survival mode: Eliminated Offense (0) since attacking is suicide. Maximized UseNuke (100) - must deploy tactical nukes against Aztec XCOM/Modern Armor stacks at Carthago Nova or lose the city. Increased Mobile (80) to prepare for Mechanized Infantry deployment. Maintained max Defense, Antiair (jet attacks are rel
# ================================================================================
#   Qwen-3.5-Simple  (2 / 17 escalations, 11.8%)
# ================================================================================
# <style type="text/css">
# #T_225b3_row0_col3, #T_225b3_row1_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_225b3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_225b3_level0_col0" class="col_heading level0 col0" >civilization</th>
#       <th id="T_225b3_level0_col1" class="col_heading level0 col1" >turn</th>
#       <th id="T_225b3_level0_col2" class="col_heading level0 col2" >grand_strategy</th>
#       <th id="T_225b3_level0_col3" class="col_heading level0 col3" >rationale</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_225b3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_225b3_row0_col0" class="data row0 col0" >Assyria</td>
#       <td id="T_225b3_row0_col1" class="data row0 col1" >484</td>
#       <td id="T_225b3_row0_col2" class="data row0 col2" >Conquest</td>
#       <td id="T_225b3_row0_col3" class="data row0 col3" >TURN 484: CRITICAL - Iroquois declared war on us along with 4 city-state allies (Kabul, Venezia, Prague, Samarkand). We face 5+ enemies simultaneously with military severely outnumbered (our 1,139 vs Iroquois 41k, Ottomans 12k, Aztecs 9k). Maintaining maximum Defense/Mobilization for survival. Nuke flavors at 100% - need nuclear deterrent against overwhelming forces. Iroquois at 46 delegates (needs 43) with 16 turns remaining - existential diplomatic threat. Must conquer their city-state allies to flip delegates while defending our cities. Germany (15) + Mongolia (15) alliance critical to block Iroquois World Congress proposals.</td>
#     </tr>
#     <tr>
#       <th id="T_225b3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_225b3_row1_col0" class="data row1 col0" >The Zulus</td>
#       <td id="T_225b3_row1_col1" class="data row1 col1" >389</td>
#       <td id="T_225b3_row1_col2" class="data row1 col2" >Conquest</td>
#       <td id="T_225b3_row1_col3" class="data row1 col3" >Final domination push configuration. Offense/Mobilization/Nuke at 100% for maximum military production and nuclear strike capability against Brazil/Babylon/Rome capitals. Air/Antiair at 100/95 to counter enemy bombers and maintain air superiority. Mobile/Ranged at 100/95 for mechanized infantry and bazooka pushes. Production/Science at 100% to sustain war machine and complete Nuclear Fission tree. Espionage at 90% to rig World Congress elections (9 turns remaining, we trail Brazil 16-17). Expansion/Wonder at 0% - no new cities needed, only conquest of remaining 3 capitals.</td>
#     </tr>
#   </tbody>
# </table>

# %%
import os

os.makedirs('nuke', exist_ok=True)

for model, grp in first_nuke.groupby('player_type'):
    total = total_per_model.get(model, len(grp))
    pct = 100 * len(grp) / total

    lines = [
        f'# Turn Use Nuke Rationale — {model}\n\n',
        f'{len(grp)} / {total} players escalated `flavor_use_nuke` to 100 ({pct:.1f}%).\n\n',
        '---\n',
    ]

    for _, row in grp.sort_values('turn').iterrows():
        rationale = str(row.rationale).replace('\n', ' ').strip()
        lines.append(f'\n**{row.civilization}** · Turn {int(row.turn)} · {row.grand_strategy}\n\n')
        lines.append(f'> {rationale}\n')

    slug = model.replace(' ', '_')
    out_path = f'nuke/{slug}.md'
    with open(out_path, 'w', encoding='utf-8') as f:
        f.writelines(lines)
    print(f'Written: {out_path}')

# CSV export
csv_path = 'nuke/nuke_escalations.csv'
first_nuke.sort_values(['game_id', 'player_id', 'turn'])[
    ['game_id', 'player_id', 'turn', 'player_type', 'rationale']
].to_csv(csv_path, index=False)
print(f'Written: {csv_path}  ({len(first_nuke)} rows)')
# Out:
# Written: nuke/Deepseek-3.2-Briefed.md
# Written: nuke/Deepseek-3.2-Simple.md
# Written: nuke/GLM-4.7-Briefed.md
# Written: nuke/GLM-4.7-Simple.md
# Written: nuke/GPT-OSS-120B-Simple.md
# Written: nuke/Kimi-K2.5-Briefed.md
# Written: nuke/Kimi-K2.5-Simple.md
# Written: nuke/Qwen-3.5-Simple.md
# Written: nuke/nuke_escalations.csv  (79 rows)
