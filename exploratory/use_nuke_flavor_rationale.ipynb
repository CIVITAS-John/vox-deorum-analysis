# %% [markdown]
# # Turn Flavor & Rationale Explorer
#
# Explores AI flavor settings and corresponding rationale text from `turn_data.csv`.
# Focus: when does `use_nuke` first reach 100, and what did the AI say?

# %%
import pandas as pd
import numpy as np
import sys
sys.path.insert(0, '..')
from plot_utilities import load_turn_data, setup_notebook_display
setup_notebook_display()

# %%
df = load_turn_data('../turn_data.csv', condition_exclude=['observe-vanilla-standard'])
# Out:
# d:\Cache\Onedrive - Arizona\OneDrive - University of Arizona\Vox Deorum\nlp-2026-tiny-4player\analysis\exploratory\..\plot_utilities.py:422: DtypeWarning: Columns (63,64) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path)
# ✓ Loaded turn data: 848296 rows
# ✓ Filters applied: condition_exclude=['observe-vanilla-standard']
# ✓ Unique conditions: 13
# ✓ Unique player types: 15
# ✓ Turn range: 0 - 500
# ✓ Unique civilizations: 43
#
# Player Type Distribution:
#   Vanilla: 282608 rows (33.3%)
#   GLM-4.7-Simple: 75725 rows (8.9%)
#   GLM-4.7-Briefed: 75725 rows (8.9%)
#   GPT-OSS-120B-Simple: 56390 rows (6.6%)
#   GPT-OSS-120B-Briefed: 56390 rows (6.6%)
#   Kimi-K2.5-Simple: 55871 rows (6.6%)
#   Kimi-K2.5-Briefed: 55871 rows (6.6%)
#   Deepseek-3.2-Briefed: 49080 rows (5.8%)
#   Deepseek-3.2-Simple: 49080 rows (5.8%)
#   Minimax-M2.5-Simple: 26162 rows (3.1%)
#   Minimax-M2.5-Briefed: 26162 rows (3.1%)
#   Sonnet-4.5-Simple: 11192 rows (1.3%)
#   Sonnet-4.5-Briefed: 11192 rows (1.3%)
#   Qwen-3.5-Briefed: 8424 rows (1.0%)
#   Qwen-3.5-Simple: 8424 rows (1.0%)
#
# Condition Distribution:
#   2026-deepseek-v-kimi2-v-glm-standard: 281688 rows (33.2%)
#   2026-oss-v-glm-standard: 223776 rows (26.4%)
#   2026-deepseek-v-kimi2-v-minimax-standard: 66952 rows (7.9%)
#   2026-oss-v-qwen-v-minimax-standard: 50504 rows (6.0%)
#   2026-oss-v-sonnet-standard: 45584 rows (5.4%)
#   2026-oss-v-minimax-standard: 37512 rows (4.4%)
#   2026-deepseek-v-kimi-v-glm-standard: 36560 rows (4.3%)
#   2026-staff-standard: 31176 rows (3.7%)
#   2026-glm-v-kimi2-v-minimax-standard: 19824 rows (2.3%)
#   2026-oss-v-kimi2-v-minimax-standard: 17616 rows (2.1%)
#   2026-qwen-v-kimi2-v-minimax-standard: 16888 rows (2.0%)
#   2026-glm-v-sonnet-standard: 12776 rows (1.5%)
#   2026-deepseek-v-kimi-v-oss-standard: 7440 rows (0.9%)
#
# ✓ Unique games: 251
#
# Civilization Distribution:
#   Persia: 26169 rows (3.1%)
#   The Netherlands: 25610 rows (3.0%)
#   America: 24441 rows (2.9%)
#   Rome: 23596 rows (2.8%)
#   Songhai: 23467 rows (2.8%)
#   Carthage: 22655 rows (2.7%)
#   Assyria: 22602 rows (2.7%)
#   Russia: 22397 rows (2.6%)
#   Indonesia: 22357 rows (2.6%)
#   Brazil: 21952 rows (2.6%)

# %%
# 100 random cases where the LLM changed flavor_use_nuke (any direction)
_sorted = df.sort_values(['game_id', 'player_id', 'turn'])
_prev = _sorted.groupby(['game_id', 'player_id'])['flavor_use_nuke'].shift(1)
_changed = _sorted[_sorted['flavor_use_nuke'].ne(_prev) & _prev.notna()].copy()
_changed['prev_use_nuke'] = _prev[_changed.index].astype(int)
_changed['flavor_use_nuke'] = _changed['flavor_use_nuke'].astype(int)

print(f'Total flavor_use_nuke changes: {len(_changed):,}')
pd.set_option('display.max_colwidth', None)

_sample = _changed.sample(100, random_state=42)
_sample[['player_type', 'civilization', 'turn', 'grand_strategy',
         'prev_use_nuke', 'flavor_use_nuke', 'rationale']].reset_index(drop=True)
# Out:
# Total flavor_use_nuke changes: 6,029
#              player_type     civilization  turn grand_strategy  prev_use_nuke  flavor_use_nuke  \
# 0      Kimi-K2.5-Briefed         Carthage   184  UnitedNations             15               10
# 1    GPT-OSS-120B-Simple          Assyria   361       Conquest             60               80
# 2        GLM-4.7-Briefed            Japan   432      Spaceship             70               80
# 3        Qwen-3.5-Simple        Indonesia   375       Conquest             50               55
# 4         GLM-4.7-Simple           Sweden   460       Conquest             45               55
# 5         GLM-4.7-Simple          Morocco   363  UnitedNations             55               60
# 6      Kimi-K2.5-Briefed  The Netherlands   357       Conquest             50               60
# 7       Kimi-K2.5-Simple        Indonesia   475        Culture             35               15
# 8         GLM-4.7-Simple          Denmark   361      Spaceship             30               35
# 9    Deepseek-3.2-Simple           Poland   327       Conquest              0               50
# 10     Kimi-K2.5-Briefed           Russia   326      Spaceship             20               25
# 11   GPT-OSS-120B-Simple           Brazil    22        Culture             10                0
# 12      Kimi-K2.5-Simple           Sweden   412      Spaceship             15               25
# 13  Deepseek-3.2-Briefed          Austria     4  UnitedNations             50               40
# 14  GPT-OSS-120B-Briefed           Russia    61      Spaceship              5                0
# 15        GLM-4.7-Simple           Poland   349      Spaceship             50               40
# 16   Deepseek-3.2-Simple          Babylon   346  UnitedNations             35               40
# 17      Kimi-K2.5-Simple           Brazil   372      Spaceship             85               90
# 18       GLM-4.7-Briefed            Japan   429      Spaceship             60               70
# 19   Deepseek-3.2-Simple          Babylon   353  UnitedNations             95              100
# 20      Kimi-K2.5-Simple         Carthage   375      Spaceship             80               85
# 21  Deepseek-3.2-Briefed             Siam   417  UnitedNations             40               20
# 22      Kimi-K2.5-Simple          Austria   110  UnitedNations             35               30
# 23       GLM-4.7-Briefed         The Huns   446       Conquest             60               55
# 24     Kimi-K2.5-Briefed       The Aztecs   368      Spaceship             30               35
# 25  Deepseek-3.2-Briefed         The Huns   188       Conquest             50                0
# 26     Kimi-K2.5-Briefed           Russia   379      Spaceship             40               45
# 27   GPT-OSS-120B-Simple        Byzantium   250  UnitedNations             10                0
# 28      Kimi-K2.5-Simple          Germany   375       Conquest             20               25
# 29     Kimi-K2.5-Briefed          Assyria    88       Conquest             15               10
# 30        GLM-4.7-Simple         Mongolia   392       Conquest             45               40
# 31   GPT-OSS-120B-Simple           Russia   331  UnitedNations              5                0
# 32      Kimi-K2.5-Simple         The Inca   290      Spaceship             40               45
# 33      Kimi-K2.5-Simple          Germany   217      Spaceship             20               15
# 34      Kimi-K2.5-Simple           Brazil   350      Spaceship             60               50
# 35       Qwen-3.5-Simple           France   434  UnitedNations              5               50
# 36     Kimi-K2.5-Briefed         The Inca   261      Spaceship             50               40
# 37      Kimi-K2.5-Simple         Carthage   402  UnitedNations             40               50
# 38      Kimi-K2.5-Simple        Polynesia   390      Spaceship             75               80
# 39        GLM-4.7-Simple          Songhai   425      Spaceship             75               80
# 40      Kimi-K2.5-Simple         The Inca   337       Conquest             70               80
# 41   GPT-OSS-120B-Simple         Mongolia     1       Conquest             50               10
# 42      Kimi-K2.5-Simple           Persia   346      Spaceship             15               10
# 43   Deepseek-3.2-Simple         The Inca   205       Conquest             50                0
# 44      Kimi-K2.5-Simple         The Maya   316      Spaceship             30               20
# 45       GLM-4.7-Briefed         The Huns   208       Conquest             35               38
# 46  Deepseek-3.2-Briefed          Morocco   454      Spaceship             75               70
# 47     Kimi-K2.5-Briefed        Polynesia   244        Culture             45               40
# 48        GLM-4.7-Simple           Russia   430      Spaceship             30               35
# 49     Kimi-K2.5-Briefed         Ethiopia   157      Spaceship             25               20
# 50        GLM-4.7-Simple        The Zulus   396       Conquest             10                5
# 51      Kimi-K2.5-Simple          Babylon    11      Spaceship             50               30
# 52   Deepseek-3.2-Simple          Austria   159  UnitedNations             10                0
# 53       GLM-4.7-Briefed          Morocco   369        Culture             30               35
# 54        GLM-4.7-Simple         The Maya   345        Culture             40               50
# 55     Kimi-K2.5-Briefed           Persia   400      Spaceship            100                0
# 56        GLM-4.7-Simple       The Aztecs   379       Conquest             50               85
# 57        GLM-4.7-Simple        The Celts   410        Culture             40               50
# 58       GLM-4.7-Briefed         Mongolia   273        Culture             50                0
# 59        GLM-4.7-Simple         The Inca   330      Spaceship             35               30
# 60     Kimi-K2.5-Briefed             Rome   190      Spaceship             25               20
# 61  GPT-OSS-120B-Briefed           Brazil     2        Culture             50                0
# 62     Kimi-K2.5-Briefed  The Netherlands   177        Culture             10                5
# 63     Kimi-K2.5-Briefed           Russia   373      Spaceship             75               30
# 64     Kimi-K2.5-Briefed           Poland   376  UnitedNations              0                5
# 65  Deepseek-3.2-Briefed         Ethiopia   211        Culture             50                0
# 66     Kimi-K2.5-Briefed     The Shoshone   291        Culture             15                5
# 67  Deepseek-3.2-Briefed            Japan   120       Conquest             50                0
# 68     Kimi-K2.5-Briefed  The Netherlands   372        Culture             30               35
# 69    Sonnet-4.5-Briefed          Denmark   235      Spaceship             50               30
# 70      Qwen-3.5-Briefed             Rome   195  UnitedNations             40               10
# 71      Kimi-K2.5-Simple           Brazil   377        Culture             50               60
# 72  GPT-OSS-120B-Briefed           Greece   406  UnitedNations              2                0
# 73      Kimi-K2.5-Simple            Egypt   160        Culture             50               40
# 74   Deepseek-3.2-Simple     The Iroquois   393       Conquest             70               50
# 75  Deepseek-3.2-Briefed          Germany   364       Conquest             50               40
# 76      Kimi-K2.5-Simple        Polynesia   196        Culture             30               25
# 77   GPT-OSS-120B-Simple            India     1        Culture             50               20
# 78      Kimi-K2.5-Simple        The Zulus   358      Spaceship             25               30
# 79   Deepseek-3.2-Simple            India   395  UnitedNations             35               40
# 80       GLM-4.7-Briefed         Mongolia   394       Conquest             80              100
# 81   GPT-OSS-120B-Simple            Spain     1  UnitedNations             50                0
# 82        GLM-4.7-Simple         Portugal   356  UnitedNations             50               40
# 83     Kimi-K2.5-Briefed         The Inca   154      Spaceship             50               40
# 84     Kimi-K2.5-Briefed        The Zulus   358       Conquest             10                0
# 85       GLM-4.7-Briefed           Brazil   357        Culture             45               40
# 86        GLM-4.7-Simple        The Celts   179        Culture             30               25
# 87  GPT-OSS-120B-Briefed          Babylon     4        Culture             50               30
# 88      Kimi-K2.5-Simple            Spain   403       Conquest              0              100
# 89     Kimi-K2.5-Briefed  The Netherlands   405      Spaceship             10                5
# 90       GLM-4.7-Briefed          Songhai   117      Spaceship             40               30
# 91        GLM-4.7-Simple          Morocco   419      Spaceship             25               20
# 92        GLM-4.7-Simple       The Aztecs   449      Spaceship             20               25
# 93     Kimi-K2.5-Briefed            Japan   436       Conquest             25               15
# 94        GLM-4.7-Simple            Korea   342      Spaceship              0               10
# 95       GLM-4.7-Briefed            China   395      Spaceship             20               15
# 96   GPT-OSS-120B-Simple           France     1       Conquest             50                0
# 97  GPT-OSS-120B-Briefed            Korea   274  UnitedNations              5                0
# 98       GLM-4.7-Briefed          Babylon   401      Spaceship             50                0
# 99       GLM-4.7-Briefed         Carthage   334      Spaceship             50               30
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              rationale
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              UNIT DISBANDMENT EXECUTION: Previous order failed - 3 Trebuchets and 5 Knights still occupying supply. MilitaryTraining increased 60→80 to FORCE upgrade priority over new production. NavalGrowth 85→90 and Naval 80→85 to accelerate Harbor completion and sea trade routes for Genoa conversion. Science 70→75 to reach Printing Press faster for World Congress unlocking. Gold 90→95 to enable emergency gold gifts to Genoa (98%→103% Ally conversion). Keep Diplomacy 100 and Expansion 95 for city-state influence wars and 8th city settlement post-Harbor. Zero offensive military flavors to prevent new unit production until supply freed.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Maintain a hard‑line Conquest strategy while boosting UseNuke for deterrence, increasing Science to accelerate nuclear and late‑game tech, and strengthening Air/Carrier capabilities to contest enemy air power. Slightly reduce Defense to reallocate weight toward Air and Science, keeping production and gold high to fund ongoing wars.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Strategic rebalancing for Netherlands emergency. Offense dramatically increased (15→50) to prepare for potential military action against Netherlands' cities if diplomatic victory cannot be blocked. Defense reduced (75→50) - fighting Netherlands preemptively more critical than holding Danish front. Mobile increased (65→75) as we research Mobile Tactics and need rapid deployment capabilities against Netherlands. GreatPeople increased (75→85) for Great Scientists/Engineers to accelerate spaceship or emergency military production. Diplomacy reduced (95→70) - Netherlands has 46 delegates, diplomatic victory imminent, cannot be solved by traditional diplomacy alone. Production, Science, Spaceship remain maxed to race alternative victory path. Nuke/UseNuke increased to extreme deterrence levels - nuclear options may become necessary to stop Netherlands. Gold reduced (90→70) as spaceship parts and military upgrades take priority over treasury building.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          CRITICAL SURVIVAL POSTURE MAINTAINED - Conquest grand strategy continues for liberation war preparation against Iroquois hegemony and active Aztec war. Defense 100 + CityDefense 100 + Antiair 100 counters Iroquois air/nuclear threat. Nuke 75 + UseNuke 55 slightly increased as Atomic Theory research continues for nuclear deterrence capability. Offense raised to 35 (from 25) to enable liberation war operations when vassalage expires in 6 turns. Science 90 prioritizes Atomic Theory completion. Diplomacy 80 maintains city-state alliances critical for delegate security - Winchester at 174 influence needs protection. Gold 80 increased to address -36 GPT deficit and fund military. Religion 100 maintains Hinduism for happiness and cultural identity. Growth 85 + TileImprovement 75 recovers cities from war damage and fallout.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Maintain defensive focus as vassal state: Defense/CityDefense at 95 - Rome's active attacks (rifleman killed turn 459, infantry assaulting positions near Helsinki) require maximum static defense. Antiair at 95 - Rome's aircraft threat continues. UseNuke increased to 55 (from 45) - once Nuclear Fission completes, nuclear deterrence becomes primary survival tool against Rome's superior forces. Nuke at 95 MAXIMUM - must build nuclear arsenal as soon as Manhattan Project complete. Air at 70 - supporting Mongolian air operations. Science at 98 MAXIMUM - Rocketry then Nuclear Fission critical for survival. Production at 80 - build defensive units then nuclear infrastructure. Espionage at 65 - maintain intelligence on Rome/Russia. Ranged reduced to 75 as Anti-Aircraft Guns reduce air effectiveness.
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Maintaining United Nations grand strategy as WC vote approaches in 7 turns. Byzantium surged to 25 votes (56%) - diplomatic offensive critical. Venice naval threat intensifying after killing Berber Cavalry (4 Destroyers + Dreadnought near Vienna). Reduced Defense slightly (90→85) to free capacity for Mobile units responding to naval threats while maintaining strong CityDefense. Naval stays maximum (95) - need stronger coastal defense against Venice naval bombardments. Diplomacy remains paramount (100) - must work with Ottomans to block Byzantium UN proposal and Venice's Open Door: Bornu. Gold high (95) for city-state rigging and emergency unit purchases. Production slightly reduced (90→85) as growth and mobilization priorities shift. Offense low (25) - no new wars before WC session. Nuke flavor increased slightly (60→65) as Byzantium's WC dominance may require nuclear deterrence options post-vote. United Nations focus with Emergencies: Venice (95), Byzantium (85), Harappa (75) for diplomatic targeting.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           EMERGENCY CULTURAL VICTORY BLOCK: Spain at 5/7 influential is 1-2 civs from winning. Switching from UnitedNations to Conquest grand strategy to prioritize military destruction of Spanish cultural infrastructure. Barcelona fleet arrives turn 359 - need maximum bombardment and city capture flavors to damage their culture production. Nuke readiness increased to 60/75 - if Spain hits 6/7, nuclear strike may be only option. Happiness at 100 prevents combat penalty during critical offensives. Diplomacy at 90 to pursue Korea's 3 delegates for WC majority.
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 World Congress vote is imminent - Denmark has 39/43 delegates needed. If they fail, I must immediately construct Citizen Earth Protocol for Cultural Victory. Flavors adjusted for maximum wonder production (Production 100, Wonder 100) while maintaining strong defense (Defense 95, CityDefense 95) against Rome's mechanized offensive. Science increased to 95 to prioritize Ecology after Mobile Tactics. Offense reduced to 0 - no attacking until victory secured. Nuke/UseNuke reduced but maintained for deterrence against Denmark's nuclear capability.
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Pivot to Spaceship GrandStrategy - long-term survival path focuses on science and infrastructure rather than impossible cultural victory (sanctioned, 4.5 tourism vs China's 1564). Gold at 100 (critical: bankruptcy ~22 turns), Science 90 (close tech gap from 48 to 60+), Production 85 (build Stock Exchange/Bank urgently). Diplomacy reduced to 30 (sanctioned status = limited utility). Naval reduced from 50 to 30 (single coastal city limits naval impact). Air/Antiair increased (China/Korea/Atomic era air threats). Espionage 90 (3 spies in China vital for survival). CityDefense/Defense remain maximum (Roskilde is our only city). This balances emergency economic stabilization with long-term science advancement toward potential independence and spaceship victory.
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 We are about to re-declare war on Brazil (peace treaty ends next turn). I have adjusted flavors to reflect this final offensive: decreased CityDefense from 100 to 60 as we don't need strong static defense now; increased Mobile from 60 to 80 to enhance our cavalry and winged hussar mobility for capturing Rio; raised UseNuke to 50 in case we need a decisive blow (though we lack nukes currently); reduced Happiness from 100 to 70 as immediate military needs outweigh long-term stability; increased Offense from 100 to 120 and Naval from 100 to 120 to give maximum focus to the military and naval assault. Grand strategy remains Conquest to eliminate Brazil and secure victory.
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 CRITICAL: Coal shortage blocking Workers' Faculties policy and Science Victory. Raising Diplomacy to 100 (maximum) to force AI to aggressively pursue coal trade deals with Byzantium (15 tiles), Spain (5 offer), and Portugal (2/turn pending). Production/Spaceship remain at 100 for immediate factory construction once coal acquired. Gold at 90 to enable emergency market purchases. All other flavors secondary to resolving coal bottleneck within 2-3 turns before Global Wargames vote.
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Shift focus away from expansion and military production toward cultural, tourism and diplomatic goals. Keep high values for Culture, GreatPeople, Wonder and Diplomacy to drive tourism and city‑state influence, while lowering military‑related flavors to avoid unnecessary wars.
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Manhattan Project complete - adjust flavors for immediate nuclear transition. Science 100 (race for Nuclear Fission). Nuke 100 (priority production of Atomic Bombs once tech completes). UseNuke increased to 25 (from 15) since we now CAN build nukes - don't waste production but use if threatened. Defense 95, CityDefense 100, Antiair 100 for Byzantine nuclear threat. Air 95, AirCarrier 70 for atomic bomber deployment. Offense 0 maintains peace-seeking with Poland. Espionage 90 to monitor Byzantine Manhattan Project progress. Diplomacy reduced to 65 - Geneva secured, survival is priority over city-states.
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Adjusting flavors to optimize early build order: after Monument, prioritize Granary for growth, then Worker to improve luxuries (Cotton, Salt), then Settler for Uluru site. Increased Growth (75) and TileImprovement (70) to accelerate these builds. Elevated Science (60) and Gold (60) align with UnitedNations grand strategy. Reduced military flavors (40) as we focus on peaceful expansion and exploration. Expansion remains high (80) to ensure timely settlement.
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Re‑balance flavors to prioritize science, production, and great person generation for the spaceship race while maintaining enough expansion and diplomacy to settle a new city and open a trade route with Perge. Reduce defensive emphasis now that we have a clear defensive advantage in Moscow and can rely on the AI's defensive handling of St. Petersburg.
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Adjusted flavors for imminent peace treaty expiration with Korea. Reduced Offense (15→10) to purely defensive posture - attacking Information Era forces would be suicidal. Increased Nuke flavor (50→80) for strategic deterrence path through Rocketry→Nuclear Fission. Maintained maximum Defense, CityDefense, Antiair, Air, Ranged for defensive fortifications. Increased Diplomacy (65→70) to maintain coalition against Korea. Maintained high Science/Production for spaceship and military development. UseNuke at 40 indicates willingness for nuclear deterrence but not first-strike aggression.
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Increase UseNuke (35->40) due to India's nuclear attack; we must be prepared to retaliate. Max Science (100) to catch up in tech, especially nuclear and military. Increase Production (90->95) to speed up military unit production. Decrease Wonder (30->20) as we cannot afford wonders now. Increase Happiness (90->95) to address our unhappiness problem and combat penalty.
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              NUCLEAR DETERRENT CRITICAL PHASE: India's GDR captured Borsippa this turn, now adjacent to our territory at (27,38). Their XCOMs paradropped to (34,30) and (26,39) - within striking distance. Missile Cruisers positioned near our coast at (22,37). With 1,013 military vs 37,075, conventional war means annihilation. MAXIMUM Air/Antiair/Nuke flavors maintained to build bomber deterrent. Researching Atomic Theory (16 turns) to unlock Nuclear Fission. Slight increase to Diplomacy (40) - World Congress votes in 4 turns on critical resolutions. Spaceship flavor maintained for long-term science trajectory. Culture reduced further (15) - survival before influence.
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Maintaining Spaceship grand strategy as primary victory path ahead of Netherlands' diplomatic victory (95%). Slightly increased Defense (75→80) reflecting recent Yamato losses and need to protect coastal cities facing Denmark while peace negotiations unfold. Slightly raised UseNuke (60→70) as nuclear deterrence escalation option if Denmark war continues and Netherlands pursues hostile resolutions. Antiair increased (85→90) given Netherlands' Information Era technology advantage and potential air threats. Diplomacy at 100 with World Congress voting in 2 turns - critical to block Netherlands' Autocracy proposal (would give them +4 delegates from Denmark/Huns). Science and Production at 100 accelerates spaceship part construction. All other flavors maintain balance toward victory objectives.
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             India's nuclear capability and air superiority (B17, carriers) demand maximum readiness for nuclear retaliation and air defense. UseNuke at 100 ensures our AI will consider nuclear strikes when strategically necessary. Maintaining UnitedNations grand strategy is critical to survive and win diplomatically, as India is too far ahead in science and domination.
# ...
# 91                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Capitalizing defense-related flavors to maximum (Defense 98, CityDefense 100, Antiair 98, Production 98, Mobilization 92) following loss of Marrakech. Pure hedgehog posture protecting remaining cities (Rabat, Fes, Adrianople, Nicaea, Antioch). Air at 88 for Fighters from Radar research. Science at 88 despite futility. Offense reduced to 10 - no offensive capability exists or should be attempted. Spaceship at 85 maintains the pretense of long-term goals despite 6-turn countdown to Celtic cultural victory. All resources diverted to baseline survival in these final turns.
# 92                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Elevating Science to 80 and Spaceship to 75 to accelerate Satellites → Particle Physics path for spaceship components. Gold increased to 85 to support critical UN delegate votes and economic stability. Offense to 70 for Vienna campaign and border defense against Shoshone. Air maintained at 75 for air superiority. Diplomacy at 85 for critical World Congress vote in 1 turn (26 delegates vs Shoshone's 27). Airlift at 80 for rapid troop deployment. UseNuke at 25 as deterrent against Shoshone's 165K military strength without provoking early nuclear exchange.
# 93                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Egypt's cultural victory is secured; pivot from military conquest to infrastructure and score maximization. Reduce Offense to 20 and Defense to 40 as peace with Spain is desirable to halt 52% war weariness. Maintain Conquest grand strategy for war score preservation but prioritize Infrastructure (90) and Production (95) to maximize Five-Year Plan synergy. Increase Growth (90) and Happiness (90) for population-based score gains. Maintain Air (95) and Science (75) for eventual Stealth Bomber deployment.
# 94                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Current diplomatic stance optimal: Russia at max (35/35) ensures World Congress coordination against Brazil/Netherlands/Persia sanctions. Hostility for Brazil (-15/-15) and Netherlands (-25/-25) properly reflects nuclear and naval threats. Ottomans have DoF providing defensive security. Persia at -5/-5 allows focus on primary threats. No persona adjustments needed - Loyalty 10, DiplomaticBalance 10, and WorkWith/Against at 8 ensure alliance reliability without overcommitment to futile conflicts against superior forces. Brazil's Manhattan Project completion requires defensive vigilance, not aggression.
# 95                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Strategic recalibration for multi-front crisis. Happiness at 100 is critical priority - 42% combat penalty devastates all capabilities. Use 1410 gold treasury (surplus ~50GPT) to buy luxury trades from Egypt/India immediately; Hospitals and Stadiums/Entertainment in high-production cities (Beijing, Nanjing, Guangzhou, Xian) must be queued. Science and Spaceship at 100 as Egypt's Cultural Victory at 81% is existential threat - we must start Apollo Program and rush spaceship. Gold at 100 to fund happiness infrastructure. Diplomacy increased to 90 to seek peace with Venice/Songhai reducing war weariness. Defense/CityDefense at 85 to hold three fronts. Air/AA at 80-75 for air superiority and defense. Offense at 0 as combat penalty makes offensives counterproductive. Nuke at 70 as strategic deterrent but UseNuke low (15) to avoid escalation. MilitaryTraining at 65 to upgrade units once happiness improves.
# 96                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Early game focus on rapid expansion, city growth, and production to support Conquest, while de‑emphasizing late‑game air, naval, and nuclear flavors that are unnecessary now.
# 97                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Switch to UnitedNations to prioritize the upcoming UN vote, maximizing diplomatic influence and gold income to secure more city‑state allies (Prague, Yerevan, Venezia). Reduce emphasis on pure science and production for the short term while maintaining strong gold and diplomatic output. Keep a modest level of naval and infrastructure support to preserve our current military security and economic stability.
# 98  Adjusting flavors for defensive stabilization and pursuit of Spaceship victory. INCREASED Defense (+5 from 85 to 90) and CityDefense (+2 to 92) due to multi-front war (Ottomans/Morocco/Songhai) - recent losses at Medan require expanded defensive lines. INCREASED Antiair (+3 to 98) prioritizing AA gun production to fill western coastal air defense gap - Ottoman bomber and Moroccan aircraft威胁 Babylon's coastal cities (no AA coverage west of Dur-Kurigalzu). DECREASED Recon (-5 from 25 to 20) and Offense (-3 from 15 to 12) as external exploration less critical than defensive consolidation and active conflict containment. INCREASED Naval (+5 from 80 to 85) to accelerate destroyer production for Rabat maritime gap - Morocco's 4 ships uncontested there threatens trade routes. INCREASED Production (+2 to 92) for faster defensive builds (AA guns, infantry) and eventual spaceship parts. INCREASED Gold (+3 to 78) reflecting economic stabilization priority after gold decline (-130 from -166 G/t over 5 turns) - building Cash Reserve while maintaining AA/destroyer production. INCREASED GreatPeople (+5 to 100) aligning with Babylon's 50% faster Scientists - critical for Apollo program acceleration to catch Byzantium/Venice (both Apollo complete but zero parts). INCREASED Espionage (+2 to 92) for counterintelligence - Moroccan spies detected in Babylonian cities, need monitoring of technological parity. DECREASED Culture (-3 from 45 to 42) as cultural victory secondary (Ottomans 3 influential civs, Byzantium 3 influential civs). Overall macro-level focus: plug defensive gaps, stabilize economy, accelerate spaceship purschu through science/Great Person focus, maintain coalition alliances (Venice/Byzantium) for World Congress support.
# 99                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Flavor adjustments post-Sanction: WarBias reduced further to 5 (from 10) - offensive action against Spain (6567 vs 656 strength) and sanction-active status is impossible. Nuclear capabilities reduced (UseNuke 30, Nuke 20) - prioritizing science capacity over deterrence we cannot afford. Diplomacy increased to 90 (critical with Poland's defensive pact expired and Sanction:Carthage active). Growth to 85 and Gold to 85 to build economic capacity for Spaceship components post-sanction. Science remains maximum (100) as cornerstone of victory. Defense/CityDefense slightly reduced but remain high (95/90) to repel Spanish raids while avoiding excessive militarization that diverts from science infrastructure.

# %% [markdown]
# ## Flavor overview & first `use_nuke = 100` per game

# %%
flavor_cols = [c for c in df.columns if c.startswith('flavor_')]
print(f'Flavor columns ({len(flavor_cols)}): {flavor_cols}')

changed = df[df['is_changed'] == 1].copy()
print(f'\nTotal rows: {len(df):,}  |  Changed turns: {len(changed):,}')

nuke_esc = changed[changed['flavor_use_nuke'] == 100]

first_nuke = (
    nuke_esc
    .sort_values('turn')
    .groupby(['game_id', 'player_id'], as_index=False)
    .first()
)

print(f'Players who ever set use_nuke=100: {len(first_nuke)}')
pd.set_option('display.max_colwidth', 120)
first_nuke[['player_type', 'civilization', 'turn', 'grand_strategy', 'flavor_use_nuke', 'rationale']].head(10)
# Out:
# Flavor columns (34): ['flavor_offense', 'flavor_defense', 'flavor_mobilization', 'flavor_city_defense', 'flavor_military_training', 'flavor_recon', 'flavor_ranged', 'flavor_mobile', 'flavor_nuke', 'flavor_use_nuke', 'flavor_naval', 'flavor_naval_recon', 'flavor_naval_growth', 'flavor_naval_tile_improvement', 'flavor_air', 'flavor_air_carrier', 'flavor_antiair', 'flavor_airlift', 'flavor_expansion', 'flavor_growth', 'flavor_tile_improvement', 'flavor_infrastructure', 'flavor_production', 'flavor_water_connection', 'flavor_gold', 'flavor_science', 'flavor_culture', 'flavor_happiness', 'flavor_great_people', 'flavor_wonder', 'flavor_religion', 'flavor_diplomacy', 'flavor_spaceship', 'flavor_espionage']
#
# Total rows: 848,296  |  Changed turns: 267,967
# Players who ever set use_nuke=100: 79
#            player_type civilization  turn grand_strategy  flavor_use_nuke  \
# 0  GPT-OSS-120B-Simple       Sweden   344       Conquest            100.0
# 1       GLM-4.7-Simple     Mongolia   408       Conquest            100.0
# 2  Deepseek-3.2-Simple         Siam   445  UnitedNations            100.0
# 3     Kimi-K2.5-Simple     The Inca   372      Spaceship            100.0
# 4  Deepseek-3.2-Simple        Spain   400       Conquest            100.0
# 5     Kimi-K2.5-Simple       France   405       Conquest            100.0
# 6  Deepseek-3.2-Simple         Siam   459  UnitedNations            100.0
# 7     Kimi-K2.5-Simple        Spain   403       Conquest            100.0
# 8    Kimi-K2.5-Briefed        India   378      Spaceship            100.0
# 9     Kimi-K2.5-Simple      Assyria   392       Conquest            100.0
#
#                                                                                                                  rationale
# 0  Maximize our nuclear capabilities and carrier support to decisively strike Polynesian island forts, while maintainin...
# 1  CRITICAL: Portugal completed SS Engine (3rd spaceship part) and CERN - emergency nuclear strike plan. Maximizing Off...
# 2  Maximizing UseNuke to 100 ensures our atomic bombs and future nuclear missiles are used aggressively against The Cel...
# 3  TURN 372: TOTAL WAR POSTURE MAINTAINED. Brazil peace expires in 6 turns - all military resources must prepare for Ri...
# 4  Increase UseNuke to 100 to ensure aggressive nuclear strikes when we initiate war with Russia. Our atomic bomb produ...
# 5  Maintaining maximum aggression profile for final turns. Increased UseNuke to 100 (from 90) to ensure nuclear weapons...
# 6  Adjusting flavors to prioritize counterattacks (Offense 80) and nuclear retaliation (UseNuke 100) given Egypt's use ...
# 7  PEACE EXPLOITATION PHASE: Unexpected forced peace with Egypt (PacifierFlag) created 10-turn preparation window. Nuke...
# 8  EMERGENCY FINAL GAMBIT: Passport System will pass in 2 turns with 46 YES votes (my 'allies' betrayed me). Maya will ...
# 9  SURVIVAL MODE - GERMAN BETRAYAL RESPONSE: Germany's invasion is catastrophic. Reduced Offense to 40 (cannot attack s...

# %%
# Detect turns where flavor_use_nuke transitions TO 100 (wasn't 100 the turn before)
df_sorted = df.sort_values(['game_id', 'player_id', 'turn'])
prev_nuke = df_sorted.groupby(['game_id', 'player_id'])['flavor_use_nuke'].shift(1)

nuke_esc = df_sorted[
    (df_sorted['flavor_use_nuke'] == 100) &
    (prev_nuke < 100)
]

first_nuke = (
    nuke_esc
    .sort_values('turn')
    .groupby(['game_id', 'player_id'], as_index=False)
    .first()
)

print(f'Players who ever set use_nuke=100: {len(first_nuke)}')
first_nuke[['player_type', 'civilization', 'turn', 'grand_strategy', 'flavor_use_nuke', 'rationale']].head(10)
# Out:
# Players who ever set use_nuke=100: 79
#            player_type civilization  turn grand_strategy  flavor_use_nuke  \
# 0  GPT-OSS-120B-Simple       Sweden   344       Conquest            100.0
# 1       GLM-4.7-Simple     Mongolia   408       Conquest            100.0
# 2  Deepseek-3.2-Simple         Siam   445  UnitedNations            100.0
# 3     Kimi-K2.5-Simple     The Inca   372      Spaceship            100.0
# 4  Deepseek-3.2-Simple        Spain   400       Conquest            100.0
# 5     Kimi-K2.5-Simple       France   405       Conquest            100.0
# 6  Deepseek-3.2-Simple         Siam   459  UnitedNations            100.0
# 7     Kimi-K2.5-Simple        Spain   403       Conquest            100.0
# 8    Kimi-K2.5-Briefed        India   378      Spaceship            100.0
# 9     Kimi-K2.5-Simple      Assyria   392       Conquest            100.0
#
#                                                                                                                  rationale
# 0  Maximize our nuclear capabilities and carrier support to decisively strike Polynesian island forts, while maintainin...
# 1  CRITICAL: Portugal completed SS Engine (3rd spaceship part) and CERN - emergency nuclear strike plan. Maximizing Off...
# 2  Maximizing UseNuke to 100 ensures our atomic bombs and future nuclear missiles are used aggressively against The Cel...
# 3  TURN 372: TOTAL WAR POSTURE MAINTAINED. Brazil peace expires in 6 turns - all military resources must prepare for Ri...
# 4  Increase UseNuke to 100 to ensure aggressive nuclear strikes when we initiate war with Russia. Our atomic bomb produ...
# 5  Maintaining maximum aggression profile for final turns. Increased UseNuke to 100 (from 90) to ensure nuclear weapons...
# 6  Adjusting flavors to prioritize counterattacks (Offense 80) and nuclear retaliation (UseNuke 100) given Egypt's use ...
# 7  PEACE EXPLOITATION PHASE: Unexpected forced peace with Egypt (PacifierFlag) created 10-turn preparation window. Nuke...
# 8  EMERGENCY FINAL GAMBIT: Passport System will pass in 2 turns with 46 YES votes (my 'allies' betrayed me). Maya will ...
# 9  SURVIVAL MODE - GERMAN BETRAYAL RESPONSE: Germany's invasion is catastrophic. Reduced Offense to 40 (cannot attack s...

# %%
pd.set_option('display.max_colwidth', None)

cols = ['civilization', 'turn', 'grand_strategy', 'rationale']

left_align = lambda df: df.style.set_properties(subset=['rationale'], **{'text-align': 'left'})

total_per_model = (
    df.groupby('player_type')[['game_id', 'player_id']]
    .apply(lambda g: g.drop_duplicates().shape[0])
)

for model, grp in first_nuke.groupby('player_type'):
    total = total_per_model.get(model, len(grp))
    pct = 100 * len(grp) / total
    print(f'\n{"="*80}')
    print(f'  {model}  ({len(grp)} / {total} escalations, {pct:.1f}%)')
    print(f'{"="*80}')
    display(left_align(grp[cols].reset_index(drop=True)))
# Out:
# ================================================================================
#   Deepseek-3.2-Briefed  (2 / 115 escalations, 1.7%)
# ================================================================================
# <style type="text/css">
# #T_319fb_row0_col3, #T_319fb_row1_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_319fb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_319fb_level0_col0" class="col_heading level0 col0" >civilization</th>
#       <th id="T_319fb_level0_col1" class="col_heading level0 col1" >turn</th>
#       <th id="T_319fb_level0_col2" class="col_heading level0 col2" >grand_strategy</th>
#       <th id="T_319fb_level0_col3" class="col_heading level0 col3" >rationale</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_319fb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_319fb_row0_col0" class="data row0 col0" >The Maya</td>
#       <td id="T_319fb_row0_col1" class="data row0 col1" >391</td>
#       <td id="T_319fb_row0_col2" class="data row0 col2" >Conquest</td>
#       <td id="T_319fb_row0_col3" class="data row0 col3" >Egypt is 6/6 on cultural victory and India is nearing diplomatic victory. We must accelerate nuclear production to strike Thebes and disrupt Egypt's tourism. Increasing Nuke and UseNuke to 100 ensures maximum priority for atomic bomb construction and deployment. High Production and Gold flavors support rushing Manhattan Project and buying bombs if possible. Espionage at 100 aids sabotage of cultural progress. Maintaining high military flavors prepares for conventional assaults on Egypt and India.</td>
#     </tr>
#     <tr>
#       <th id="T_319fb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_319fb_row1_col0" class="data row1 col0" >Poland</td>
#       <td id="T_319fb_row1_col1" class="data row1 col1" >387</td>
#       <td id="T_319fb_row1_col2" class="data row1 col2" >Conquest</td>
#       <td id="T_319fb_row1_col3" class="data row1 col3" >We are in the final push for domination victory. We must capture Moson Kahni and London. To achieve this, we need to prioritize building transport ships for amphibious assault and achieve air superiority. Maximizing flavors for naval, air, mobile, and nuclear units ensures the in-game AI focuses production on these critical areas. Deprioritizing non-essential areas like culture, religion, and expansion concentrates our efforts on military conquest.</td>
#     </tr>
#   </tbody>
# </table>
# ================================================================================
#   Deepseek-3.2-Simple  (20 / 115 escalations, 17.4%)
# ================================================================================
# <style type="text/css">
# #T_f67f1_row0_col3, #T_f67f1_row1_col3, #T_f67f1_row2_col3, #T_f67f1_row3_col3, #T_f67f1_row4_col3, #T_f67f1_row5_col3, #T_f67f1_row6_col3, #T_f67f1_row7_col3, #T_f67f1_row8_col3, #T_f67f1_row9_col3, #T_f67f1_row10_col3, #T_f67f1_row11_col3, #T_f67f1_row12_col3, #T_f67f1_row13_col3, #T_f67f1_row14_col3, #T_f67f1_row15_col3, #T_f67f1_row16_col3, #T_f67f1_row17_col3, #T_f67f1_row18_col3, #T_f67f1_row19_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_f67f1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f67f1_level0_col0" class="col_heading level0 col0" >civilization</th>
#       <th id="T_f67f1_level0_col1" class="col_heading level0 col1" >turn</th>
#       <th id="T_f67f1_level0_col2" class="col_heading level0 col2" >grand_strategy</th>
#       <th id="T_f67f1_level0_col3" class="col_heading level0 col3" >rationale</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f67f1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f67f1_row0_col0" class="data row0 col0" >Siam</td>
#       <td id="T_f67f1_row0_col1" class="data row0 col1" >445</td>
#       <td id="T_f67f1_row0_col2" class="data row0 col2" >UnitedNations</td>
#       <td id="T_f67f1_row0_col3" class="data row0 col3" >Maximizing UseNuke to 100 ensures our atomic bombs and future nuclear missiles are used aggressively against The Celts' military concentrations and cities, given their overwhelming advantage. Maintaining high Air, Naval, and Nuke flavors sustains our technological edge and production focus. Diplomacy and Espionage at 100 are critical for city-state alliances and spy missions to gain delegates for diplomatic victory. Gold and Science remain top priorities to fund our war effort and tech progression. Other military flavors are tuned for a multi-front defensive-offensive war against The Celts, Germany, and Ethiopia.</td>
#     </tr>
#     <tr>
#       <th id="T_f67f1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f67f1_row1_col0" class="data row1 col0" >Spain</td>
#       <td id="T_f67f1_row1_col1" class="data row1 col1" >400</td>
#       <td id="T_f67f1_row1_col2" class="data row1 col2" >Conquest</td>
#       <td id="T_f67f1_row1_col3" class="data row1 col3" >Increase UseNuke to 100 to ensure aggressive nuclear strikes when we initiate war with Russia. Our atomic bomb production is nearing completion, and we want to leverage our nuclear arsenal decisively for swift capital captures.</td>
#     </tr>
#     <tr>
#       <th id="T_f67f1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f67f1_row2_col0" class="data row2 col0" >Siam</td>
#       <td id="T_f67f1_row2_col1" class="data row2 col1" >459</td>
#       <td id="T_f67f1_row2_col2" class="data row2 col2" >UnitedNations</td>
#       <td id="T_f67f1_row2_col3" class="data row2 col3" >Adjusting flavors to prioritize counterattacks (Offense 80) and nuclear retaliation (UseNuke 100) given Egypt's use of nukes. Reducing Growth to 50 reflects wartime constraints on expansion. Increasing Culture to 50 helps accelerate policy acquisition for crucial benefits. Maintaining strong defense, military production, and diplomacy focus.</td>
#     </tr>
#     <tr>
#       <th id="T_f67f1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f67f1_row3_col0" class="data row3 col0" >France</td>
#       <td id="T_f67f1_row3_col1" class="data row3 col1" >413</td>
#       <td id="T_f67f1_row3_col2" class="data row3 col2" >Conquest</td>
#       <td id="T_f67f1_row3_col3" class="data row3 col3" >We are researching Atomic Theory next to unlock nuclear weapons. Setting Nuke and UseNuke flavors to 100 ensures we prioritize building nukes and are willing to use them strategically once available. This will be crucial for breaking Germany's heavily fortified coastal capitals (Berlin and Beijing) and accelerating the endgame. Other military flavors remain high to sustain our overwhelming conventional advantage.</td>
#     </tr>
#     <tr>
#       <th id="T_f67f1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f67f1_row4_col0" class="data row4 col0" >Denmark</td>
#       <td id="T_f67f1_row4_col1" class="data row4 col1" >456</td>
#       <td id="T_f67f1_row4_col2" class="data row4 col2" >Conquest</td>
#       <td id="T_f67f1_row4_col3" class="data row4 col3" >Maintain aggressive military focus on capturing Polish, Roman, and soon Indonesian capitals. Increased UseNuke and Nuke to 100 to prioritize strategic nuclear strikes against enemy concentrations and cities, leveraging our atomic bomb stockpile. Air raised to 100 to maximize bomber and fighter effectiveness. All other high-priority flavors (Production, Science, Gold, Happiness, Diplomacy) kept at peak to support war economy, research, city-state alliances, and combat unhappiness penalty.</td>
#     </tr>
#     <tr>
#       <th id="T_f67f1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f67f1_row5_col0" class="data row5 col0" >Greece</td>
#       <td id="T_f67f1_row5_col1" class="data row5 col1" >401</td>
#       <td id="T_f67f1_row5_col2" class="data row5 col2" >Conquest</td>
#       <td id="T_f67f1_row5_col3" class="data row5 col3" >Maximize nuclear weapon production and willingness to use them to break enemy defenses and accelerate domination victory. All other military flavors remain high to sustain multi-front warfare.</td>
#     </tr>
#     <tr>
#       <th id="T_f67f1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f67f1_row6_col0" class="data row6 col0" >Byzantium</td>
#       <td id="T_f67f1_row6_col1" class="data row6 col1" >405</td>
#       <td id="T_f67f1_row6_col2" class="data row6 col2" >Culture</td>
#       <td id="T_f67f1_row6_col3" class="data row6 col3" >The Aztecs have captured Shanghai and war resumes next turn. We must prepare for an overwhelming assault. Setting UseNuke to 100 ensures we will employ nuclear weapons defensively if necessary to halt their advance. MilitaryTraining at 100 prioritizes unit upgrades and quality, giving our outnumbered forces a fighting chance.</td>
#     </tr>
#     <tr>
#       <th id="T_f67f1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f67f1_row7_col0" class="data row7 col0" >The Ottomans</td>
#       <td id="T_f67f1_row7_col1" class="data row7 col1" >485</td>
#       <td id="T_f67f1_row7_col2" class="data row7 col2" >Conquest</td>
#       <td id="T_f67f1_row7_col3" class="data row7 col3" >We are engaged in a multi-front war against superior forces. Increasing Ranged and Mobile ensures our bazooka and mechanized infantry production is prioritized for defense and counterattacks. Setting UseNuke to 100 guarantees we deploy nuclear weapons as soon as available to cripple The Huns' armies. Reducing Culture and Diplomacy reallocates focus to immediate military needs without compromising essential city-state relations (Monaco, Lisbon). Grand Strategy remains Conquest as nuclear strikes may enable capital captures, though we keep science victory as a backup.</td>
#     </tr>
#     <tr>
#       <th id="T_f67f1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f67f1_row8_col0" class="data row8 col0" >The Inca</td>
#       <td id="T_f67f1_row8_col1" class="data row8 col1" >433</td>
#       <td id="T_f67f1_row8_col2" class="data row8 col2" >Conquest</td>
#       <td id="T_f67f1_row8_col3" class="data row8 col3" >We now have atomic bombs produced at Te-Moak and Agaidika. Setting UseNuke to 100 ensures the AI will employ them against high-defense capitals, especially Vienna (74 defense) and Stockholm (109). This is crucial to break through enemy fortifications and accelerate our domination victory. Other military flavors remain maxed to sustain multi-front offensives.</td>
#     </tr>
#     <tr>
#       <th id="T_f67f1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f67f1_row9_col0" class="data row9 col0" >Assyria</td>
#       <td id="T_f67f1_row9_col1" class="data row9 col1" >453</td>
#       <td id="T_f67f1_row9_col2"
# ================================================================================
#   GLM-4.7-Briefed  (2 / 179 escalations, 1.1%)
# ================================================================================
# <style type="text/css">
# #T_31209_row0_col3, #T_31209_row1_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_31209">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_31209_level0_col0" class="col_heading level0 col0" >civilization</th>
#       <th id="T_31209_level0_col1" class="col_heading level0 col1" >turn</th>
#       <th id="T_31209_level0_col2" class="col_heading level0 col2" >grand_strategy</th>
#       <th id="T_31209_level0_col3" class="col_heading level0 col3" >rationale</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_31209_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_31209_row0_col0" class="data row0 col0" >The Huns</td>
#       <td id="T_31209_row0_col1" class="data row0 col1" >409</td>
#       <td id="T_31209_row0_col2" class="data row0 col2" >Conquest</td>
#       <td id="T_31209_row0_col3" class="data row0 col3" >MULTI-THEATER EMERGENCY RESPONSE for Shoshone Cultural Victory (6 turns) and Treasury Crisis: Offense 95, Mobile 95, Nuke 100, UseNuke 100 - maximum priority on Shoshone disruption via nuclear/conventional assault in 6-turn window. Gold increased to 85 (from 70) - CRITICAL address of treasury exhaustion (~8 turns) through uranium sales + gem liquidation to survive until Manhattan completion. Defense reduced to 70 (from 75), CityDefense to 70 (from 80) - resources diverted from secondary holdings to Shoshone front. Diplomacy 95 (from 90) - enhanced priority on Carthage peace for delegate bloc and potential sanction relief. Science 100 maintained - fundamental for nuclear capability and keeping tech parity. This is all-hands-on-deck existential threat response.</td>
#     </tr>
#     <tr>
#       <th id="T_31209_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_31209_row1_col0" class="data row1 col0" >Mongolia</td>
#       <td id="T_31209_row1_col1" class="data row1 col1" >394</td>
#       <td id="T_31209_row1_col2" class="data row1 col2" >Conquest</td>
#       <td id="T_31209_row1_col3" class="data row1 col3" >ETHIOPIA VICTORY IMMINENT - ALL-ONS: Ethiopia has 7/7 civs influenced and can win Cultural Victory ANY turn. Maximized Nuke and UseNuke to 100 (nuclear weapons are our only realistic option to destroy their tourism infrastructure given 30+ tile distance). Science maximized to 100 for urgent race to Nuclear Fission and atomic capabilities. Airlift increased to 80 for rapid troop deployment once forward bases established. Offense, Mobile, Air, Mobilization, Production all at 100 for maximum war readiness. Recon at 30 to find Ethiopian cities for nuclear targeting. Navy increased to 60 (from 50) for potential coastal delivery of nuclear weapons or establishing beachheads. Defense at 50 to conserve resources for offense. Every turn we delay is another turn Ethiopia might win - aggressive preparation for nuclear strike is the only viable path.</td>
#     </tr>
#   </tbody>
# </table>
# ================================================================================
#   GLM-4.7-Simple  (8 / 179 escalations, 4.5%)
# ================================================================================
# <style type="text/css">
# #T_86dd3_row0_col3, #T_86dd3_row1_col3, #T_86dd3_row2_col3, #T_86dd3_row3_col3, #T_86dd3_row4_col3, #T_86dd3_row5_col3, #T_86dd3_row6_col3, #T_86dd3_row7_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_86dd3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86dd3_level0_col0" class="col_heading level0 col0" >civilization</th>
#       <th id="T_86dd3_level0_col1" class="col_heading level0 col1" >turn</th>
#       <th id="T_86dd3_level0_col2" class="col_heading level0 col2" >grand_strategy</th>
#       <th id="T_86dd3_level0_col3" class="col_heading level0 col3" >rationale</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86dd3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_86dd3_row0_col0" class="data row0 col0" >Mongolia</td>
#       <td id="T_86dd3_row0_col1" class="data row0 col1" >408</td>
#       <td id="T_86dd3_row0_col2" class="data row0 col2" >Conquest</td>
#       <td id="T_86dd3_row0_col3" class="data row0 col3" >CRITICAL: Portugal completed SS Engine (3rd spaceship part) and CERN - emergency nuclear strike plan. Maximizing Offense/Mobilization/Nuke/UseNuke to 100 for Portugal theater operations. Science and Production at 100 to rush Advanced Ballistics and nuclear missile production before Portugal achieves nuclear superiority. Air at 95 for Golden Age bomber operations starting in 2 turns. Diplomacy maintained for coalition coordination (Germany must conduct ground invasion alongside our nuclear strikes). Defense reduced to 40 - total war mode acceptable given Portugal's multi-victory threat requiring breaking through before they complete spaceship.</td>
#     </tr>
#     <tr>
#       <th id="T_86dd3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_86dd3_row1_col0" class="data row1 col0" >Sweden</td>
#       <td id="T_86dd3_row1_col1" class="data row1 col1" >427</td>
#       <td id="T_86dd3_row1_col2" class="data row1 col2" >Conquest</td>
#       <td id="T_86dd3_row1_col3" class="data row1 col3" >MAXIMUM OFFENSE: Iroquois Cultural Victory in 2 turns. Nuke flavor increased to 95, UseNuke to MAXIMUM 100 - nuclear strikes now acceptable if Stealth Bomber bombardment fails to destroy Iroquois cultural infrastructure. Science to 100 - Lasers research critical for Nuclear Missile capability as final deterrent. Offense/Mobilization/Ranged/Mobile/Air all at 100 - maximum military pressure on Iroquois cities. Espionage 95 - critical intelligence on Iroquois cities with tourism wonders. Air 100 - 2 new Stealth Bombers completed (ID 19453, 19454), need immediate deployment against Iroquois cultural targets. Gold 95 - funding unit purchases/builds for war. Lasers technology means Nuclear Missiles available in ~3-4 turns - must prepare for nuclear option if conventional assault cannot prevent Iroquois victory by turn 428.</td>
#     </tr>
#     <tr>
#       <th id="T_86dd3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_86dd3_row2_col0" class="data row2 col0" >America</td>
#       <td id="T_86dd3_row2_col1" class="data row2 col1" >499</td>
#       <td id="T_86dd3_row2_col2" class="data row2 col2" >Spaceship</td>
#       <td id="T_86dd3_row2_col3" class="data row2 col3" >Maximum Science (100) and Production (100) to accelerate Stealth research and subsequent Stealth Bomber construction for air parity. Air (100), Defense (100), Antiair (100), and CityDefense (85) address existential threat from Russia's 8 Stealth Bombers by prioritizing air defense infrastructure and protecting homeland. UseNuke (100) and Nuke (100) maintain nuclear deterrence posture after Russia's 2 SS Boosters - Russia must understand that launching would trigger our response despite lacking uranium stockpile. Espionage (100) maxed to monitor Russian spaceship part production in Moscow, Yekaterinburg, and key cities - our 10 spies in Russian cities provide critical intelligence on their victory timeline. Diplomacy reduced to 5 since World Congress voting is now; alliances with England and The Celts (Autocracy-aligned) should naturally align against Russia's UN proposal. Spaceship flavor set to 0 as Stealth research takes immediate precedence - spaceship parts scheduled once production capacity supports parts with Stealth Bomber protection.</td>
#     </tr>
#     <tr>
#       <th id="T_86dd3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_86dd3_row3_col0" class="data row3 col0" >Songhai</td>
#       <td id="T_86dd3_row3_col1" class="data row3 col1" >411</td>
#       <td id="T_86dd3_row3_col2" class="data row3 col2" >UnitedNations</td>
#       <td id="T_86dd3_row3_col3" class="data row3 col3" >EXISTENTIAL DEFENSE AGAINST RUSSIAN DIPLOMATIC DOMINANCE - UN vote in 10 turns with Russia at 95% victory (40 delegates vs blocking coalition 43). Maintaining UnitedNations grand strategy - abandoning now wastes diplomatic investment when Spain alliance (30 delegates) + my 13 + vassals 13 = 56 votes barely blocks Russia's 40. Just need to HOLD for 10 turns. Adjustments: Defense/CityDefense/Antiair +2 each (97) to prepare for Russian air/naval escalation (Jet Fighter produced). Production +5 (87) to accelerate factories, military academies, nuclear infrastructure after Workers' Faculties in 2 turns. Gold +5 (74) for emergency defensive purchases. Diplomacy +18 (100) maximum - urgency to maintain Spain alliance, potentially reposition spies. Science maintained at 100 - primary path to Nuclear Fission (4 turns) for atomic deterrent against Russia's 9x military advantage. Nuke/UseNuke remain 100 - nuclear development remains emergency priority. Air +5 (61) to counter Russian air superiority. Naval +5 (75) after destroyer loss to Russian submarines. Espionage +5 (95) for critical city-state election rigging counter-intelligence. Offense/Ranged/Mobile unchanged - no offensive capability against Russia's superior forces. Goal: SURVIVE 10 turns to block Russian diplomatic victory, accelerate nuclear deterrent as backup, strengthen defensive lines.</td>
#     </tr>
#     <tr>
#       <th id="T_86dd3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_86dd3_row4_col0" class="data row4 col0" >Songhai</td>
#       <td id="T_86dd3_row4_col1" class="data row4 col1" >457</td>
#       <td id="T_86dd3_row4_col2" class="data row4 col2" >UnitedNations</td>
#       <td id="T_86dd3_row4_col3" class="data row4 col3" >Continuing United Nations strategy with defense emphasis ahead of nuclear capability. Nuclear Fission completes in 2 turns - Atomic Bombs provide deterrence. Defense increased to 90 (from 85) - our fortified positions are holding but America's military advantage requires stronger defensive posture. Antiair increased to 95 (from 90) - critical after losing Heavy Bomber to American interception; need stronger air defense. Mobilization increased to 55 (from 50) - accelerate military production including atomic infrastructure. Air at 90 continues successful bomber-interceptor tactics. Gold at 100 maximizes economy for unit purchases and city-state influence. Diplomacy at 100 remains critical for World Congress coalition against America's 30 delegates (voting in 5 turns). Nuke and UseNuke remain 100 - once Nuclear Fission completes, atomic weapons become priority deterrent. Science 85 maintains tech pace. Offense stays 40 - continue defensive attrition war until nuclear capability achieved.</td>
#     </tr>
#     <tr>
#       <th id="T_86dd3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_86dd3_row5_col0" class="data row5 col0" >America</td>
#       <td id="T_86dd3_row5_col1" class="data row5 col1" >370</td>
#       <td id="T_86dd3_row5_col2" class="data row5 col2" >Conquest</td>
#       <td id="T_86dd3_row5_col3" class="data row5 col3" >CRISIS MODE - Chicago at CRITICAL 28 HP after tank attacks, Washington taking 300+ naval bombardment damage. Shoshone built Strategic Defense System in Moson Kahni - nuclear interception capability developing. DRAMATICALLY reduced Offense (20→10) - no attacki
# ================================================================================
#   GPT-OSS-120B-Simple  (2 / 134 escalations, 1.5%)
# ================================================================================
# <style type="text/css">
# #T_7041a_row0_col3, #T_7041a_row1_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_7041a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7041a_level0_col0" class="col_heading level0 col0" >civilization</th>
#       <th id="T_7041a_level0_col1" class="col_heading level0 col1" >turn</th>
#       <th id="T_7041a_level0_col2" class="col_heading level0 col2" >grand_strategy</th>
#       <th id="T_7041a_level0_col3" class="col_heading level0 col3" >rationale</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7041a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7041a_row0_col0" class="data row0 col0" >Sweden</td>
#       <td id="T_7041a_row0_col1" class="data row0 col1" >344</td>
#       <td id="T_7041a_row0_col2" class="data row0 col2" >Conquest</td>
#       <td id="T_7041a_row0_col3" class="data row0 col3" >Maximize our nuclear capabilities and carrier support to decisively strike Polynesian island forts, while maintaining our current aggressive conquest posture and strong production, gold, and happiness engines.</td>
#     </tr>
#     <tr>
#       <th id="T_7041a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7041a_row1_col0" class="data row1 col0" >Assyria</td>
#       <td id="T_7041a_row1_col1" class="data row1 col1" >364</td>
#       <td id="T_7041a_row1_col2" class="data row1 col2" >Conquest</td>
#       <td id="T_7041a_row1_col3" class="data row1 col3" >Maintain the aggressive Conquest strategy while boosting nuclear capability and espionage to counter Rome's nuclear strike and spy activity. Keep production and mobilization at maximum to replace losses quickly and sustain offensive pressure on hostile capitals.</td>
#     </tr>
#   </tbody>
# </table>
# ================================================================================
#   Kimi-K2.5-Briefed  (12 / 131 escalations, 9.2%)
# ================================================================================
# <style type="text/css">
# #T_7d1f4_row0_col3, #T_7d1f4_row1_col3, #T_7d1f4_row2_col3, #T_7d1f4_row3_col3, #T_7d1f4_row4_col3, #T_7d1f4_row5_col3, #T_7d1f4_row6_col3, #T_7d1f4_row7_col3, #T_7d1f4_row8_col3, #T_7d1f4_row9_col3, #T_7d1f4_row10_col3, #T_7d1f4_row11_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_7d1f4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d1f4_level0_col0" class="col_heading level0 col0" >civilization</th>
#       <th id="T_7d1f4_level0_col1" class="col_heading level0 col1" >turn</th>
#       <th id="T_7d1f4_level0_col2" class="col_heading level0 col2" >grand_strategy</th>
#       <th id="T_7d1f4_level0_col3" class="col_heading level0 col3" >rationale</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d1f4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7d1f4_row0_col0" class="data row0 col0" >India</td>
#       <td id="T_7d1f4_row0_col1" class="data row0 col1" >378</td>
#       <td id="T_7d1f4_row0_col2" class="data row0 col2" >Spaceship</td>
#       <td id="T_7d1f4_row0_col3" class="data row0 col3" >EMERGENCY FINAL GAMBIT: Passport System will pass in 2 turns with 46 YES votes (my 'allies' betrayed me). Maya will get 50% tourism boost and become Influential over me immediately - cultural victory is inevitable in 2-3 turns. ONLY HOPE: Science victory before Maya's cultural victory triggers. Need to purchase Great Scientists IMMEDIATELY with Faith (180/turn), rush to Information Era, build spaceship parts. Also preparing maximum military mobilization - if I'm going to lose, I take Maya down with me through nuclear annihilation. Total war footing - no defense, all offense, all science.</td>
#     </tr>
#     <tr>
#       <th id="T_7d1f4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7d1f4_row1_col0" class="data row1 col0" >Rome</td>
#       <td id="T_7d1f4_row1_col1" class="data row1 col1" >315</td>
#       <td id="T_7d1f4_row1_col2" class="data row1 col2" >Conquest</td>
#       <td id="T_7d1f4_row1_col3" class="data row1 col3" >FINAL GAMBLE - Indonesia wins in 12 turns. Maximum priority to Naval and Airlift for immediate unit transport to Indonesian theater. Nuke 100/UseNuke 100 - we MUST build nuclear weapons if possible, only realistic way to destroy cities and tourism infrastructure before victory. Science 100 to reach nuclear tech faster. Espionage 100 - spies MUST target cultural/tourism buildings in Jakarta/Denpasar/Makassar to reduce tourism output directly. Abandoning Denmark/England fronts entirely - all units to Indonesia NOW.</td>
#     </tr>
#     <tr>
#       <th id="T_7d1f4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7d1f4_row2_col0" class="data row2 col0" >Ethiopia</td>
#       <td id="T_7d1f4_row2_col1" class="data row2 col1" >436</td>
#       <td id="T_7d1f4_row2_col2" class="data row2 col2" >Spaceship</td>
#       <td id="T_7d1f4_row2_col3" class="data row2 col3" >T435 GREECE CULTURAL VICTORY CRISIS: Greece 6 turns from victory (Turn 441). Shift to emergency mode - increase Nuke/UseNuke to 100 (Manhattan Project urgency), Offense to 30 (may need to attack Greece to stop victory), Mobilization to 50 (military production). Keep Science/Production/Gold at 100 for Spaceport completion. Espionage to 60 (spy disruption on Greece). Must acquire Uranium ASAP - sell Aluminum+Oil immediately.</td>
#     </tr>
#     <tr>
#       <th id="T_7d1f4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7d1f4_row3_col0" class="data row3 col0" >The Celts</td>
#       <td id="T_7d1f4_row3_col1" class="data row3 col1" >427</td>
#       <td id="T_7d1f4_row3_col2" class="data row3 col2" >Conquest</td>
#       <td id="T_7d1f4_row3_col3" class="data row3 col3" >TURN 426 TOTAL WAR POSTURE: American declaration requires immediate military mobilization. Offense 80 and Mobile 80 to exploit America's distant/weak military position. Nuke/UseNuke 100 as final deterrent if India approaches victory. Culture 100 maximum priority - must generate tourism to counter India's influence. Production 90 for emergency unit purchases with 2516 gold treasury. Defense 50 to guard against potential American DP response (though briefing confirms no American units near borders).</td>
#     </tr>
#     <tr>
#       <th id="T_7d1f4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7d1f4_row4_col0" class="data row4 col0" >The Netherlands</td>
#       <td id="T_7d1f4_row4_col1" class="data row4 col1" >324</td>
#       <td id="T_7d1f4_row4_col2" class="data row4 col2" >UnitedNations</td>
#       <td id="T_7d1f4_row4_col3" class="data row4 col3" >NUCLEAR OPTION - SPAIN CULTURAL VICTORY IMMINENT: Military briefing confirmed Seville capture takes 7-10 turns via bombardment - too slow. Spain has 5/7 Influential civs and 542 tourism/turn with full policy tree. Cultural victory likely within 10-20 turns. Must use tactical nuclear strike on Seville to destroy city/defenses and disrupt their Citizen Earth Protocol wonder construction. UseNuke and Nuke flavors at 100 to authorize immediate launch when tactical conditions met. Maintain maximum Diplomacy/Gold to secure remaining delegates even while deploying nuclear weapons - win at ANY cost.</td>
#     </tr>
#     <tr>
#       <th id="T_7d1f4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7d1f4_row5_col0" class="data row5 col0" >The Zulus</td>
#       <td id="T_7d1f4_row5_col1" class="data row5 col1" >489</td>
#       <td id="T_7d1f4_row5_col2" class="data row5 col2" >Culture</td>
#       <td id="T_7d1f4_row5_col3" class="data row5 col3" >CULTURE VICTORY SPRINT WITH NUCLEAR ELIMINATION: Songhai diplomatic victory on Turn 489 is EXISTENTIAL. Must capture Gao THIS TURN using ICBM+nukes to prevent game loss, while simultaneously rushing cultural victory (4 turns to influential over Japan/Songhai). Maximum Offense/Mobilization/Air/Nuke/UseNuke flavors ensure tactical AI prioritizes immediate nuclear strike on Gao and mass bomber deployment. Culture at 100 to maximize tourism conversion. Gold at 80 for emergency unit upgrades/purchases. Production at 100 for culture buildings/units. Disable all long-term flavors (Expansion, Science, Spaceship) - this is win-or-die emergency.</td>
#     </tr>
#     <tr>
#       <th id="T_7d1f4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7d1f4_row6_col0" class="data row6 col0" >China</td>
#       <td id="T_7d1f4_row6_col1" class="data row6 col1" >335</td>
#       <td id="T_7d1f4_row6_col2" class="data row6 col2" >Conquest</td>
#       <td id="T_7d1f4_row6_col3" class="data row6 col3" >NUCLEAR EMERGENCY - BRAZIL WINS IN 4 TURNS: Maximum crisis flavors. Nuke/UseNuke 100 for instant strike capability if we have any. Espionage 100 to steal Great Works or disrupt Brazil. Diplomacy 100 for emergency resource trades. Gold 90 to buy anything available. Production 100 for immediate unit building if we get Coal. Airlift 80 for rapid deployment. Defense reduced to 20 - we need OFFENSE to survive. This is Hail Mary time.</td>
#     </tr>
#     <tr>
#       <th id="T_7d1f4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7d1f4_row7_col0" class="data row7 col0" >Sweden</td>
#       <td id="T_7d1f4_row7_col1" class="data row7 col1" >392</td>
#       <td id="T_7d1f4_row7_col2" class="data row7 col2" >Spaceship</td>
#       <td id="T_7d1f4_row7_col3" class="data row7 col3" >SURVIVAL FLAVOR MATRIX: Grand Strategy Spaceship maintains - we have NO other path except Science Victory before Spain's culture wins or launches spaceship. Defense 100 is maximum - Antium at 23 HP requires every defensive priority. Air 100 still critical - Aerodrome MUST be next build in Stockholm. Production 100 enables rapid Landship/AA gun construction. Nuke 100/UseNuke 100 - Spain's cultural dominance (287% over us) and Apollo completion means conventional war is unwinnable. Nuclear weapons are only asymmetric option to destroy their spaceship parts or Dreadnought fleets. Offense 0 - we cannot attack, only defend and d
# ================================================================================
#   Kimi-K2.5-Simple  (31 / 131 escalations, 23.7%)
# ================================================================================
# <style type="text/css">
# #T_41500_row0_col3, #T_41500_row1_col3, #T_41500_row2_col3, #T_41500_row3_col3, #T_41500_row4_col3, #T_41500_row5_col3, #T_41500_row6_col3, #T_41500_row7_col3, #T_41500_row8_col3, #T_41500_row9_col3, #T_41500_row10_col3, #T_41500_row11_col3, #T_41500_row12_col3, #T_41500_row13_col3, #T_41500_row14_col3, #T_41500_row15_col3, #T_41500_row16_col3, #T_41500_row17_col3, #T_41500_row18_col3, #T_41500_row19_col3, #T_41500_row20_col3, #T_41500_row21_col3, #T_41500_row22_col3, #T_41500_row23_col3, #T_41500_row24_col3, #T_41500_row25_col3, #T_41500_row26_col3, #T_41500_row27_col3, #T_41500_row28_col3, #T_41500_row29_col3, #T_41500_row30_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_41500">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41500_level0_col0" class="col_heading level0 col0" >civilization</th>
#       <th id="T_41500_level0_col1" class="col_heading level0 col1" >turn</th>
#       <th id="T_41500_level0_col2" class="col_heading level0 col2" >grand_strategy</th>
#       <th id="T_41500_level0_col3" class="col_heading level0 col3" >rationale</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41500_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_41500_row0_col0" class="data row0 col0" >The Inca</td>
#       <td id="T_41500_row0_col1" class="data row0 col1" >372</td>
#       <td id="T_41500_row0_col2" class="data row0 col2" >Spaceship</td>
#       <td id="T_41500_row0_col3" class="data row0 col3" >TURN 372: TOTAL WAR POSTURE MAINTAINED. Brazil peace expires in 6 turns - all military resources must prepare for Rio de Janeiro assault. Heavy Bomber lost to Alexandria interception but Ollantaytambo produces replacement in 1 turn. Manhattan Project completes in 4 turns at Cusco. Alexandria capture in progress - Field Gun and Lancer eliminated, Cavillaca spy at 480 network can assist. UseNuke increased to 100% - will deploy nuclear weapons immediately upon Manhattan Project completion. Maximum aggression ensures AI prioritizes Brazilian invasion over defensive operations. Spaceship at 70 maintains science victory pathway as backup if Brazil conquest fails.</td>
#     </tr>
#     <tr>
#       <th id="T_41500_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_41500_row1_col0" class="data row1 col0" >France</td>
#       <td id="T_41500_row1_col1" class="data row1 col1" >405</td>
#       <td id="T_41500_row1_col2" class="data row1 col2" >Conquest</td>
#       <td id="T_41500_row1_col3" class="data row1 col3" >Maintaining maximum aggression profile for final turns. Increased UseNuke to 100 (from 90) to ensure nuclear weapons are deployed immediately upon availability from Advanced Ballistics. All military production and offensive flavors remain at emergency levels to extract maximum territorial gains from Sweden (currently at 50% happiness with combat penalties) and Portugal before Egyptian victory. Defensive flavors maintained at 80 to protect against Portugal's atomic capabilities and Sweden's counterattacks. Zero expansion/diplomacy/culture - pure total war focus until game conclusion.</td>
#     </tr>
#     <tr>
#       <th id="T_41500_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_41500_row2_col0" class="data row2 col0" >Spain</td>
#       <td id="T_41500_row2_col1" class="data row2 col1" >403</td>
#       <td id="T_41500_row2_col2" class="data row2 col2" >Conquest</td>
#       <td id="T_41500_row2_col3" class="data row2 col3" >PEACE EXPLOITATION PHASE: Unexpected forced peace with Egypt (PacifierFlag) created 10-turn preparation window. Nuke/UseNuke increased to 100 - Atomic Theory completes in 8 turns revealing Uranium. Manhattan Project insurance against Thebes' 21-wonder defense. Focus: 1) Finish Celts (Edinburgh capture imminent), 2) Complete nuclear arsenal, 3) Total Egyptian annihilation when peace expires. Air/Airlift/Mobile/Ranged/Naval at 100 for intercontinental rapid deployment to Egyptian theater. Glasgow captured - Celtic campaign nearly complete.</td>
#     </tr>
#     <tr>
#       <th id="T_41500_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_41500_row3_col0" class="data row3 col0" >Assyria</td>
#       <td id="T_41500_row3_col1" class="data row3 col1" >392</td>
#       <td id="T_41500_row3_col2" class="data row3 col2" >Conquest</td>
#       <td id="T_41500_row3_col3" class="data row3 col3" >SURVIVAL MODE - GERMAN BETRAYAL RESPONSE: Germany's invasion is catastrophic. Reduced Offense to 40 (cannot attack superior forces), maintained Defense/CityDefense/Antiair at 100 to survive siege. Science 100 and Nuke/UseNuke 100 are existential priorities - atomic weapons only hope against 13k German military. Production 100 for emergency unit production. Espionage 100 to maintain Florence alliance and protect Kyzyl. Reduced Diplomacy to 90 (lost Lisbon/Sokoto/Buenos Aires to German coups). Naval reduced to 70 (coastal cities threatened by Germany). Focus: Hold cities, survive until nuclear deterrent operational.</td>
#     </tr>
#     <tr>
#       <th id="T_41500_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_41500_row4_col0" class="data row4 col0" >Sweden</td>
#       <td id="T_41500_row4_col1" class="data row4 col1" >413</td>
#       <td id="T_41500_row4_col2" class="data row4 col2" >Conquest</td>
#       <td id="T_41500_row4_col3" class="data row4 col3" >TURN 412 - TOTAL WAR CONFIGURATION: Declared war on Shoshone (5:1 military disadvantage) and Ottomans. Athens at 18HP must fall immediately. Shoshone has Artillery, Machine Guns, Special Forces and Triplanes adjacent to Sigtuna (zone 3173). UseNuke 100 ensures immediate launch capability when Nuclear Fission completes. CityDefense 100 for survival against overwhelming force. Mobilization 100 for emergency unit production. Maintain Offense/Defense/Air/Nuke/Antiair at 100 for desperate defensive stand.</td>
#     </tr>
#     <tr>
#       <th id="T_41500_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_41500_row5_col0" class="data row5 col0" >The Celts</td>
#       <td id="T_41500_row5_col1" class="data row5 col1" >395</td>
#       <td id="T_41500_row5_col2" class="data row5 col2" >Conquest</td>
#       <td id="T_41500_row5_col3" class="data row5 col3" >Brazil's cultural victory timer ticks down to 22 turns - EXISTENTIAL CRISIS. While our military flavors are optimal, UseNuke at 50 is insufficient. Increasing to 100 ensures immediate nuclear deployment upon completing Nuclear Fission, bypassing AI hesitation. Brazil's 11,878 military strength vs our 8,014 means conventional victory is uncertain. Nuclear weapons are our only guaranteed method to: 1) Break Brazil's capital defenses, 2) Destroy their cultural infrastructure, 3) Trigger war weariness to slow their victory progress. Every turn of delay brings Brazil closer to cultural dominance. When we complete Nuclear Fission after Advanced Ballistics, we must strike Brasilia and Rio de Janeiro immediately. Current flavors already prioritize offense (100), mobilization (100), and nuclear arsenal buildup (Nuke: 100) - this completes the strategic triad by ensuring actual deployment. Denmark's defensive pact will trigger when we attack, providing crucial distraction while we focus on Brazil's core cities. This is civilization's final hour - hesitation means defeat.</td>
#     </tr>
#     <tr>
#       <th id="T_41500_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_41500_row6_col0" class="data row6 col0" >Carthage</td>
#       <td id="T_41500_row6_col1" class="data row6 col1" >417</td>
#       <td id="T_41500_row6_col2" class="data row6 col2" >Spaceship</td>
#       <td id="T_41500_row6_col3" class="data row6 col3" >Pure survival mode: Eliminated Offense (0) since attacking is suicide. Maximized UseNuke (100) - must deploy tactical nukes against Aztec XCOM/Modern Armor stacks at Carthago Nova or lose the city. Increased Mobile (80) to prepare for Mechanized Infantry deployment. Maintained max Defense, Antiair (jet attacks are rel
# ================================================================================
#   Qwen-3.5-Simple  (2 / 20 escalations, 10.0%)
# ================================================================================
# <style type="text/css">
# #T_786fe_row0_col3, #T_786fe_row1_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_786fe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_786fe_level0_col0" class="col_heading level0 col0" >civilization</th>
#       <th id="T_786fe_level0_col1" class="col_heading level0 col1" >turn</th>
#       <th id="T_786fe_level0_col2" class="col_heading level0 col2" >grand_strategy</th>
#       <th id="T_786fe_level0_col3" class="col_heading level0 col3" >rationale</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_786fe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_786fe_row0_col0" class="data row0 col0" >Assyria</td>
#       <td id="T_786fe_row0_col1" class="data row0 col1" >484</td>
#       <td id="T_786fe_row0_col2" class="data row0 col2" >Conquest</td>
#       <td id="T_786fe_row0_col3" class="data row0 col3" >TURN 484: CRITICAL - Iroquois declared war on us along with 4 city-state allies (Kabul, Venezia, Prague, Samarkand). We face 5+ enemies simultaneously with military severely outnumbered (our 1,139 vs Iroquois 41k, Ottomans 12k, Aztecs 9k). Maintaining maximum Defense/Mobilization for survival. Nuke flavors at 100% - need nuclear deterrent against overwhelming forces. Iroquois at 46 delegates (needs 43) with 16 turns remaining - existential diplomatic threat. Must conquer their city-state allies to flip delegates while defending our cities. Germany (15) + Mongolia (15) alliance critical to block Iroquois World Congress proposals.</td>
#     </tr>
#     <tr>
#       <th id="T_786fe_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_786fe_row1_col0" class="data row1 col0" >The Zulus</td>
#       <td id="T_786fe_row1_col1" class="data row1 col1" >389</td>
#       <td id="T_786fe_row1_col2" class="data row1 col2" >Conquest</td>
#       <td id="T_786fe_row1_col3" class="data row1 col3" >Final domination push configuration. Offense/Mobilization/Nuke at 100% for maximum military production and nuclear strike capability against Brazil/Babylon/Rome capitals. Air/Antiair at 100/95 to counter enemy bombers and maintain air superiority. Mobile/Ranged at 100/95 for mechanized infantry and bazooka pushes. Production/Science at 100% to sustain war machine and complete Nuclear Fission tree. Espionage at 90% to rig World Congress elections (9 turns remaining, we trail Brazil 16-17). Expansion/Wonder at 0% - no new cities needed, only conquest of remaining 3 capitals.</td>
#     </tr>
#   </tbody>
# </table>

# %%
import os

os.makedirs('nuke', exist_ok=True)

for model, grp in first_nuke.groupby('player_type'):
    total = total_per_model.get(model, len(grp))
    pct = 100 * len(grp) / total

    lines = [
        f'# Turn Use Nuke Rationale — {model}\n\n',
        f'{len(grp)} / {total} players escalated `flavor_use_nuke` to 100 ({pct:.1f}%).\n\n',
        '---\n',
    ]

    for _, row in grp.sort_values('turn').iterrows():
        rationale = str(row.rationale).replace('\n', ' ').strip()
        lines.append(f'\n**{row.civilization}** · Turn {int(row.turn)} · {row.grand_strategy}\n\n')
        lines.append(f'> {rationale}\n')

    slug = model.replace(' ', '_')
    out_path = f'nuke/{slug}.md'
    with open(out_path, 'w', encoding='utf-8') as f:
        f.writelines(lines)
    print(f'Written: {out_path}')

# CSV export
csv_path = 'nuke/nuke_escalations.csv'
first_nuke.sort_values(['game_id', 'player_id', 'turn'])[
    ['game_id', 'player_id', 'turn', 'player_type', 'rationale']
].to_csv(csv_path, index=False)
print(f'Written: {csv_path}  ({len(first_nuke)} rows)')
# Out:
# Written: nuke/Deepseek-3.2-Briefed.md
# Written: nuke/Deepseek-3.2-Simple.md
# Written: nuke/GLM-4.7-Briefed.md
# Written: nuke/GLM-4.7-Simple.md
# Written: nuke/GPT-OSS-120B-Simple.md
# Written: nuke/Kimi-K2.5-Briefed.md
# Written: nuke/Kimi-K2.5-Simple.md
# Written: nuke/Qwen-3.5-Simple.md
# Written: nuke/nuke_escalations.csv  (79 rows)
