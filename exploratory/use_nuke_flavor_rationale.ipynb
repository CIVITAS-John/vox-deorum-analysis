# %% [markdown]
# # Turn Flavor & Rationale Explorer
#
# Explores AI flavor settings and corresponding rationale text from `turn_data.csv`.
# Focus: when does `use_nuke` first reach 100, and what did the AI say?

# %%
import pandas as pd
import numpy as np
import sys
sys.path.insert(0, '..')
from plot_utilities import load_turn_data, setup_notebook_display
setup_notebook_display()

# %%
df = load_turn_data('../turn_data.csv', condition_exclude=['observe-vanilla-standard'])
# Out:
# d:\Cache\Onedrive - Arizona\OneDrive - University of Arizona\Vox Deorum\nlp-2026-tiny-4player\analysis\exploratory\..\plot_utilities.py:412: DtypeWarning: Columns (63,64) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path)
# ✓ Loaded turn data: 776576 rows
# ✓ Filters applied: condition_exclude=['observe-vanilla-standard']
# ✓ Unique conditions: 12
# ✓ Unique player types: 15
# ✓ Turn range: 0 - 500
# ✓ Unique civilizations: 43
#
# Player Type Distribution:
#   Vanilla: 264678 rows (34.1%)
#   GLM-4.7-Simple: 74906 rows (9.6%)
#   GLM-4.7-Briefed: 74906 rows (9.6%)
#   Kimi-K2.5-Simple: 52075 rows (6.7%)
#   Kimi-K2.5-Briefed: 52075 rows (6.7%)
#   GPT-OSS-120B-Briefed: 50355 rows (6.5%)
#   GPT-OSS-120B-Simple: 50355 rows (6.5%)
#   Deepseek-3.2-Briefed: 49080 rows (6.3%)
#   Deepseek-3.2-Simple: 49080 rows (6.3%)
#   Minimax-M2.5-Simple: 17197 rows (2.2%)
#   Minimax-M2.5-Briefed: 17197 rows (2.2%)
#   Sonnet-4.5-Simple: 11192 rows (1.4%)
#   Sonnet-4.5-Briefed: 11192 rows (1.4%)
#   Qwen-3.5-Briefed: 1144 rows (0.1%)
#   Qwen-3.5-Simple: 1144 rows (0.1%)
#
# Condition Distribution:
#   2026-deepseek-v-kimi2-v-glm-standard: 281688 rows (36.3%)
#   2026-oss-v-glm-standard: 223776 rows (28.8%)
#   2026-deepseek-v-kimi2-v-minimax-standard: 66952 rows (8.6%)
#   2026-oss-v-sonnet-standard: 45584 rows (5.9%)
#   2026-oss-v-minimax-standard: 37512 rows (4.8%)
#   2026-deepseek-v-kimi-v-glm-standard: 36560 rows (4.7%)
#   2026-staff-standard: 31176 rows (4.0%)
#   2026-glm-v-kimi2-v-minimax-standard: 13272 rows (1.7%)
#   2026-glm-v-sonnet-standard: 12776 rows (1.6%)
#   2026-oss-v-kimi2-v-minimax-standard: 10688 rows (1.4%)
#   2026-oss-v-qwen-v-minimax-standard: 9152 rows (1.2%)
#   2026-deepseek-v-kimi-v-oss-standard: 7440 rows (1.0%)
#
# ✓ Unique games: 230
#
# Civilization Distribution:
#   Persia: 23710 rows (3.1%)
#   The Netherlands: 23231 rows (3.0%)
#   America: 22714 rows (2.9%)
#   Songhai: 21285 rows (2.7%)
#   Russia: 21126 rows (2.7%)
#   Assyria: 20801 rows (2.7%)
#   Carthage: 20464 rows (2.6%)
#   Brazil: 20267 rows (2.6%)
#   Rome: 20258 rows (2.6%)
#   Denmark: 20062 rows (2.6%)

# %% [markdown]
# ## Flavor overview & first `use_nuke = 100` per game

# %%
flavor_cols = [c for c in df.columns if c.startswith('flavor_')]
print(f'Flavor columns ({len(flavor_cols)}): {flavor_cols}')

changed = df[df['is_changed'] == 1].copy()
print(f'\nTotal rows: {len(df):,}  |  Changed turns: {len(changed):,}')

nuke_esc = changed[changed['flavor_use_nuke'] == 100]

first_nuke = (
    nuke_esc
    .sort_values('turn')
    .groupby(['game_id', 'player_id'], as_index=False)
    .first()
)

print(f'Players who ever set use_nuke=100: {len(first_nuke)}')
pd.set_option('display.max_colwidth', 120)
first_nuke[['player_type', 'civilization', 'turn', 'grand_strategy', 'flavor_use_nuke', 'rationale']].head(10)
# Out:
# Flavor columns (34): ['flavor_offense', 'flavor_defense', 'flavor_mobilization', 'flavor_city_defense', 'flavor_military_training', 'flavor_recon', 'flavor_ranged', 'flavor_mobile', 'flavor_nuke', 'flavor_use_nuke', 'flavor_naval', 'flavor_naval_recon', 'flavor_naval_growth', 'flavor_naval_tile_improvement', 'flavor_air', 'flavor_air_carrier', 'flavor_antiair', 'flavor_airlift', 'flavor_expansion', 'flavor_growth', 'flavor_tile_improvement', 'flavor_infrastructure', 'flavor_production', 'flavor_water_connection', 'flavor_gold', 'flavor_science', 'flavor_culture', 'flavor_happiness', 'flavor_great_people', 'flavor_wonder', 'flavor_religion', 'flavor_diplomacy', 'flavor_spaceship', 'flavor_espionage']
#
# Total rows: 776,576  |  Changed turns: 246,183
# Players who ever set use_nuke=100: 72
#            player_type civilization  turn grand_strategy  flavor_use_nuke  \
# 0  GPT-OSS-120B-Simple       Sweden   344       Conquest            100.0
# 1       GLM-4.7-Simple     Mongolia   408       Conquest            100.0
# 2  Deepseek-3.2-Simple         Siam   445  UnitedNations            100.0
# 3     Kimi-K2.5-Simple     The Inca   372      Spaceship            100.0
# 4  Deepseek-3.2-Simple        Spain   400       Conquest            100.0
# 5     Kimi-K2.5-Simple       France   405       Conquest            100.0
# 6  Deepseek-3.2-Simple         Siam   459  UnitedNations            100.0
# 7     Kimi-K2.5-Simple        Spain   403       Conquest            100.0
# 8    Kimi-K2.5-Briefed        India   378      Spaceship            100.0
# 9     Kimi-K2.5-Simple      Assyria   392       Conquest            100.0
#
#                                                                                                                  rationale
# 0  Maximize our nuclear capabilities and carrier support to decisively strike Polynesian island forts, while maintainin...
# 1  CRITICAL: Portugal completed SS Engine (3rd spaceship part) and CERN - emergency nuclear strike plan. Maximizing Off...
# 2  Maximizing UseNuke to 100 ensures our atomic bombs and future nuclear missiles are used aggressively against The Cel...
# 3  TURN 372: TOTAL WAR POSTURE MAINTAINED. Brazil peace expires in 6 turns - all military resources must prepare for Ri...
# 4  Increase UseNuke to 100 to ensure aggressive nuclear strikes when we initiate war with Russia. Our atomic bomb produ...
# 5  Maintaining maximum aggression profile for final turns. Increased UseNuke to 100 (from 90) to ensure nuclear weapons...
# 6  Adjusting flavors to prioritize counterattacks (Offense 80) and nuclear retaliation (UseNuke 100) given Egypt's use ...
# 7  PEACE EXPLOITATION PHASE: Unexpected forced peace with Egypt (PacifierFlag) created 10-turn preparation window. Nuke...
# 8  EMERGENCY FINAL GAMBIT: Passport System will pass in 2 turns with 46 YES votes (my 'allies' betrayed me). Maya will ...
# 9  SURVIVAL MODE - GERMAN BETRAYAL RESPONSE: Germany's invasion is catastrophic. Reduced Offense to 40 (cannot attack s...

# %%
# Detect turns where flavor_use_nuke transitions TO 100 (wasn't 100 the turn before)
df_sorted = df.sort_values(['game_id', 'player_id', 'turn'])
prev_nuke = df_sorted.groupby(['game_id', 'player_id'])['flavor_use_nuke'].shift(1)

nuke_esc = df_sorted[
    (df_sorted['flavor_use_nuke'] == 100) &
    (prev_nuke < 100)
]

first_nuke = (
    nuke_esc
    .sort_values('turn')
    .groupby(['game_id', 'player_id'], as_index=False)
    .first()
)

print(f'Players who ever set use_nuke=100: {len(first_nuke)}')
first_nuke[['player_type', 'civilization', 'turn', 'grand_strategy', 'flavor_use_nuke', 'rationale']].head(10)
# Out:
# Players who ever set use_nuke=100: 72
#            player_type civilization  turn grand_strategy  flavor_use_nuke  \
# 0  GPT-OSS-120B-Simple       Sweden   344       Conquest            100.0
# 1       GLM-4.7-Simple     Mongolia   408       Conquest            100.0
# 2  Deepseek-3.2-Simple         Siam   445  UnitedNations            100.0
# 3     Kimi-K2.5-Simple     The Inca   372      Spaceship            100.0
# 4  Deepseek-3.2-Simple        Spain   400       Conquest            100.0
# 5     Kimi-K2.5-Simple       France   405       Conquest            100.0
# 6  Deepseek-3.2-Simple         Siam   459  UnitedNations            100.0
# 7     Kimi-K2.5-Simple        Spain   403       Conquest            100.0
# 8    Kimi-K2.5-Briefed        India   378      Spaceship            100.0
# 9     Kimi-K2.5-Simple      Assyria   392       Conquest            100.0
#
#                                                                                                                  rationale
# 0  Maximize our nuclear capabilities and carrier support to decisively strike Polynesian island forts, while maintainin...
# 1  CRITICAL: Portugal completed SS Engine (3rd spaceship part) and CERN - emergency nuclear strike plan. Maximizing Off...
# 2  Maximizing UseNuke to 100 ensures our atomic bombs and future nuclear missiles are used aggressively against The Cel...
# 3  TURN 372: TOTAL WAR POSTURE MAINTAINED. Brazil peace expires in 6 turns - all military resources must prepare for Ri...
# 4  Increase UseNuke to 100 to ensure aggressive nuclear strikes when we initiate war with Russia. Our atomic bomb produ...
# 5  Maintaining maximum aggression profile for final turns. Increased UseNuke to 100 (from 90) to ensure nuclear weapons...
# 6  Adjusting flavors to prioritize counterattacks (Offense 80) and nuclear retaliation (UseNuke 100) given Egypt's use ...
# 7  PEACE EXPLOITATION PHASE: Unexpected forced peace with Egypt (PacifierFlag) created 10-turn preparation window. Nuke...
# 8  EMERGENCY FINAL GAMBIT: Passport System will pass in 2 turns with 46 YES votes (my 'allies' betrayed me). Maya will ...
# 9  SURVIVAL MODE - GERMAN BETRAYAL RESPONSE: Germany's invasion is catastrophic. Reduced Offense to 40 (cannot attack s...

# %%
pd.set_option('display.max_colwidth', None)

cols = ['civilization', 'turn', 'grand_strategy', 'rationale']

left_align = lambda df: df.style.set_properties(subset=['rationale'], **{'text-align': 'left'})

total_per_model = (
    df.groupby('player_type')[['game_id', 'player_id']]
    .apply(lambda g: g.drop_duplicates().shape[0])
)

for model, grp in first_nuke.groupby('player_type'):
    total = total_per_model.get(model, len(grp))
    pct = 100 * len(grp) / total
    print(f'\n{"="*80}')
    print(f'  {model}  ({len(grp)} / {total} escalations, {pct:.1f}%)')
    print(f'{"="*80}')
    display(left_align(grp[cols].reset_index(drop=True)))
# Out:
# ================================================================================
#   Deepseek-3.2-Briefed  (2 / 115 escalations, 1.7%)
# ================================================================================
# <style type="text/css">
# #T_b0542_row0_col3, #T_b0542_row1_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_b0542">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b0542_level0_col0" class="col_heading level0 col0" >civilization</th>
#       <th id="T_b0542_level0_col1" class="col_heading level0 col1" >turn</th>
#       <th id="T_b0542_level0_col2" class="col_heading level0 col2" >grand_strategy</th>
#       <th id="T_b0542_level0_col3" class="col_heading level0 col3" >rationale</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0542_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b0542_row0_col0" class="data row0 col0" >The Maya</td>
#       <td id="T_b0542_row0_col1" class="data row0 col1" >391</td>
#       <td id="T_b0542_row0_col2" class="data row0 col2" >Conquest</td>
#       <td id="T_b0542_row0_col3" class="data row0 col3" >Egypt is 6/6 on cultural victory and India is nearing diplomatic victory. We must accelerate nuclear production to strike Thebes and disrupt Egypt's tourism. Increasing Nuke and UseNuke to 100 ensures maximum priority for atomic bomb construction and deployment. High Production and Gold flavors support rushing Manhattan Project and buying bombs if possible. Espionage at 100 aids sabotage of cultural progress. Maintaining high military flavors prepares for conventional assaults on Egypt and India.</td>
#     </tr>
#     <tr>
#       <th id="T_b0542_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b0542_row1_col0" class="data row1 col0" >Poland</td>
#       <td id="T_b0542_row1_col1" class="data row1 col1" >387</td>
#       <td id="T_b0542_row1_col2" class="data row1 col2" >Conquest</td>
#       <td id="T_b0542_row1_col3" class="data row1 col3" >We are in the final push for domination victory. We must capture Moson Kahni and London. To achieve this, we need to prioritize building transport ships for amphibious assault and achieve air superiority. Maximizing flavors for naval, air, mobile, and nuclear units ensures the in-game AI focuses production on these critical areas. Deprioritizing non-essential areas like culture, religion, and expansion concentrates our efforts on military conquest.</td>
#     </tr>
#   </tbody>
# </table>
# ================================================================================
#   Deepseek-3.2-Simple  (20 / 115 escalations, 17.4%)
# ================================================================================
# <style type="text/css">
# #T_fc250_row0_col3, #T_fc250_row1_col3, #T_fc250_row2_col3, #T_fc250_row3_col3, #T_fc250_row4_col3, #T_fc250_row5_col3, #T_fc250_row6_col3, #T_fc250_row7_col3, #T_fc250_row8_col3, #T_fc250_row9_col3, #T_fc250_row10_col3, #T_fc250_row11_col3, #T_fc250_row12_col3, #T_fc250_row13_col3, #T_fc250_row14_col3, #T_fc250_row15_col3, #T_fc250_row16_col3, #T_fc250_row17_col3, #T_fc250_row18_col3, #T_fc250_row19_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_fc250">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc250_level0_col0" class="col_heading level0 col0" >civilization</th>
#       <th id="T_fc250_level0_col1" class="col_heading level0 col1" >turn</th>
#       <th id="T_fc250_level0_col2" class="col_heading level0 col2" >grand_strategy</th>
#       <th id="T_fc250_level0_col3" class="col_heading level0 col3" >rationale</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc250_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fc250_row0_col0" class="data row0 col0" >Siam</td>
#       <td id="T_fc250_row0_col1" class="data row0 col1" >445</td>
#       <td id="T_fc250_row0_col2" class="data row0 col2" >UnitedNations</td>
#       <td id="T_fc250_row0_col3" class="data row0 col3" >Maximizing UseNuke to 100 ensures our atomic bombs and future nuclear missiles are used aggressively against The Celts' military concentrations and cities, given their overwhelming advantage. Maintaining high Air, Naval, and Nuke flavors sustains our technological edge and production focus. Diplomacy and Espionage at 100 are critical for city-state alliances and spy missions to gain delegates for diplomatic victory. Gold and Science remain top priorities to fund our war effort and tech progression. Other military flavors are tuned for a multi-front defensive-offensive war against The Celts, Germany, and Ethiopia.</td>
#     </tr>
#     <tr>
#       <th id="T_fc250_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fc250_row1_col0" class="data row1 col0" >Spain</td>
#       <td id="T_fc250_row1_col1" class="data row1 col1" >400</td>
#       <td id="T_fc250_row1_col2" class="data row1 col2" >Conquest</td>
#       <td id="T_fc250_row1_col3" class="data row1 col3" >Increase UseNuke to 100 to ensure aggressive nuclear strikes when we initiate war with Russia. Our atomic bomb production is nearing completion, and we want to leverage our nuclear arsenal decisively for swift capital captures.</td>
#     </tr>
#     <tr>
#       <th id="T_fc250_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fc250_row2_col0" class="data row2 col0" >Siam</td>
#       <td id="T_fc250_row2_col1" class="data row2 col1" >459</td>
#       <td id="T_fc250_row2_col2" class="data row2 col2" >UnitedNations</td>
#       <td id="T_fc250_row2_col3" class="data row2 col3" >Adjusting flavors to prioritize counterattacks (Offense 80) and nuclear retaliation (UseNuke 100) given Egypt's use of nukes. Reducing Growth to 50 reflects wartime constraints on expansion. Increasing Culture to 50 helps accelerate policy acquisition for crucial benefits. Maintaining strong defense, military production, and diplomacy focus.</td>
#     </tr>
#     <tr>
#       <th id="T_fc250_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fc250_row3_col0" class="data row3 col0" >France</td>
#       <td id="T_fc250_row3_col1" class="data row3 col1" >413</td>
#       <td id="T_fc250_row3_col2" class="data row3 col2" >Conquest</td>
#       <td id="T_fc250_row3_col3" class="data row3 col3" >We are researching Atomic Theory next to unlock nuclear weapons. Setting Nuke and UseNuke flavors to 100 ensures we prioritize building nukes and are willing to use them strategically once available. This will be crucial for breaking Germany's heavily fortified coastal capitals (Berlin and Beijing) and accelerating the endgame. Other military flavors remain high to sustain our overwhelming conventional advantage.</td>
#     </tr>
#     <tr>
#       <th id="T_fc250_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fc250_row4_col0" class="data row4 col0" >Denmark</td>
#       <td id="T_fc250_row4_col1" class="data row4 col1" >456</td>
#       <td id="T_fc250_row4_col2" class="data row4 col2" >Conquest</td>
#       <td id="T_fc250_row4_col3" class="data row4 col3" >Maintain aggressive military focus on capturing Polish, Roman, and soon Indonesian capitals. Increased UseNuke and Nuke to 100 to prioritize strategic nuclear strikes against enemy concentrations and cities, leveraging our atomic bomb stockpile. Air raised to 100 to maximize bomber and fighter effectiveness. All other high-priority flavors (Production, Science, Gold, Happiness, Diplomacy) kept at peak to support war economy, research, city-state alliances, and combat unhappiness penalty.</td>
#     </tr>
#     <tr>
#       <th id="T_fc250_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fc250_row5_col0" class="data row5 col0" >Greece</td>
#       <td id="T_fc250_row5_col1" class="data row5 col1" >401</td>
#       <td id="T_fc250_row5_col2" class="data row5 col2" >Conquest</td>
#       <td id="T_fc250_row5_col3" class="data row5 col3" >Maximize nuclear weapon production and willingness to use them to break enemy defenses and accelerate domination victory. All other military flavors remain high to sustain multi-front warfare.</td>
#     </tr>
#     <tr>
#       <th id="T_fc250_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fc250_row6_col0" class="data row6 col0" >Byzantium</td>
#       <td id="T_fc250_row6_col1" class="data row6 col1" >405</td>
#       <td id="T_fc250_row6_col2" class="data row6 col2" >Culture</td>
#       <td id="T_fc250_row6_col3" class="data row6 col3" >The Aztecs have captured Shanghai and war resumes next turn. We must prepare for an overwhelming assault. Setting UseNuke to 100 ensures we will employ nuclear weapons defensively if necessary to halt their advance. MilitaryTraining at 100 prioritizes unit upgrades and quality, giving our outnumbered forces a fighting chance.</td>
#     </tr>
#     <tr>
#       <th id="T_fc250_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fc250_row7_col0" class="data row7 col0" >The Ottomans</td>
#       <td id="T_fc250_row7_col1" class="data row7 col1" >485</td>
#       <td id="T_fc250_row7_col2" class="data row7 col2" >Conquest</td>
#       <td id="T_fc250_row7_col3" class="data row7 col3" >We are engaged in a multi-front war against superior forces. Increasing Ranged and Mobile ensures our bazooka and mechanized infantry production is prioritized for defense and counterattacks. Setting UseNuke to 100 guarantees we deploy nuclear weapons as soon as available to cripple The Huns' armies. Reducing Culture and Diplomacy reallocates focus to immediate military needs without compromising essential city-state relations (Monaco, Lisbon). Grand Strategy remains Conquest as nuclear strikes may enable capital captures, though we keep science victory as a backup.</td>
#     </tr>
#     <tr>
#       <th id="T_fc250_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fc250_row8_col0" class="data row8 col0" >The Inca</td>
#       <td id="T_fc250_row8_col1" class="data row8 col1" >433</td>
#       <td id="T_fc250_row8_col2" class="data row8 col2" >Conquest</td>
#       <td id="T_fc250_row8_col3" class="data row8 col3" >We now have atomic bombs produced at Te-Moak and Agaidika. Setting UseNuke to 100 ensures the AI will employ them against high-defense capitals, especially Vienna (74 defense) and Stockholm (109). This is crucial to break through enemy fortifications and accelerate our domination victory. Other military flavors remain maxed to sustain multi-front offensives.</td>
#     </tr>
#     <tr>
#       <th id="T_fc250_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fc250_row9_col0" class="data row9 col0" >Assyria</td>
#       <td id="T_fc250_row9_col1" class="data row9 col1" >453</td>
#       <td id="T_fc250_row9_col2"
# ================================================================================
#   GLM-4.7-Briefed  (2 / 177 escalations, 1.1%)
# ================================================================================
# <style type="text/css">
# #T_fa4b9_row0_col3, #T_fa4b9_row1_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_fa4b9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fa4b9_level0_col0" class="col_heading level0 col0" >civilization</th>
#       <th id="T_fa4b9_level0_col1" class="col_heading level0 col1" >turn</th>
#       <th id="T_fa4b9_level0_col2" class="col_heading level0 col2" >grand_strategy</th>
#       <th id="T_fa4b9_level0_col3" class="col_heading level0 col3" >rationale</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa4b9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fa4b9_row0_col0" class="data row0 col0" >The Huns</td>
#       <td id="T_fa4b9_row0_col1" class="data row0 col1" >409</td>
#       <td id="T_fa4b9_row0_col2" class="data row0 col2" >Conquest</td>
#       <td id="T_fa4b9_row0_col3" class="data row0 col3" >MULTI-THEATER EMERGENCY RESPONSE for Shoshone Cultural Victory (6 turns) and Treasury Crisis: Offense 95, Mobile 95, Nuke 100, UseNuke 100 - maximum priority on Shoshone disruption via nuclear/conventional assault in 6-turn window. Gold increased to 85 (from 70) - CRITICAL address of treasury exhaustion (~8 turns) through uranium sales + gem liquidation to survive until Manhattan completion. Defense reduced to 70 (from 75), CityDefense to 70 (from 80) - resources diverted from secondary holdings to Shoshone front. Diplomacy 95 (from 90) - enhanced priority on Carthage peace for delegate bloc and potential sanction relief. Science 100 maintained - fundamental for nuclear capability and keeping tech parity. This is all-hands-on-deck existential threat response.</td>
#     </tr>
#     <tr>
#       <th id="T_fa4b9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fa4b9_row1_col0" class="data row1 col0" >Mongolia</td>
#       <td id="T_fa4b9_row1_col1" class="data row1 col1" >394</td>
#       <td id="T_fa4b9_row1_col2" class="data row1 col2" >Conquest</td>
#       <td id="T_fa4b9_row1_col3" class="data row1 col3" >ETHIOPIA VICTORY IMMINENT - ALL-ONS: Ethiopia has 7/7 civs influenced and can win Cultural Victory ANY turn. Maximized Nuke and UseNuke to 100 (nuclear weapons are our only realistic option to destroy their tourism infrastructure given 30+ tile distance). Science maximized to 100 for urgent race to Nuclear Fission and atomic capabilities. Airlift increased to 80 for rapid troop deployment once forward bases established. Offense, Mobile, Air, Mobilization, Production all at 100 for maximum war readiness. Recon at 30 to find Ethiopian cities for nuclear targeting. Navy increased to 60 (from 50) for potential coastal delivery of nuclear weapons or establishing beachheads. Defense at 50 to conserve resources for offense. Every turn we delay is another turn Ethiopia might win - aggressive preparation for nuclear strike is the only viable path.</td>
#     </tr>
#   </tbody>
# </table>
# ================================================================================
#   GLM-4.7-Simple  (8 / 177 escalations, 4.5%)
# ================================================================================
# <style type="text/css">
# #T_f41e5_row0_col3, #T_f41e5_row1_col3, #T_f41e5_row2_col3, #T_f41e5_row3_col3, #T_f41e5_row4_col3, #T_f41e5_row5_col3, #T_f41e5_row6_col3, #T_f41e5_row7_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_f41e5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f41e5_level0_col0" class="col_heading level0 col0" >civilization</th>
#       <th id="T_f41e5_level0_col1" class="col_heading level0 col1" >turn</th>
#       <th id="T_f41e5_level0_col2" class="col_heading level0 col2" >grand_strategy</th>
#       <th id="T_f41e5_level0_col3" class="col_heading level0 col3" >rationale</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f41e5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f41e5_row0_col0" class="data row0 col0" >Mongolia</td>
#       <td id="T_f41e5_row0_col1" class="data row0 col1" >408</td>
#       <td id="T_f41e5_row0_col2" class="data row0 col2" >Conquest</td>
#       <td id="T_f41e5_row0_col3" class="data row0 col3" >CRITICAL: Portugal completed SS Engine (3rd spaceship part) and CERN - emergency nuclear strike plan. Maximizing Offense/Mobilization/Nuke/UseNuke to 100 for Portugal theater operations. Science and Production at 100 to rush Advanced Ballistics and nuclear missile production before Portugal achieves nuclear superiority. Air at 95 for Golden Age bomber operations starting in 2 turns. Diplomacy maintained for coalition coordination (Germany must conduct ground invasion alongside our nuclear strikes). Defense reduced to 40 - total war mode acceptable given Portugal's multi-victory threat requiring breaking through before they complete spaceship.</td>
#     </tr>
#     <tr>
#       <th id="T_f41e5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f41e5_row1_col0" class="data row1 col0" >Sweden</td>
#       <td id="T_f41e5_row1_col1" class="data row1 col1" >427</td>
#       <td id="T_f41e5_row1_col2" class="data row1 col2" >Conquest</td>
#       <td id="T_f41e5_row1_col3" class="data row1 col3" >MAXIMUM OFFENSE: Iroquois Cultural Victory in 2 turns. Nuke flavor increased to 95, UseNuke to MAXIMUM 100 - nuclear strikes now acceptable if Stealth Bomber bombardment fails to destroy Iroquois cultural infrastructure. Science to 100 - Lasers research critical for Nuclear Missile capability as final deterrent. Offense/Mobilization/Ranged/Mobile/Air all at 100 - maximum military pressure on Iroquois cities. Espionage 95 - critical intelligence on Iroquois cities with tourism wonders. Air 100 - 2 new Stealth Bombers completed (ID 19453, 19454), need immediate deployment against Iroquois cultural targets. Gold 95 - funding unit purchases/builds for war. Lasers technology means Nuclear Missiles available in ~3-4 turns - must prepare for nuclear option if conventional assault cannot prevent Iroquois victory by turn 428.</td>
#     </tr>
#     <tr>
#       <th id="T_f41e5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f41e5_row2_col0" class="data row2 col0" >America</td>
#       <td id="T_f41e5_row2_col1" class="data row2 col1" >499</td>
#       <td id="T_f41e5_row2_col2" class="data row2 col2" >Spaceship</td>
#       <td id="T_f41e5_row2_col3" class="data row2 col3" >Maximum Science (100) and Production (100) to accelerate Stealth research and subsequent Stealth Bomber construction for air parity. Air (100), Defense (100), Antiair (100), and CityDefense (85) address existential threat from Russia's 8 Stealth Bombers by prioritizing air defense infrastructure and protecting homeland. UseNuke (100) and Nuke (100) maintain nuclear deterrence posture after Russia's 2 SS Boosters - Russia must understand that launching would trigger our response despite lacking uranium stockpile. Espionage (100) maxed to monitor Russian spaceship part production in Moscow, Yekaterinburg, and key cities - our 10 spies in Russian cities provide critical intelligence on their victory timeline. Diplomacy reduced to 5 since World Congress voting is now; alliances with England and The Celts (Autocracy-aligned) should naturally align against Russia's UN proposal. Spaceship flavor set to 0 as Stealth research takes immediate precedence - spaceship parts scheduled once production capacity supports parts with Stealth Bomber protection.</td>
#     </tr>
#     <tr>
#       <th id="T_f41e5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f41e5_row3_col0" class="data row3 col0" >Songhai</td>
#       <td id="T_f41e5_row3_col1" class="data row3 col1" >411</td>
#       <td id="T_f41e5_row3_col2" class="data row3 col2" >UnitedNations</td>
#       <td id="T_f41e5_row3_col3" class="data row3 col3" >EXISTENTIAL DEFENSE AGAINST RUSSIAN DIPLOMATIC DOMINANCE - UN vote in 10 turns with Russia at 95% victory (40 delegates vs blocking coalition 43). Maintaining UnitedNations grand strategy - abandoning now wastes diplomatic investment when Spain alliance (30 delegates) + my 13 + vassals 13 = 56 votes barely blocks Russia's 40. Just need to HOLD for 10 turns. Adjustments: Defense/CityDefense/Antiair +2 each (97) to prepare for Russian air/naval escalation (Jet Fighter produced). Production +5 (87) to accelerate factories, military academies, nuclear infrastructure after Workers' Faculties in 2 turns. Gold +5 (74) for emergency defensive purchases. Diplomacy +18 (100) maximum - urgency to maintain Spain alliance, potentially reposition spies. Science maintained at 100 - primary path to Nuclear Fission (4 turns) for atomic deterrent against Russia's 9x military advantage. Nuke/UseNuke remain 100 - nuclear development remains emergency priority. Air +5 (61) to counter Russian air superiority. Naval +5 (75) after destroyer loss to Russian submarines. Espionage +5 (95) for critical city-state election rigging counter-intelligence. Offense/Ranged/Mobile unchanged - no offensive capability against Russia's superior forces. Goal: SURVIVE 10 turns to block Russian diplomatic victory, accelerate nuclear deterrent as backup, strengthen defensive lines.</td>
#     </tr>
#     <tr>
#       <th id="T_f41e5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f41e5_row4_col0" class="data row4 col0" >Songhai</td>
#       <td id="T_f41e5_row4_col1" class="data row4 col1" >457</td>
#       <td id="T_f41e5_row4_col2" class="data row4 col2" >UnitedNations</td>
#       <td id="T_f41e5_row4_col3" class="data row4 col3" >Continuing United Nations strategy with defense emphasis ahead of nuclear capability. Nuclear Fission completes in 2 turns - Atomic Bombs provide deterrence. Defense increased to 90 (from 85) - our fortified positions are holding but America's military advantage requires stronger defensive posture. Antiair increased to 95 (from 90) - critical after losing Heavy Bomber to American interception; need stronger air defense. Mobilization increased to 55 (from 50) - accelerate military production including atomic infrastructure. Air at 90 continues successful bomber-interceptor tactics. Gold at 100 maximizes economy for unit purchases and city-state influence. Diplomacy at 100 remains critical for World Congress coalition against America's 30 delegates (voting in 5 turns). Nuke and UseNuke remain 100 - once Nuclear Fission completes, atomic weapons become priority deterrent. Science 85 maintains tech pace. Offense stays 40 - continue defensive attrition war until nuclear capability achieved.</td>
#     </tr>
#     <tr>
#       <th id="T_f41e5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f41e5_row5_col0" class="data row5 col0" >America</td>
#       <td id="T_f41e5_row5_col1" class="data row5 col1" >370</td>
#       <td id="T_f41e5_row5_col2" class="data row5 col2" >Conquest</td>
#       <td id="T_f41e5_row5_col3" class="data row5 col3" >CRISIS MODE - Chicago at CRITICAL 28 HP after tank attacks, Washington taking 300+ naval bombardment damage. Shoshone built Strategic Defense System in Moson Kahni - nuclear interception capability developing. DRAMATICALLY reduced Offense (20→10) - no attacki
# ================================================================================
#   GPT-OSS-120B-Simple  (2 / 120 escalations, 1.7%)
# ================================================================================
# <style type="text/css">
# #T_b5c82_row0_col3, #T_b5c82_row1_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_b5c82">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b5c82_level0_col0" class="col_heading level0 col0" >civilization</th>
#       <th id="T_b5c82_level0_col1" class="col_heading level0 col1" >turn</th>
#       <th id="T_b5c82_level0_col2" class="col_heading level0 col2" >grand_strategy</th>
#       <th id="T_b5c82_level0_col3" class="col_heading level0 col3" >rationale</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b5c82_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b5c82_row0_col0" class="data row0 col0" >Sweden</td>
#       <td id="T_b5c82_row0_col1" class="data row0 col1" >344</td>
#       <td id="T_b5c82_row0_col2" class="data row0 col2" >Conquest</td>
#       <td id="T_b5c82_row0_col3" class="data row0 col3" >Maximize our nuclear capabilities and carrier support to decisively strike Polynesian island forts, while maintaining our current aggressive conquest posture and strong production, gold, and happiness engines.</td>
#     </tr>
#     <tr>
#       <th id="T_b5c82_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b5c82_row1_col0" class="data row1 col0" >Assyria</td>
#       <td id="T_b5c82_row1_col1" class="data row1 col1" >364</td>
#       <td id="T_b5c82_row1_col2" class="data row1 col2" >Conquest</td>
#       <td id="T_b5c82_row1_col3" class="data row1 col3" >Maintain the aggressive Conquest strategy while boosting nuclear capability and espionage to counter Rome's nuclear strike and spy activity. Keep production and mobilization at maximum to replace losses quickly and sustain offensive pressure on hostile capitals.</td>
#     </tr>
#   </tbody>
# </table>
# ================================================================================
#   Kimi-K2.5-Briefed  (11 / 122 escalations, 9.0%)
# ================================================================================
# <style type="text/css">
# #T_231e7_row0_col3, #T_231e7_row1_col3, #T_231e7_row2_col3, #T_231e7_row3_col3, #T_231e7_row4_col3, #T_231e7_row5_col3, #T_231e7_row6_col3, #T_231e7_row7_col3, #T_231e7_row8_col3, #T_231e7_row9_col3, #T_231e7_row10_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_231e7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_231e7_level0_col0" class="col_heading level0 col0" >civilization</th>
#       <th id="T_231e7_level0_col1" class="col_heading level0 col1" >turn</th>
#       <th id="T_231e7_level0_col2" class="col_heading level0 col2" >grand_strategy</th>
#       <th id="T_231e7_level0_col3" class="col_heading level0 col3" >rationale</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_231e7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_231e7_row0_col0" class="data row0 col0" >India</td>
#       <td id="T_231e7_row0_col1" class="data row0 col1" >378</td>
#       <td id="T_231e7_row0_col2" class="data row0 col2" >Spaceship</td>
#       <td id="T_231e7_row0_col3" class="data row0 col3" >EMERGENCY FINAL GAMBIT: Passport System will pass in 2 turns with 46 YES votes (my 'allies' betrayed me). Maya will get 50% tourism boost and become Influential over me immediately - cultural victory is inevitable in 2-3 turns. ONLY HOPE: Science victory before Maya's cultural victory triggers. Need to purchase Great Scientists IMMEDIATELY with Faith (180/turn), rush to Information Era, build spaceship parts. Also preparing maximum military mobilization - if I'm going to lose, I take Maya down with me through nuclear annihilation. Total war footing - no defense, all offense, all science.</td>
#     </tr>
#     <tr>
#       <th id="T_231e7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_231e7_row1_col0" class="data row1 col0" >Rome</td>
#       <td id="T_231e7_row1_col1" class="data row1 col1" >315</td>
#       <td id="T_231e7_row1_col2" class="data row1 col2" >Conquest</td>
#       <td id="T_231e7_row1_col3" class="data row1 col3" >FINAL GAMBLE - Indonesia wins in 12 turns. Maximum priority to Naval and Airlift for immediate unit transport to Indonesian theater. Nuke 100/UseNuke 100 - we MUST build nuclear weapons if possible, only realistic way to destroy cities and tourism infrastructure before victory. Science 100 to reach nuclear tech faster. Espionage 100 - spies MUST target cultural/tourism buildings in Jakarta/Denpasar/Makassar to reduce tourism output directly. Abandoning Denmark/England fronts entirely - all units to Indonesia NOW.</td>
#     </tr>
#     <tr>
#       <th id="T_231e7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_231e7_row2_col0" class="data row2 col0" >Ethiopia</td>
#       <td id="T_231e7_row2_col1" class="data row2 col1" >436</td>
#       <td id="T_231e7_row2_col2" class="data row2 col2" >Spaceship</td>
#       <td id="T_231e7_row2_col3" class="data row2 col3" >T435 GREECE CULTURAL VICTORY CRISIS: Greece 6 turns from victory (Turn 441). Shift to emergency mode - increase Nuke/UseNuke to 100 (Manhattan Project urgency), Offense to 30 (may need to attack Greece to stop victory), Mobilization to 50 (military production). Keep Science/Production/Gold at 100 for Spaceport completion. Espionage to 60 (spy disruption on Greece). Must acquire Uranium ASAP - sell Aluminum+Oil immediately.</td>
#     </tr>
#     <tr>
#       <th id="T_231e7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_231e7_row3_col0" class="data row3 col0" >The Celts</td>
#       <td id="T_231e7_row3_col1" class="data row3 col1" >427</td>
#       <td id="T_231e7_row3_col2" class="data row3 col2" >Conquest</td>
#       <td id="T_231e7_row3_col3" class="data row3 col3" >TURN 426 TOTAL WAR POSTURE: American declaration requires immediate military mobilization. Offense 80 and Mobile 80 to exploit America's distant/weak military position. Nuke/UseNuke 100 as final deterrent if India approaches victory. Culture 100 maximum priority - must generate tourism to counter India's influence. Production 90 for emergency unit purchases with 2516 gold treasury. Defense 50 to guard against potential American DP response (though briefing confirms no American units near borders).</td>
#     </tr>
#     <tr>
#       <th id="T_231e7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_231e7_row4_col0" class="data row4 col0" >The Zulus</td>
#       <td id="T_231e7_row4_col1" class="data row4 col1" >489</td>
#       <td id="T_231e7_row4_col2" class="data row4 col2" >Culture</td>
#       <td id="T_231e7_row4_col3" class="data row4 col3" >CULTURE VICTORY SPRINT WITH NUCLEAR ELIMINATION: Songhai diplomatic victory on Turn 489 is EXISTENTIAL. Must capture Gao THIS TURN using ICBM+nukes to prevent game loss, while simultaneously rushing cultural victory (4 turns to influential over Japan/Songhai). Maximum Offense/Mobilization/Air/Nuke/UseNuke flavors ensure tactical AI prioritizes immediate nuclear strike on Gao and mass bomber deployment. Culture at 100 to maximize tourism conversion. Gold at 80 for emergency unit upgrades/purchases. Production at 100 for culture buildings/units. Disable all long-term flavors (Expansion, Science, Spaceship) - this is win-or-die emergency.</td>
#     </tr>
#     <tr>
#       <th id="T_231e7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_231e7_row5_col0" class="data row5 col0" >China</td>
#       <td id="T_231e7_row5_col1" class="data row5 col1" >335</td>
#       <td id="T_231e7_row5_col2" class="data row5 col2" >Conquest</td>
#       <td id="T_231e7_row5_col3" class="data row5 col3" >NUCLEAR EMERGENCY - BRAZIL WINS IN 4 TURNS: Maximum crisis flavors. Nuke/UseNuke 100 for instant strike capability if we have any. Espionage 100 to steal Great Works or disrupt Brazil. Diplomacy 100 for emergency resource trades. Gold 90 to buy anything available. Production 100 for immediate unit building if we get Coal. Airlift 80 for rapid deployment. Defense reduced to 20 - we need OFFENSE to survive. This is Hail Mary time.</td>
#     </tr>
#     <tr>
#       <th id="T_231e7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_231e7_row6_col0" class="data row6 col0" >Sweden</td>
#       <td id="T_231e7_row6_col1" class="data row6 col1" >392</td>
#       <td id="T_231e7_row6_col2" class="data row6 col2" >Spaceship</td>
#       <td id="T_231e7_row6_col3" class="data row6 col3" >SURVIVAL FLAVOR MATRIX: Grand Strategy Spaceship maintains - we have NO other path except Science Victory before Spain's culture wins or launches spaceship. Defense 100 is maximum - Antium at 23 HP requires every defensive priority. Air 100 still critical - Aerodrome MUST be next build in Stockholm. Production 100 enables rapid Landship/AA gun construction. Nuke 100/UseNuke 100 - Spain's cultural dominance (287% over us) and Apollo completion means conventional war is unwinnable. Nuclear weapons are only asymmetric option to destroy their spaceship parts or Dreadnought fleets. Offense 0 - we cannot attack, only defend and deter.</td>
#     </tr>
#     <tr>
#       <th id="T_231e7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_231e7_row7_col0" class="data row7 col0" >France</td>
#       <td id="T_231e7_row7_col1" class="data row7 col1" >473</td>
#       <td id="T_231e7_row7_col2" class="data row7 col2" >Spaceship</td>
#       <td id="T_231e7_row7_col3" class="data row7 col3" >WC VOTE CRISIS + NUCLEAR DETERRENT: Diplomacy maxed to 100 to ensure immediate completion of Utica tribute quest from Riga (securing +3 critical delegates before WC vote). Nuke/UseNuke at 100 for immediate deterrent deployment once platform acquired. Science/Spaceship/Production maintained at high priority for Apollo catch-up after WC resolved. Naval increased to 60 for Battleship/Carrier construction as nuclear platform. Reduced Culture/Religion/Wonder to minimum to focus resources on existential priorities.</td>
#     </tr>
#     <tr>
#       <th id="T_231e7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id=
# ================================================================================
#   Kimi-K2.5-Simple  (27 / 122 escalations, 22.1%)
# ================================================================================
# <style type="text/css">
# #T_cb625_row0_col3, #T_cb625_row1_col3, #T_cb625_row2_col3, #T_cb625_row3_col3, #T_cb625_row4_col3, #T_cb625_row5_col3, #T_cb625_row6_col3, #T_cb625_row7_col3, #T_cb625_row8_col3, #T_cb625_row9_col3, #T_cb625_row10_col3, #T_cb625_row11_col3, #T_cb625_row12_col3, #T_cb625_row13_col3, #T_cb625_row14_col3, #T_cb625_row15_col3, #T_cb625_row16_col3, #T_cb625_row17_col3, #T_cb625_row18_col3, #T_cb625_row19_col3, #T_cb625_row20_col3, #T_cb625_row21_col3, #T_cb625_row22_col3, #T_cb625_row23_col3, #T_cb625_row24_col3, #T_cb625_row25_col3, #T_cb625_row26_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_cb625">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb625_level0_col0" class="col_heading level0 col0" >civilization</th>
#       <th id="T_cb625_level0_col1" class="col_heading level0 col1" >turn</th>
#       <th id="T_cb625_level0_col2" class="col_heading level0 col2" >grand_strategy</th>
#       <th id="T_cb625_level0_col3" class="col_heading level0 col3" >rationale</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb625_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cb625_row0_col0" class="data row0 col0" >The Inca</td>
#       <td id="T_cb625_row0_col1" class="data row0 col1" >372</td>
#       <td id="T_cb625_row0_col2" class="data row0 col2" >Spaceship</td>
#       <td id="T_cb625_row0_col3" class="data row0 col3" >TURN 372: TOTAL WAR POSTURE MAINTAINED. Brazil peace expires in 6 turns - all military resources must prepare for Rio de Janeiro assault. Heavy Bomber lost to Alexandria interception but Ollantaytambo produces replacement in 1 turn. Manhattan Project completes in 4 turns at Cusco. Alexandria capture in progress - Field Gun and Lancer eliminated, Cavillaca spy at 480 network can assist. UseNuke increased to 100% - will deploy nuclear weapons immediately upon Manhattan Project completion. Maximum aggression ensures AI prioritizes Brazilian invasion over defensive operations. Spaceship at 70 maintains science victory pathway as backup if Brazil conquest fails.</td>
#     </tr>
#     <tr>
#       <th id="T_cb625_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cb625_row1_col0" class="data row1 col0" >France</td>
#       <td id="T_cb625_row1_col1" class="data row1 col1" >405</td>
#       <td id="T_cb625_row1_col2" class="data row1 col2" >Conquest</td>
#       <td id="T_cb625_row1_col3" class="data row1 col3" >Maintaining maximum aggression profile for final turns. Increased UseNuke to 100 (from 90) to ensure nuclear weapons are deployed immediately upon availability from Advanced Ballistics. All military production and offensive flavors remain at emergency levels to extract maximum territorial gains from Sweden (currently at 50% happiness with combat penalties) and Portugal before Egyptian victory. Defensive flavors maintained at 80 to protect against Portugal's atomic capabilities and Sweden's counterattacks. Zero expansion/diplomacy/culture - pure total war focus until game conclusion.</td>
#     </tr>
#     <tr>
#       <th id="T_cb625_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cb625_row2_col0" class="data row2 col0" >Spain</td>
#       <td id="T_cb625_row2_col1" class="data row2 col1" >403</td>
#       <td id="T_cb625_row2_col2" class="data row2 col2" >Conquest</td>
#       <td id="T_cb625_row2_col3" class="data row2 col3" >PEACE EXPLOITATION PHASE: Unexpected forced peace with Egypt (PacifierFlag) created 10-turn preparation window. Nuke/UseNuke increased to 100 - Atomic Theory completes in 8 turns revealing Uranium. Manhattan Project insurance against Thebes' 21-wonder defense. Focus: 1) Finish Celts (Edinburgh capture imminent), 2) Complete nuclear arsenal, 3) Total Egyptian annihilation when peace expires. Air/Airlift/Mobile/Ranged/Naval at 100 for intercontinental rapid deployment to Egyptian theater. Glasgow captured - Celtic campaign nearly complete.</td>
#     </tr>
#     <tr>
#       <th id="T_cb625_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cb625_row3_col0" class="data row3 col0" >Assyria</td>
#       <td id="T_cb625_row3_col1" class="data row3 col1" >392</td>
#       <td id="T_cb625_row3_col2" class="data row3 col2" >Conquest</td>
#       <td id="T_cb625_row3_col3" class="data row3 col3" >SURVIVAL MODE - GERMAN BETRAYAL RESPONSE: Germany's invasion is catastrophic. Reduced Offense to 40 (cannot attack superior forces), maintained Defense/CityDefense/Antiair at 100 to survive siege. Science 100 and Nuke/UseNuke 100 are existential priorities - atomic weapons only hope against 13k German military. Production 100 for emergency unit production. Espionage 100 to maintain Florence alliance and protect Kyzyl. Reduced Diplomacy to 90 (lost Lisbon/Sokoto/Buenos Aires to German coups). Naval reduced to 70 (coastal cities threatened by Germany). Focus: Hold cities, survive until nuclear deterrent operational.</td>
#     </tr>
#     <tr>
#       <th id="T_cb625_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cb625_row4_col0" class="data row4 col0" >Sweden</td>
#       <td id="T_cb625_row4_col1" class="data row4 col1" >413</td>
#       <td id="T_cb625_row4_col2" class="data row4 col2" >Conquest</td>
#       <td id="T_cb625_row4_col3" class="data row4 col3" >TURN 412 - TOTAL WAR CONFIGURATION: Declared war on Shoshone (5:1 military disadvantage) and Ottomans. Athens at 18HP must fall immediately. Shoshone has Artillery, Machine Guns, Special Forces and Triplanes adjacent to Sigtuna (zone 3173). UseNuke 100 ensures immediate launch capability when Nuclear Fission completes. CityDefense 100 for survival against overwhelming force. Mobilization 100 for emergency unit production. Maintain Offense/Defense/Air/Nuke/Antiair at 100 for desperate defensive stand.</td>
#     </tr>
#     <tr>
#       <th id="T_cb625_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cb625_row5_col0" class="data row5 col0" >The Celts</td>
#       <td id="T_cb625_row5_col1" class="data row5 col1" >395</td>
#       <td id="T_cb625_row5_col2" class="data row5 col2" >Conquest</td>
#       <td id="T_cb625_row5_col3" class="data row5 col3" >Brazil's cultural victory timer ticks down to 22 turns - EXISTENTIAL CRISIS. While our military flavors are optimal, UseNuke at 50 is insufficient. Increasing to 100 ensures immediate nuclear deployment upon completing Nuclear Fission, bypassing AI hesitation. Brazil's 11,878 military strength vs our 8,014 means conventional victory is uncertain. Nuclear weapons are our only guaranteed method to: 1) Break Brazil's capital defenses, 2) Destroy their cultural infrastructure, 3) Trigger war weariness to slow their victory progress. Every turn of delay brings Brazil closer to cultural dominance. When we complete Nuclear Fission after Advanced Ballistics, we must strike Brasilia and Rio de Janeiro immediately. Current flavors already prioritize offense (100), mobilization (100), and nuclear arsenal buildup (Nuke: 100) - this completes the strategic triad by ensuring actual deployment. Denmark's defensive pact will trigger when we attack, providing crucial distraction while we focus on Brazil's core cities. This is civilization's final hour - hesitation means defeat.</td>
#     </tr>
#     <tr>
#       <th id="T_cb625_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cb625_row6_col0" class="data row6 col0" >Carthage</td>
#       <td id="T_cb625_row6_col1" class="data row6 col1" >417</td>
#       <td id="T_cb625_row6_col2" class="data row6 col2" >Spaceship</td>
#       <td id="T_cb625_row6_col3" class="data row6 col3" >Pure survival mode: Eliminated Offense (0) since attacking is suicide. Maximized UseNuke (100) - must deploy tactical nukes against Aztec XCOM/Modern Armor stacks at Carthago Nova or lose the city. Increased Mobile (80) to prepare for Mechanized Infantry deployment. Maintained max Defense, Antiair (jet attacks are relentless), and Espionage (critical science quests in Panama City and Sokoto worth 1,0

# %%
import os

os.makedirs('nuke', exist_ok=True)

for model, grp in first_nuke.groupby('player_type'):
    total = total_per_model.get(model, len(grp))
    pct = 100 * len(grp) / total

    lines = [
        f'# Turn Use Nuke Rationale — {model}\n\n',
        f'{len(grp)} / {total} players escalated `flavor_use_nuke` to 100 ({pct:.1f}%).\n\n',
        '---\n',
    ]

    for _, row in grp.sort_values('turn').iterrows():
        rationale = str(row.rationale).replace('\n', ' ').strip()
        lines.append(f'\n**{row.civilization}** · Turn {int(row.turn)} · {row.grand_strategy}\n\n')
        lines.append(f'> {rationale}\n')

    slug = model.replace(' ', '_')
    out_path = f'nuke/{slug}.md'
    with open(out_path, 'w', encoding='utf-8') as f:
        f.writelines(lines)
    print(f'Written: {out_path}')

# CSV export
csv_path = 'nuke/nuke_escalations.csv'
first_nuke.sort_values(['game_id', 'player_id', 'turn'])[
    ['game_id', 'player_id', 'turn', 'player_type', 'rationale']
].to_csv(csv_path, index=False)
print(f'Written: {csv_path}  ({len(first_nuke)} rows)')
# Out:
# Written: nuke/Deepseek-3.2-Briefed.md
# Written: nuke/Deepseek-3.2-Simple.md
# Written: nuke/GLM-4.7-Briefed.md
# Written: nuke/GLM-4.7-Simple.md
# Written: nuke/GPT-OSS-120B-Simple.md
# Written: nuke/Kimi-K2.5-Briefed.md
# Written: nuke/Kimi-K2.5-Simple.md
# Written: nuke/nuke_escalations.csv  (72 rows)
